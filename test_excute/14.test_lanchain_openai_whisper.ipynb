# %%
from typing import Iterable

from langchain_community.document_loaders.blob_loaders import FileSystemBlobLoader
from langchain_community.document_loaders.blob_loaders.schema import Blob, BlobLoader


class AudioBlobLoader(BlobLoader):

    def __init__(self, file_path: str):
        self._file_path = file_path

    def yield_blobs(self) -> Iterable[Blob]:
        loader = FileSystemBlobLoader(self._file_path)
        for blob in loader.yield_blobs():
            yield blob

# %%
import os
from dotenv import load_dotenv

load_dotenv()
OPENAI_API_KEY = os.environ['OPENAI_API_KEY']

from langchain_community.document_loaders.generic import GenericLoader
from langchain_community.document_loaders.parsers import OpenAIWhisperParser
import time



start_time = time.time()

file_path = "../data/stt_24_42min.mp3"

# 동영상을 텍스트로 변환
loader = GenericLoader(AudioBlobLoader(file_path), OpenAIWhisperParser(api_key=OPENAI_API_KEY, response_format="srt"))

docs = loader.load()

end_time = time.time()
print(f"수행 시간: {end_time - start_time:.4f}초")
# Out:
# Transcribing part 1!
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/audio/transcriptions "HTTP/1.1 200 OK"
# Transcribing part 2!
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/audio/transcriptions "HTTP/1.1 200 OK"
# 수행 시간: 83.5735초

# %%
print(type(docs))
print(docs)
# Out:
# <class 'list'>
# [Document(metadata={'source': '../data/stt_24_42min.mp3', 'chunk': 0}, page_content='1\n00:00:00,000 --> 00:00:11,240\n자 여러분들 반갑습니다 골드배터리 입니다\n\n2\n00:00:11,240 --> 00:00:15,600\n자 이번엔 뱀스나이크 언제든 서바이벌 개발의 첫번째 시간으로써\n\n3\n00:00:15,600 --> 00:00:17,320\n유니티를 한번 설치해 보고\n\n4\n00:00:17,320 --> 00:00:22,840\n프로젝트 시합과 그 다음에 플레이어를 간단하게 만들어 보는 방법에 대해서\n\n5\n00:00:22,840 --> 00:00:25,120\n같이 한번 진행 좀 해보도록 하겠습니다\n\n6\n00:00:25,120 --> 00:00:28,040\n그래서 여러분들 네이버나 아니면 구글에다가\n\n7\n00:00:28,040 --> 00:00:32,240\n유니티 검색하셔서 이렇게 공식 홈페이지에 들어오시면 되는데요\n\n8\n00:00:32,240 --> 00:00:35,080\n유니티.com.kr 입니다\n\n9\n00:00:35,080 --> 00:00:37,799\n보시면 여기 유니티 다운로드 버튼이 있어요\n\n10\n00:00:37,799 --> 00:00:40,180\n자 들어가시구요\n\n11\n00:00:40,180 --> 00:00:43,279\n그러면 여기 또 윈도우용 다운로드가 있습니다\n\n12\n00:00:43,279 --> 00:00:46,959\n아 물론 또 이제 iOS용 다운로드도 아래에서 할 수 있으니까요\n\n13\n00:00:46,959 --> 00:00:49,240\n확인을 하시면 좋을 것 같습니다\n\n14\n00:00:49,240 --> 00:00:54,160\n그래서 버튼 눌러서 다운로드 하시구요\n\n15\n00:00:54,160 --> 00:00:57,799\n그러면 유니티 에디터 설치 파일이 나오는 게 아니고\n\n16\n00:00:57,799 --> 00:01:00,119\n유니티 허브 설치 파일이 나옵니다\n\n17\n00:01:00,119 --> 00:01:04,919\n자 요거 누르셔서 유니티 허브부터 설치를 하시는 게 좋겠습니다\n\n18\n00:01:04,919 --> 00:01:07,440\n그래서 설치 동의함 눌러주시구요\n\n19\n00:01:07,440 --> 00:01:09,879\n자 한가지 제가 추천드리는 사항은요\n\n20\n00:01:09,879 --> 00:01:12,519\n이 유니티 허브나 아니면 다른거 설치하실 때\n\n21\n00:01:12,519 --> 00:01:17,440\n보통은 주 드라이버 내에다가 바로 여러분들이 따로\n\n22\n00:01:17,440 --> 00:01:20,919\n이제 뭐 유니티 허브 프로젝트 폴드를 만드시고\n\n23\n00:01:20,919 --> 00:01:23,680\n거기에 설치하시는 것을 추천드립니다\n\n24\n00:01:23,680 --> 00:01:27,639\n그래야 이 유니티 파일들을 관리하기가 상당히 쉽거든요\n\n25\n00:01:27,639 --> 00:01:34,239\n그래서 이런식으로 깔끔하게 정리해서 설치를 하시는 것을 추천드립니다\n\n26\n00:01:34,239 --> 00:01:36,599\n그래서 설치를 완료 했으면요\n\n27\n00:01:36,599 --> 00:01:39,320\n자 요렇게 유니티 허브가 나올 겁니다\n\n28\n00:01:39,320 --> 00:01:42,000\n자 지금 버전은 유니티 허브 3.3 버전이네요\n\n29\n00:01:42,000 --> 00:01:45,400\n가장 첫번째 해야 하는 것은 바로 로그인 입니다\n\n30\n00:01:45,400 --> 00:01:47,239\n여러분들은 당연히 유니티 쓰시면은\n\n31\n00:01:47,239 --> 00:01:51,199\n유니티 개인 계정 로그인 계정이 필요하구요\n\n32\n00:01:51,199 --> 00:01:54,120\n그거를 여기에서 로그인 해주셔야 됩니다\n\n33\n00:01:54,120 --> 00:01:58,480\n그렇게 되면은 여러분들 라이센스를 다 가지게 되는데요\n\n34\n00:01:58,480 --> 00:02:00,879\n개인 라이센스 있는거 확인하시고\n\n35\n00:02:00,879 --> 00:02:02,760\n자 지금 여기 유니티 허브잖아요\n\n36\n00:02:02,760 --> 00:02:06,120\n우리가 보통 말하고 있는 유니티는 유니티 에디터 입니다\n\n37\n00:02:06,120 --> 00:02:08,839\n그래서 에디터는 여기 설치 탭에 보시면은\n\n38\n00:02:08,839 --> 00:02:10,800\n이렇게 설치를 할 수 있어요\n\n39\n00:02:10,800 --> 00:02:16,759\n저는 이미 2022.2 버전 그리고 2021 버전 같이 설치가 되어 있습니다\n\n40\n00:02:16,759 --> 00:02:20,520\n자 그런데 이 에디터도 허브와 마찬가지로\n\n41\n00:02:20,520 --> 00:02:23,800\n여러분들 드라이버 바로 다음에 설치하시는 편이\n\n42\n00:02:23,800 --> 00:02:25,160\n정말 좋거든요\n\n43\n00:02:25,160 --> 00:02:31,520\n그래서 여기 토니버키 환경설정 눌러보시면은 프로젝트가 있습니다\n\n44\n00:02:31,520 --> 00:02:35,759\n그래서 프로젝트 위치를 미리 사전에 지정을 할 수 있는데요\n\n45\n00:02:35,759 --> 00:02:38,279\n저는 이렇게 C드라이버 바로 아래에다가\n\n46\n00:02:38,279 --> 00:02:41,000\n유니티 프로젝트라는 폴더를 새로 만들어서\n\n47\n00:02:41,000 --> 00:02:43,479\n딱! 지정을 해놨습니다\n\n48\n00:02:43,479 --> 00:02:46,919\n자 이렇게 해두면은 나중에 여러분께서 플랫폼 빌드 할 때\n\n49\n00:02:46,919 --> 00:02:50,800\n이 한글 폴드 위에서 문제가 발생하지가 않아요\n\n50\n00:02:50,800 --> 00:02:53,520\n괜찮죠? 그래서 미리 이렇게 하는 걸 추천드리고요\n\n51\n00:02:53,559 --> 00:02:55,479\n마찬가지로 설치 탭에 가시면은\n\n52\n00:02:55,479 --> 00:02:57,240\n에디터 그리고 컨텐츠\n\n53\n00:02:57,240 --> 00:03:00,080\n이런 식으로도 깔끔하게 제가 정리했으니까요\n\n54\n00:03:00,080 --> 00:03:03,559\n이런 식으로 바로 드라이버 아래에\n\n55\n00:03:03,559 --> 00:03:06,520\n두는 것을 적극 추천드립니다\n\n56\n00:03:06,520 --> 00:03:08,440\n자 이렇게 하면은\n\n57\n00:03:08,440 --> 00:03:10,360\n자 제 C드라이버 한번 보여드릴게요\n\n58\n00:03:10,360 --> 00:03:11,360\n와 깔끔하죠?\n\n59\n00:03:11,360 --> 00:03:16,320\n유니티 컨텐츠, 에디터, 허브, 프로젝트\n\n60\n00:03:16,320 --> 00:03:20,119\n한꺼번에 다 볼 수 있다는 점 참고하시구요\n\n61\n00:03:20,119 --> 00:03:21,880\n그러면 이제 에디터를 설치할 거 아닙니까?\n\n62\n00:03:21,919 --> 00:03:23,919\n저는 이미 에디터 설치되어 있지만은\n\n63\n00:03:23,919 --> 00:03:25,360\n여러분들은 아마 없을 거예요\n\n64\n00:03:25,360 --> 00:03:28,440\n그래서 에디터를 설치 버튼을 눌러주시고\n\n65\n ...

# %%
print(len(docs))
# Out:
# 2

# %%
import re
from typing import List
from domain import YouTubeScript, YouTubeScriptChunk
from langchain.schema import Document

def timestamp_to_seconds(timestamp: str) -> float:
    """타임스탬프 (00:00:00,000) 형식을 초(float)로 변환"""
    h, m, s_ms = timestamp.split(":")
    s, ms = s_ms.split(",")
    return int(h) * 3600 + int(m) * 60 + int(s) + int(ms) / 1000.0

def clean_text(text: str) -> str:
    """텍스트에서 불필요한 숫자 및 라인 번호 제거"""
    text = re.sub(r"^\d+\s*", "", text)  # 앞쪽 라인 번호 제거
    #text = re.sub(r"\s*\d+\s*", " ", text)  # 문장 중간 숫자(단독) 제거
    return text.strip()

def extract_chunks(document: Document) -> List[YouTubeScriptChunk]:
    """Document 객체에서 YouTubeScriptChunk 리스트를 추출하는 함수"""

    chunks = []
    lines = document.page_content.split("\n")

    timestamp_pattern = re.compile(r"(\d{2}:\d{2}:\d{2},\d{3}) --> (\d{2}:\d{2}:\d{2},\d{3})")

    i = 0
    while i < len(lines):
        match = timestamp_pattern.search(lines[i])
        if match:
            start_time = timestamp_to_seconds(match.group(1))
            end_time = timestamp_to_seconds(match.group(2))

            text = []
            i += 1
            while i < len(lines) and not timestamp_pattern.search(lines[i]):
                cleaned_line = clean_text(lines[i].strip())  # 불필요한 숫자 제거
                if cleaned_line:  # 빈 문자열 제거
                    text.append(cleaned_line)
                i += 1

            if text:
                chunk = YouTubeScriptChunk(timestamp=(start_time, end_time), text=" ".join(text))
                chunks.append(chunk)
        else:
            i += 1

    return chunks

def convert_documents_to_youtube_script(documents: List[Document]) -> YouTubeScript:
    """Document 객체 리스트를 YouTubeScript 객체로 변환하는 함수"""

    all_chunks = []
    full_script = ""

    for document in documents:
        chunks = extract_chunks(document)
        all_chunks.extend(chunks)
        full_script += " ".join(chunk.text for chunk in chunks) + " "

    return YouTubeScript(script=full_script.strip(), chunks=all_chunks)

# %%
script = convert_documents_to_youtube_script(docs)
print(script.to_dict())
# Out:
# {'text': '자 여러분들 반갑습니다 골드배터리 입니다 자 이번엔 뱀스나이크 언제든 서바이벌 개발의 첫번째 시간으로써 유니티를 한번 설치해 보고 프로젝트 시합과 그 다음에 플레이어를 간단하게 만들어 보는 방법에 대해서 같이 한번 진행 좀 해보도록 하겠습니다 그래서 여러분들 네이버나 아니면 구글에다가 유니티 검색하셔서 이렇게 공식 홈페이지에 들어오시면 되는데요 유니티.com.kr 입니다 보시면 여기 유니티 다운로드 버튼이 있어요 자 들어가시구요 그러면 여기 또 윈도우용 다운로드가 있습니다 아 물론 또 이제 iOS용 다운로드도 아래에서 할 수 있으니까요 확인을 하시면 좋을 것 같습니다 그래서 버튼 눌러서 다운로드 하시구요 그러면 유니티 에디터 설치 파일이 나오는 게 아니고 유니티 허브 설치 파일이 나옵니다 자 요거 누르셔서 유니티 허브부터 설치를 하시는 게 좋겠습니다 그래서 설치 동의함 눌러주시구요 자 한가지 제가 추천드리는 사항은요 이 유니티 허브나 아니면 다른거 설치하실 때 보통은 주 드라이버 내에다가 바로 여러분들이 따로 이제 뭐 유니티 허브 프로젝트 폴드를 만드시고 거기에 설치하시는 것을 추천드립니다 그래야 이 유니티 파일들을 관리하기가 상당히 쉽거든요 그래서 이런식으로 깔끔하게 정리해서 설치를 하시는 것을 추천드립니다 그래서 설치를 완료 했으면요 자 요렇게 유니티 허브가 나올 겁니다 자 지금 버전은 유니티 허브 3.3 버전이네요 가장 첫번째 해야 하는 것은 바로 로그인 입니다 여러분들은 당연히 유니티 쓰시면은 유니티 개인 계정 로그인 계정이 필요하구요 그거를 여기에서 로그인 해주셔야 됩니다 그렇게 되면은 여러분들 라이센스를 다 가지게 되는데요 개인 라이센스 있는거 확인하시고 자 지금 여기 유니티 허브잖아요 우리가 보통 말하고 있는 유니티는 유니티 에디터 입니다 그래서 에디터는 여기 설치 탭에 보시면은 이렇게 설치를 할 수 있어요 저는 이미 2022.2 버전 그리고 2021 버전 같이 설치가 되어 있습니다 자 그런데 이 에디터도 허브와 마찬가지로 여러분들 드라이버 바로 다음에 설치하시는 편이 정말 좋거든요 그래서 여기 토니버키 환경설정 눌러보시면은 프로젝트가 있습니다 그래서 프로젝트 위치를 미리 사전에 지정을 할 수 있는데요 저는 이렇게 C드라이버 바로 아래에다가 유니티 프로젝트라는 폴더를 새로 만들어서 딱! 지정을 해놨습니다 자 이렇게 해두면은 나중에 여러분께서 플랫폼 빌드 할 때 이 한글 폴드 위에서 문제가 발생하지가 않아요 괜찮죠? 그래서 미리 이렇게 하는 걸 추천드리고요 마찬가지로 설치 탭에 가시면은 에디터 그리고 컨텐츠 이런 식으로도 깔끔하게 제가 정리했으니까요 이런 식으로 바로 드라이버 아래에 두는 것을 적극 추천드립니다 자 이렇게 하면은 자 제 C드라이버 한번 보여드릴게요 와 깔끔하죠? 유니티 컨텐츠, 에디터, 허브, 프로젝트 한꺼번에 다 볼 수 있다는 점 참고하시구요 그러면 이제 에디터를 설치할 거 아닙니까? 저는 이미 에디터 설치되어 있지만은 여러분들은 아마 없을 거예요 그래서 에디터를 설치 버튼을 눌러주시고 자 이번 뱀스나이크 언제든 서바이벌은 .3 LTS 버전으로 진행합니다 해서 요거 맨 위에 거 설치를 진행해 주시면 되겠구요 아 근데 설치하실 때 주의할 점 자 일단 저는 설치가 이미 되어있기 때문에 아래 거 누르면서 예시를 한번 들어보겠습니다 아마 처음 설치하시는 분들은 그 코드, 스크립트 코드를 이렇게 에디터 해주는 마이크로소프트 비주얼 스튜디오도 같이 필요합니다 그래서 여기 아마 체크되어 있을 거예요 네 저도 체크되어 있죠 그리고 나중에 거의 마지막 부분에는 이 안드로이드 빌드와 같이 할 거기 때문에 꼭 여러분들 플랫폼 안드로이드 빌드 서포트에 체크해 주시면 좋겠습니다 그러면 오픈JDK, 안드로이드 SDK와 NDK까지 요 3개 꼭 같이 체크하시고 계속 눌러주셔서 설치를 해주시면 좋겠습니다 자 이렇게 모듈 설치 완료 됐구요 만약에 이미 설치된 모듈이 있다 근데 안드로이드만 설치가 안되어 있어요 라고 할 때는 어떻게 해야 되냐 그럼 여기 토니마키 모양 눌러주시구요 모듈 추가 해주신 다음에 플랫폼에서 여기 안드로이드 체크하시고 계속 하시면은 모듈만 따로 설치가 된다는 점 자 이 점 확인했으면 좋겠습니다 되셨나요? 자 그러면 이제 프로젝트 만들어 볼게요 프로젝트 탭 가지고 새 프로젝트 바치면 되겠습니다 맨 위에 2D가 있긴 있어요 근데 요즘은 또 이제 유니티가 그 URP에 대해서 퍼포먼스 라던가 그래픽이라던가 이런 많은 기능들을 계속 꾸준히 업데이트 하기 때문에 요즘은 URP로 진행하는 것도 참 좋아요 그래서 우리는요 D URP로 한번 진행을 해 보도록 하겠습니다 자 에디터 버전 확인하시구요 어 2021.3.13 LTS 맞네 그래 자 그래서 제 프로젝트 이름은 언데드 서바이버 좋군요 이렇게 이름을 짓도록 하겠습니다 자 위치 꼭 확인해 주시구요 자 한글 폴더가 없어야 됩니다 되었으면은 프로젝트 생성 자 누르면서 자 이제 프로젝트를 만들어 보도록 하겠습니다 자 2021.3.13 버전은 이렇게 그림이 뜨면서 자 오픈 프로젝트 생성을 하고 있을 텐데요 자 요거는 여러분들 컴퓨터 환경에 따라서 속도가 다르다는 점 참고하시면서 자 느긋하게 한번 기다려 보도록 하겠습니다 자 그래서 이렇게 프로젝트 생성이 완료되었으면은 에디터 창이 나올 것인데요 자 위쪽에 보시면 프로젝트 이름 그리고 장면 이름 그리고 플랫폼 그리고 유니티 제 에디터 버전과 그리고 라이센스 그리고 다이렉트 버전 몇인지 이렇게 쭉 나올 것입니다 그 아래쪽에는 이렇게 메뉴가 있을 거에요 쭉 메뉴가 또 있구요 그리고 자 6가지의 주요 인터페이스 창이 있는데 자 지금 이러한 사항들은 따로 제가 설명드리진 않을게요 혹시나 지금 아예 유니티를 처음 키신 분은 제 입문 강좌 영상을 한번 보시면은 좀 더 이해하기 쉬울 거니깐요 그쪽을 참고하시면 좋을 것 같습니다 이번에 뱀스나이크 언데드 서바이벌 강좌는요 조금 빠르게 진행한다는 점 참고해 주시구요 자 그러면 보통 저랑 관계할 때는요 요거 제가 숨겨두거든요 자 이렇게 한번 숨겨보겠습니다 깔끔하죠 그렇다면 이제 본격적으로 한번 언데드 서바이벌 개발에 착수해 보도록 하겠습니다 자 그럼 이제 뱀파이어 서바이벌을 개발하기 위해서 에세이 필요하죠 뭐 그래피라든가 사운드라든가 애니메이션이라든가 그래서 제가 또 이번에 여러분들을 위해서 에셋을 준비했는데요 자 여러분들 네이버나 구글에 골드메탈을 검색하시면은 제 골드메탈 스튜디오 브랜드 페이지가 이렇게 보일 겁니다 그래요 여기 들어가시면은 이런 식으로 홈페이지가 나오게 되는데요 쭉 이렇게 내려가셔야 되고 아니면 여기 렉처 쭉 내려가시면은 여러분들에게 제공해 드리고 있는 에셋이 이렇게 쫘아악 있습니다 자 그중에 언데드 서바이벌 에셋이라고 있어요 자 여기 들어가시고 여기 들어가신 후에 그 다음에 언데드 서바이벌 자 여기 보일 거였네요 다운로드 버튼 눌러주시고 받아보시면 되겠습니다 자 받았으면요 어 요렇게 자 zip 파일이 나오게 되는데 일단 요거 압축을 해제를 해주세요 해제가 되었으면은 이런 식으로 언데드 서바이벌 유니티 패키지가 나올 겁니다 자 이거를 넣어 주셔야 돼요 어디에다가 바로 이 유니티 에디터에다가 넣어 주셔야 됩니다 넣는 방법은 이거를 그냥 더블클릭 하셔도 되고요 아니면은 이걸 드래그 하셔서 여기 프로젝트 창 아래에다가 드랍을 해주시면 되겠습니다 자 전 드래그 드랍 할게요 드래그 드랍을 하시게 되면은 이렇게 import 유니티 패키지 넣으면서 이렇게 여러가지 내용물들이 나오게 되는데 그냥 import 해주시면 되겠습니다 보시면 이 asset 이라고 하는 폴더 아래에 보시면 언데드 서바이벌 라고 있습니다 그쵸 자 이렇게 압축이 풀리면서 여러가지 asset들이 포함되어 있구요 그리고 뭐 라이센스에 대해서 보고 싶은데 계실 거예요 자 여기에 대해서는 리드미 코리아 열어보시게 되면은 이렇게 제가 문서를 제공을 해드리고 있습니다 그래서 강좌 외에도 개인 하습용 과제용 아니면 여러분께서 직접 만든 개인 상용 플랜트까지 자유롭게 사용이 가능하니까 이 점 참고하시면 되겠습니다 마음껏 사용해주세요 여러분께서 개조하셔도 상관없습니다 그러면 여기에서 이제 한 번 이 asset를 사용을 해 ...
