# %%
from infrastructure.database.mongo_client import MongoDBClient
from infrastructure.repository import YouTubeContentRepository
import os
from dotenv import load_dotenv

load_dotenv()

# MongoDB 클라이언트 초기화
client = MongoDBClient(uri=os.environ['MONGO_CONNECTION_STRING'])
client.connect()

# 저장소 초기화
repository = YouTubeContentRepository(client)

contents = repository.find_all()
content = contents[0]
print(content.title)
# Out:
# Connected to MongoDB
# 2D 오브젝트🧍만들기 [유니티 뱀서라이크 01]

# %%
script_whisper = content.script_whisper
script_auto = content.script_auto

print(script_whisper)
print("----"*7)
print(script_auto)
# Out:
# YouTubeScript(script=' 자 여러분들 반갑습니다 골드메탈입니다 이번엔 뱀스라이크 언더티 서바이버 개발의 첫 번째 ...', chunks=[(0.0-11.24:  자 여러분들 반갑습니다 골...), (11.24-15.56:  이번엔 뱀스라이크 언더티 ...), (15.56-24.67:  유니티를 한번 설치해 보고...), ...] (427 chunks))
# ----------------------------
# YouTubeScript(script='자 여러분들 반갑습니다 이번에는 뱀사이크 언제든 서바이버 개발에 첫 번째 시간으로서 일단 ...', chunks=[(7.799-11.88: 자 여러분들 반갑습니다 이번...), (12.059-14.34: 뱀사이크...), (13.019-16.379: 언제든 서바이버 개발에 첫 ...), ...] (634 chunks))

# %%
from pydantic import BaseModel, Field
from typing import List, Tuple
from langchain.output_parsers import PydanticOutputParser

# YouTubeScriptChunk의 Pydantic 모델 정의
class YouTubeScriptChunkModel(BaseModel):
    timestamp: Tuple[int, int] = Field(..., description="Chunk의 시작 및 끝 타임스탬프")
    text: str = Field(..., description="해당 시간의 스크립트 텍스트")

class YouTubeScriptChunksModel(BaseModel):
    chunks: List[YouTubeScriptChunkModel] = Field(..., description="타임스탬프별 텍스트 조각 리스트")

pydantic_script_refine_output_parser = PydanticOutputParser(pydantic_object=YouTubeScriptChunksModel)

# %%
from langchain.prompts import PromptTemplate

script_refine_prompt_template = PromptTemplate(
    partial_variables={'output_format': pydantic_script_refine_output_parser.get_format_instructions()},
    input_variables=["description", "script_auto", "chunks_auto", "script_whisper", "chunks_whisper"],
    template="""
    다음은 유튜브 영상의 설명과 자막입니다.
    유튜브 영상 설명:
    {description}

    - 자동 생성 자막: {script_auto}
    - Whisper 자막: {script_whisper}

    위 정보를 참고하여 더 정확하고 매끄러운 자막 청크를 생성해주세요.
    각 청크는 타임스탬프와 텍스트로 구성되어야 합니다.

    - 오타가 났거나 애매한 용어는 유튜브 영상 설명 내용을 참고해주세요.
    - 타임스탬프를 엄격하게 지켜주세요.

    반드시 아래 JSON 형식에 맞춰 반환하세요. 다른 텍스트는 포함하지 마세요.
    {output_format}
    """
)

# %%
from langchain_openai import ChatOpenAI

openai_llm = ChatOpenAI(model="gpt-4o-mini", api_key=os.environ['OPENAI_API_KEY'])

# %%
script_refine_chain = script_refine_prompt_template | openai_llm | pydantic_script_refine_output_parser

# %%
input_data = {
        "description": content.description,
        "script_auto": "\n".join(
            [f"({int(chunk.start_time)}-{int(chunk.end_time)}): {chunk.text}" for chunk in content.script_auto.chunks]
        ),
        "script_whisper": "\n".join(
            [f"({int(chunk.start_time)}-{int(chunk.end_time)}): {chunk.text}" for chunk in content.script_whisper.chunks]
        ),
    }

print(input_data)
# Out:
# {'description': '뱀서라이크 유니티 개발 강좌 첫번째 시간!\n유니티를 처음 만지는 입문자 분들도 따라하기 쉽도록\n2D 오브젝트를 유니티에서 어떻게 만드는지 차근차근 설명해드리고 있습니다.\n본격적인 움직임 구현은 다음 시간에 다룰 예정입니다.  🤗\n\n📚 뱀서라이크 개발 채널\nhttps://www.youtube.com/playlist?list=PLO-mt5Iu5TeZF8xMHqtT_DhAPKmjF6i3x\n\n📦 언데드서바이버 에셋\nhttps://prf.hn/l/aQNdNmA\n\n📖 챕터\n01 00:00 프로젝트 시작하기\n02 07:00 에셋 가져오기\n03 09:24 오브젝트 만들기\n04 17:11 컴포넌트 추가하기\n\n#유니티강좌 #유니티기초 #뱀서라이크 #뱀파이어서바이버', 'script_auto': '(7-11): 자 여러분들 반갑습니다 이번에는\n(12-14): 뱀사이크\n(13-16): 언제든 서바이버 개발에 첫 번째\n(14-19): 시간으로서 일단 유니티를 한번\n(16-20): 설치해보고 자 브레이트 시합과 그\n(19-22): 다음에 플레이어를\n(20-23): 간단하게 만들어 보는\n(22-25): 방법에 대해서 같이 한번\n(23-27): 진행 좀 해보도록 하겠습니다 그래서\n(25-30): 여러분들 뭐 네이버나 아니면\n(27-31): 구글에다가 유니티 검색하셔서 이렇게\n(30-32): 공식 홈페이지\n(31-36): 들어오시면 되는데요\n(32-38): 유니티.com/h 다운로드\n(36-40): 버튼이 있어요 자 들어가시고요\n(40-43): 그러면 여기 또 윈도우용 다운로드\n(43-45): 했습니다\n(43-47): 물론 또 이제 ius는 다운로드도\n(45-50): 아래에서 할 수 있으니깐요 확인을\n(47-53): 하시면 좋겠습니다 그래서 버튼 눌러서\n(50-53): 자 다운로드 하시고요\n(54-58): 그러면 유니티 에디터 설치 파일이\n(57-60): 나오는게 아니고\n(58-62): 허브 설치 파일이 나옵니다 자 이거\n(60-63): 누르셔서\n(62-66): 밑에 허브부터 설치를 하시는게\n(63-69): 좋겠습니다 그래서 설치 동의함\n(66-70): 눌러주고요 자 한 가지 제가\n(69-73): 추천드리는 사항은요이 유니티 허브나\n(70-77): 아니면 다른 거 설치하실 때 보통은\n(73-80): 주드라이버 내에다가 바로 여러분들이\n(77-81): 따로 이제 뭐 유니티 허브 프린트\n(80-82): 폴드를 만드시고 거기에 설치하시는\n(81-83): 것을\n(82-86): 추천드립니다\n(83-89): 그래야 유니티 파일들을 관리하기가\n(86-92): 상당히 쉽거든요 그래서 이런 식으로\n(89-94): 깔끔하게 정리해서 설치를 하시는 것을\n(92-97): 추천드립니다\n(94-99): 그래서 설치를 완료했으면요 이렇게\n(97-101): 유니티 허브가 나올 겁니다 자 지금\n(99-104): 보시는 리치허브 3.3 버전이네요\n(101-106): 가장 첫 번째 해야한 것은 바로\n(104-109): 로그인입니다 여러분들 당연히\n(106-111): 유니티 개인 계정\n(109-112): 로그인 계정이 필요하구요 그거를\n(111-114): 여기에서\n(112-117): 로그인 해 주셔야 됩니다\n(114-119): 그렇게 되면은 여러분들 라이센스를 다\n(117-119): 가지게 되는데요\n(122-126): 우리가 보통 말하고 있는 유니티는\n(124-129): 유니티 에디터입니다 그래서 에디터는\n(126-132): 여기 설치 태백 보시면은 이렇게\n(129-134): 설치를 할 수 있어요 저는 이미\n(132-137): 2021.2 버전 그리고 2021\n(134-139): 버전 같이 설치가 되어 있습니다 자\n(137-141): 그런데이 에디터도\n(139-144): 허브와 마찬가지로 여러분들\n(141-147): 드라이버 바로 다음에 설치하는 편이\n(144-150): 정말 좋거든요 그래서 자 여기\n(147-152): 톱니바퀴 환경 설정 눌러 보시면은\n(150-154): 프로젝트가 있습니다 그래서 프로젝트\n(152-157): 위치를 미리 사전 때문에\n(154-158): 지정을 할 수 있는데요 저는 이렇게\n(157-161): c 드라이브 바로 아래에다가 유니티\n(158-161): 플레이트라는 폴더를 새로 만들어서\n(161-164): 딱\n(161-166): 지점을 해냈습니다 자 이렇게 해두면은\n(164-169): 나중에 여러분께서 플랫폼 빌드 할\n(166-169): 때이 한글 폴더에 의해서\n(169-171): 문제가\n(169-172): 발생하지가 않아요\n(171-174): 괜찮죠 그래서 미리 이렇게 하는 걸\n(172-175): 추천드리고요 마찬가지로 설치 탭에\n(174-178): 가시면은\n(175-180): 에디터 그리고 컨텐츠 이런 식으로도\n(178-184): 깔끔하게 제가 정리했으니까요 아 이런\n(180-186): 식으로 바로 드라이버 아래에 두른거를\n(184-188): 적극 추천드립니다\n(186-190): 자 이렇게 하면은\n(188-193): 자 제 c드라이브 한번 보여 드릴게요\n(190-194): 와 깔끔하죠 유니드 컨텐츠\n(193-194): 에디터\n(194-197): 허브\n(194-198): 브레이트 한꺼번에 다 볼 수 있다는\n(197-201): 점\n(198-202): 참고하시고요 그럼 이제 에디터를\n(201-204): 설치할 거 아닙니까 저는 이미 에디터\n(202-207): 설치되어 있지만 여러분들 아마 없을\n(204-210): 거예요 그래서 에디터를 설치 버튼을\n(207-212): 눌러 주시고 이번 뱀사라이크\n(210-213): 서바이버는 2021.3 lts\n(212-214): 버전으로 진행합니다\n(213-216): 해서 요거\n(214-219): 맨 위에 거 설치를 진행해 주시면\n(216-221): 되겠구요 아 근데 설치하실 때 주의할\n(219-224): 점 자 일단 저는 설치가 이미 됐기\n(221-225): 때문에 아래 거 누르면서 예시를 한번\n(224-228): 들어보겠습니다\n(225-231): 아마 처음 설치하실 분들은 그\n(228-233): 코드 스크립트 코드를 이렇게 에디터\n(231-234): 해주는 마이크로소프트 비주얼\n(233-236): 스튜디오도 같이 필요합니다 그래서\n(234-239): 여기 아마 체크 되어 있을 거예요네\n(236-243): 저도 체크 되어 있죠 그리고\n(239-245): 나중에 자 거의 마지막 부분에는이\n(243-245): 안드로이드 빌드도 같이 할 거기\n(245-248): 때문에\n(245-249): 꼭 여러분들 플랫폼 안드로이드 필드\n(248-252): 서포트에 체크해 주시면 좋겠습니다\n(249-255): 그럼 오픈 jdk 안드로이드 k와\n(252-257): ndk까지요 3개 꼭 같이 체크하시고\n(255-261): 계속을 눌러주셔서 설치를 해주시면\n(257-263): 좋겠습니다 자 이렇게 모든 설치\n(261-264): 완료됐고요 만약에 이미 설치된 무도\n(263-266): 있다\n(264-269): 근데 안드로이드만 설치가 안 돼\n(266-270): 있어요라고 할 때는 어떻게 됐냐 여기\n(269-274): 톱니바퀴 뭐야\n(270-276): 눌러주시고요 모듈 추가 해주신 다음에\n(274-279): 플랫폼에서 여기 안드로이드 체크하시고\n(276-282): 계속하시면 모듈만 따로 설치가 된다는\n(279-285): 점 자이 점 확인했으면 좋겠습니다\n(282-287): 되셨나요 자 그러면 이제 플레이트\n(285-288): 한번 만들어 볼게요\n(287-291): 플레이트 탭 가지고\n(288-294): 새플렉트 가시면 되겠습니다\n(291-297): 맨 위에 2d가 있긴 있어요 자 근데\n(294-299): 요즘은 또 이제 유니티가 그 urp에\n(297-301): 대해서 퍼포먼스라든가\n(299-303): 그래픽이라든가 이러한 많은 기능들을\n(301-305): 계속 꾸준히 ...

# %%
import tiktoken

encoder = tiktoken.encoding_for_model("gpt-4o-mini")

prompt = script_refine_prompt_template.format(**input_data)
print(prompt)
tokens = len(encoder.encode(prompt))
print(tokens)
# Out:
#     다음은 유튜브 영상의 설명과 두 개의 자막입니다.
#     유튜브 영상 설명:
#     뱀서라이크 유니티 개발 강좌 첫번째 시간!
# 유니티를 처음 만지는 입문자 분들도 따라하기 쉽도록
# 2D 오브젝트를 유니티에서 어떻게 만드는지 차근차근 설명해드리고 있습니다.
# 본격적인 움직임 구현은 다음 시간에 다룰 예정입니다.  🤗
#
# 📚 뱀서라이크 개발 채널
# https://www.youtube.com/playlist?list=PLO-mt5Iu5TeZF8xMHqtT_DhAPKmjF6i3x
#
# 📦 언데드서바이버 에셋
# https://prf.hn/l/aQNdNmA
#
# 📖 챕터
# 01 00:00 프로젝트 시작하기
# 02 07:00 에셋 가져오기
# 03 09:24 오브젝트 만들기
# 04 17:11 컴포넌트 추가하기
#
# #유니티강좌 #유니티기초 #뱀서라이크 #뱀파이어서바이버
#
#     - 자동 생성 자막: (7-11): 자 여러분들 반갑습니다 이번에는
# (12-14): 뱀사이크
# (13-16): 언제든 서바이버 개발에 첫 번째
# (14-19): 시간으로서 일단 유니티를 한번
# (16-20): 설치해보고 자 브레이트 시합과 그
# (19-22): 다음에 플레이어를
# (20-23): 간단하게 만들어 보는
# (22-25): 방법에 대해서 같이 한번
# (23-27): 진행 좀 해보도록 하겠습니다 그래서
# (25-30): 여러분들 뭐 네이버나 아니면
# (27-31): 구글에다가 유니티 검색하셔서 이렇게
# (30-32): 공식 홈페이지
# (31-36): 들어오시면 되는데요
# (32-38): 유니티.com/h 다운로드
# (36-40): 버튼이 있어요 자 들어가시고요
# (40-43): 그러면 여기 또 윈도우용 다운로드
# (43-45): 했습니다
# (43-47): 물론 또 이제 ius는 다운로드도
# (45-50): 아래에서 할 수 있으니깐요 확인을
# (47-53): 하시면 좋겠습니다 그래서 버튼 눌러서
# (50-53): 자 다운로드 하시고요
# (54-58): 그러면 유니티 에디터 설치 파일이
# (57-60): 나오는게 아니고
# (58-62): 허브 설치 파일이 나옵니다 자 이거
# (60-63): 누르셔서
# (62-66): 밑에 허브부터 설치를 하시는게
# (63-69): 좋겠습니다 그래서 설치 동의함
# (66-70): 눌러주고요 자 한 가지 제가
# (69-73): 추천드리는 사항은요이 유니티 허브나
# (70-77): 아니면 다른 거 설치하실 때 보통은
# (73-80): 주드라이버 내에다가 바로 여러분들이
# (77-81): 따로 이제 뭐 유니티 허브 프린트
# (80-82): 폴드를 만드시고 거기에 설치하시는
# (81-83): 것을
# (82-86): 추천드립니다
# (83-89): 그래야 유니티 파일들을 관리하기가
# (86-92): 상당히 쉽거든요 그래서 이런 식으로
# (89-94): 깔끔하게 정리해서 설치를 하시는 것을
# (92-97): 추천드립니다
# (94-99): 그래서 설치를 완료했으면요 이렇게
# (97-101): 유니티 허브가 나올 겁니다 자 지금
# (99-104): 보시는 리치허브 3.3 버전이네요
# (101-106): 가장 첫 번째 해야한 것은 바로
# (104-109): 로그인입니다 여러분들 당연히
# (106-111): 유니티 개인 계정
# (109-112): 로그인 계정이 필요하구요 그거를
# (111-114): 여기에서
# (112-117): 로그인 해 주셔야 됩니다
# (114-119): 그렇게 되면은 여러분들 라이센스를 다
# (117-119): 가지게 되는데요
# (122-126): 우리가 보통 말하고 있는 유니티는
# (124-129): 유니티 에디터입니다 그래서 에디터는
# (126-132): 여기 설치 태백 보시면은 이렇게
# (129-134): 설치를 할 수 있어요 저는 이미
# (132-137): 2021.2 버전 그리고 2021
# (134-139): 버전 같이 설치가 되어 있습니다 자
# (137-141): 그런데이 에디터도
# (139-144): 허브와 마찬가지로 여러분들
# (141-147): 드라이버 바로 다음에 설치하는 편이
# (144-150): 정말 좋거든요 그래서 자 여기
# (147-152): 톱니바퀴 환경 설정 눌러 보시면은
# (150-154): 프로젝트가 있습니다 그래서 프로젝트
# (152-157): 위치를 미리 사전 때문에
# (154-158): 지정을 할 수 있는데요 저는 이렇게
# (157-161): c 드라이브 바로 아래에다가 유니티
# (158-161): 플레이트라는 폴더를 새로 만들어서
# (161-164): 딱
# (161-166): 지점을 해냈습니다 자 이렇게 해두면은
# (164-169): 나중에 여러분께서 플랫폼 빌드 할
# (166-169): 때이 한글 폴더에 의해서
# (169-171): 문제가
# (169-172): 발생하지가 않아요
# (171-174): 괜찮죠 그래서 미리 이렇게 하는 걸
# (172-175): 추천드리고요 마찬가지로 설치 탭에
# (174-178): 가시면은
# (175-180): 에디터 그리고 컨텐츠 이런 식으로도
# (178-184): 깔끔하게 제가 정리했으니까요 아 이런
# (180-186): 식으로 바로 드라이버 아래에 두른거를
# (184-188): 적극 추천드립니다
# (186-190): 자 이렇게 하면은
# (188-193): 자 제 c드라이브 한번 보여 드릴게요
# (190-194): 와 깔끔하죠 유니드 컨텐츠
# (193-194): 에디터
# (194-197): 허브
# (194-198): 브레이트 한꺼번에 다 볼 수 있다는
# (197-201): 점
# (198-202): 참고하시고요 그럼 이제 에디터를
# (201-204): 설치할 거 아닙니까 저는 이미 에디터
# (202-207): 설치되어 있지만 여러분들 아마 없을
# (204-210): 거예요 그래서 에디터를 설치 버튼을
# (207-212): 눌러 주시고 이번 뱀사라이크
# (210-213): 서바이버는 2021.3 lts
# (212-214): 버전으로 진행합니다
# (213-216): 해서 요거
# (214-219): 맨 위에 거 설치를 진행해 주시면
# (216-221): 되겠구요 아 근데 설치하실 때 주의할
# (219-224): 점 자 일단 저는 설치가 이미 됐기
# (221-225): 때문에 아래 거 누르면서 예시를 한번
# (224-228): 들어보겠습니다
# (225-231): 아마 처음 설치하실 분들은 그
# (228-233): 코드 스크립트 코드를 이렇게 에디터
# (231-234): 해주는 마이크로소프트 비주얼
# (233-236): 스튜디오도 같이 필요합니다 그래서
# (234-239): 여기 아마 체크 되어 있을 거예요네
# (236-243): 저도 체크 되어 있죠 그리고
# (239-245): 나중에 자 거의 마지막 부분에는이
# (243-245): 안드로이드 빌드도 같이 할 거기
# (245-248): 때문에
# (245-249): 꼭 여러분들 플랫폼 안드로이드 필드
# (248-252): 서포트에 체크해 주시면 좋겠습니다
# (249-255): 그럼 오픈 jdk 안드로이드 k와
# (252-257): ndk까지요 3개 꼭 같이 체크하시고
# (255-261): 계속을 눌러주셔서 설치를 해주시면
# (257-263): 좋겠습니다 자 이렇게 모든 설치
# (261-264): 완료됐고요 만약에 이미 설치된 무도
# (263-266): 있다
# (264-269): 근데 안드로이드만 설치가 안 돼
# (266-270): 있어요라고 할 때는 어떻게 됐냐 여기
# (269-274): 톱니바퀴 뭐야
# (270-276): 눌러주시고요 모듈 추가 해주신 다음에
# (274-279): 플랫폼에서 여기 안드로이드 체크하시고
# (276-282): 계속하시면 모듈만 따로 설치가 된다는
# (279-285): 점 자이 점 확인했으면 좋겠습니다
# (282-287): 되셨나요 자 그러면 이제 플레이트
# (285-288): 한번 만들어 볼게요
# (287-291): 플레이트 탭 가지고
# (288-294): 새플렉트 가시면 되겠습니다
# (291-297): 맨 위에 2d가 있긴 있어요 자 근데
# (294-299): 요즘은 또 이제 유니티가 그 urp에
# (297-301): 대해서 퍼포먼스라든가
# (299-303): 그래픽이라든가 이러한 많은 기능들을
# (301-305): 계속 꾸준히 업데이트 하기 때문에
# (303-309): 요즘은 urp를 드러나는 것도 참
# (305-311): 좋아요 그래서 우리는요 2D
# (309-313): urp를 한번 진행을 해보도록
# (311-314): 하겠습니다 자 에디터 버전
# (313-317): 확인하시고요
# (314-320): 22003.13 lts 맞네 그래 자
# (317-323): 그래서 제 프로젝트 이름은
# (320-323): 언데드
# (323-327): 좋군요 이렇게
# (325-327): 이름을 짓도록 하겠습니다 자 위치
# (327-329): 꼭
# (327-332): 확인해 주시고요 자 한글 폴더가
# (329-335): 없어야 됩니다 되었으면
# (332-338): 프로젝트 생성 자 누르면서
# (335-338): 페이트를 만들어 보도록 하겠습니다
# (339-345): 자 2021 버전은 이렇게 그림이
# (342-346): 뛰면서 자 오픈 플레이트
# (345-348): 생성하고 있을 텐데요
# (346-350): 요거는 여러분들 컴퓨터 환경에 따라서
# (348-352): 속도가 다르다는 점
# (350-353): 참고하시면서
# (352-355): 느긋하게 한번
# (353-358): 기다려 보도록 하겠습니다
# (359-364): 자 그래서 이렇게
# (362-367): 프로젝트 생성이 완료되었으면
# (364-367): 에디터 창이 나올 것인데요
# (369-373): 플랫폼 그리고 유니티치 에디터 버전과
# (371-375): 그리고
# (373-377): 라이센스 다이렉트 버전 몇인지 이렇게
# (375-379): 쭉 나올 것입니다 그 아래쪽에는
# (377-382): 이렇게 메뉴 있을 거예요
# (379-384): 쭉 메뉴가 됐구요 그리고 자 6가지의
# (382-385): 주요
# (384-387): 인터페이스 창이 있는데 자 지금
# (385-390): 이러한 사항들은
# (387-392): 따로 제가 설명드리지 않을게요
# (390-395): 혹시나 지금 아예 유니티를 처음 키신
# (392-397): 분은 제 그러니까 입문 강좌
# (395-399): 영상을 한번 보시면은 좀 더 이해하기
# (397-401): 쉬울 거니깐요 그쪽을 참고하시면 좋을
# (399-402): 것 같습니다 이번에
# (401-404): 뱀프라이크
# (402-407): 언데드 서바이벌 강좌는요 조금 빠르게
# (404-410): 진행한다는 점 참고해 주시고요 자
# (407-410): 그러면 보통 저는 강조할 때는요
# (412-415): 깔끔하죠
# (413-417): 그렇다면 이제 본격적으로 한번
# (415-418): 언제든 서버에
# (417-422): 착수해 보도록 하겠습니다
# (457-460): 다운로드
# (461-467): 버튼 눌러주시고 받아보시면 되겠습니다
# (464-469): 자 받았으면요 이렇게 자 g8이
# (467-473): 나오는데 일단 요거
# (469-473): 압축을 해제를 해주세요
# (473-477): 해제가 되었으면 이런 식으로
# (478-483): 서바이버 유니티 패키지가 나올 겁니다
# (480-486): 자 이거를 넣어 주셔야 돼요
# (483-488): 어디에다가 바로이 유니티 에디터에다가
# (486-489): 넣어 주셔야 됩니다
# (488-491): 넣는 방법은 이거를 그냥 더블
# (489-495): 클릭하셔도 되고요 아니면은 이걸
# (491-497): 드래그 하셔서 여기 프랜차 아래다가
# (495-500): 드랍을 해주시면 되겠습니다 자 전
# (497-500): 드래그 드랍 할게요
# (500-505): 드래그 드랍을 하시게 되면은 이렇게
# (502-506): 임포트 일렉트 패키지 넣으면서 이렇게
# (505-508): 여러가지
# (506-510): 내용물들이 나오게 되는데 그냥 임포트
# (508-513): 해주시면 되겠습니다
# (510-515): 보시면이 에셋이라고 하는 폴더 아래에
# (513-517): 보시면
# (515-520): 언제든 서바이버라고 있습니다
# (517-521): 그렇죠 자 이렇게 압축이 풀리면서
# (520-523): 여러가지
# (521-525): 에셋들이
# (523-525): 포함이 되어 있고요
# (526-529): 그리고 뭐 라이센스에 대해서 궁금하신
# (528-531): 분들 계실 거예요 자 여기에 대해서는
# (529-533): 제가 리듬이
# (531-535): 코리아
# (533-538): 열어 보시게 되면 이렇게 제가 문서를
# (535-540): 제공을 해 드리고 있습니다
# (538-542): 그렇죠 그래서
# (540-544): 강좌 외에도 뭐 개인 학습용 뭐
# (542-547): 과제용 아니면 여러분께서 직접 만든
# (544-550): 개인 상용 프랜드까지 자유롭게 사용이
# (547-551): 가능하니까 이점
# (550-554): 참고하시면 좋겠습니다 내 마음껏
# (551-557): 해주세요네 여러분께서 개조하셔도
# (554-557): 상관없습니다
# (557-561): 그러면 여기에서 이제 한번 이틀들을
# (560-563): 사용을 해서 이제 플레이어를
# (561-564): 만들어야겠죠
# (563-568): 자 그럼 플레이를 한번 만들어 볼
# (564-569): 건데요 그 전에 자 지금이 창을
# (568-572): 편리하게 쓰도록
# (569-573): 요걸 살짝 커스텀을 재볼 건데요요
# (572-574): 창에 이름 있죠
# (573-577): 이름 탭을
# (574-579): 꾹 누르시면은 이렇게 자유롭게 이동할
# (577-582): 수 있는데요 이번에는 이런 식으로
# (579-582): 한번
# (582-587): 창을 한번 이렇게
# (584-587): 변경을 해 보도록 하겠습니다
# (588-592): 그래서 어쨌든 나중에 여러분 이제
# (590-596): 모바일로 할 거기 때문에요
# (592-598): 이런 느낌으로 한번 세팅을 해보시면
# (596-599): 어떨까 합니다 자 그럼 여기서 이제
# (598-603): 플레이어를 놓으려면 이미지가 필요하죠
# (599-604): 자 게임 개발에서는 보통 이미지를
# (603-607): 스프라이트라고 부릅니다
# (604-608): 스프레이트 폴더 들어가시면은 다양한
# (607-611): 스프라이트들이 이렇게 쭉 있는데요
# (608-613): 보통 이제 우리가 게임을 개발할 때
# (611-614): 뭐 아트 직군이 따로 있다 하시면 그
# (613-617): 아트 분들께서
# (614-620): 도트나 아니면 2D 만드실 때는 보통
# (617-622): 이런 식으로 묶어서 주는 경우가
# (620-625): 있어요 자 요런 것들을 우리는
# (622-626): 아틀라스 혹은 리스프라이트 시트라고
# (625-628): 부릅니다
# (626-631): 근데 요거 이제 잘라야 하잖아요 그쵸
# (628-632): 이거를 그대로 통째로
# (631-634): 갖다 쓰기에는
# (632-637): 조금 무리가 있습니다 이런 식으로요
# (634-639): 아 좀 그래요 그쵸 그래서 잘랐어야
# (637-641): 되는데 그 짤라 쓰는 방법에 대해서
# (639-644): 먼저 설명 좀 해드리겠습니다 자 파머
# (641-646): 0이 이게 플레이어 티프트 건데요
# (644-648): 요거 선택하시고 여기
# (646-650): 인스펙터 창 보시면은
# (648-653): 여러가지 설정이 있습니다 자 좀 많죠
# (650-655): 우리는 세 가지만 보시면 될 것
# (653-657): 같습니다 일단은 픽셀퍼 유닛 지금
# (655-660): 배그로 됐죠이 100일의 의미는 지금
# (657-662): 보시면이 씬에 제가 한 칸 이렇게
# (660-664): 보이잖아요 모눈종이 보이시니까 자이
# (662-666): 한 칸에 픽셀이 몇 개가 들어가느냐
# (664-667): 그 얘기입니다
# (666-670): 즉
# (667-672): 100이면이 한 칸에 무려 100개가
# (670-675): 들어간다는 얘기죠이는 뭐 100 x는
# (672-678): 뭐 만기가 다른 얘기고
# (675-679): 그래서요 저는요 지금이 캐릭터 하나의
# (678-681): 크기가
# (679-683): 18이거든요 그래서 이걸 18로
# (681-687): 바꿔줍니다
# (683-690): 되었습니까 자 그 다음에 아랫줄
# (687-692): 보시면 필터 모드 있죠 자 이거 지금
# (690-695): 빌린으로 되어 있는데요
# (692-696): 요거를 이제 포인트로 바꿔 주시고요
# (695-697): 깔끔하게
# (696-700): 필터를 쓰지 않겠다
# (697-702): 원래의 모습을 보시면
# (700-704): 컴프레션
# (702-704): 색상을 아까처럼 압축하는 방식이
# (704-708): 있어요
# (704-709): 근데 지금 우리는 도트 이미지죠
# (708-710): 색깔 자체가 별로 없기 때문에
# (709-712): 굳이 압축을 할 필요도 없습니다
# (710-714): 오히려
# (712-716): 색상이 깨지기 때문에 우리가 원하는
# (714-718): 색상이 안 나와요 그래서
# (716-720): 요거를 논으로 바꿔 주시면 되겠습니다
# (718-722): 자 이렇게 세 개 됐죠
# (720-723): 그런 다음에 어플라이를 누르시면
# (722-725): 되겠습니다
# (723-727): 됐어요
# (725-730): 그러면 끝이냐 일단은 훨씬 더
# (727-735): 깔끔하게 나왔어요 오 좋아요 하지만
# (730-736): 우리는 하나씩 잘랐을 거기 때문에
# (735-738): 여기에서
# (736-741): 스프라이트 모두 있죠 이거 지금
# (738-744): 싱글로 되어 있는데 요거를 멀티플로
# (741-746): 바꿔 주셔야 자를 수가 있다는 점
# (744-749): 참고하시길 바랍니다 자 스프라이트에
# (746-750): 들어갈게요 자 지금 어플라인이 안
# (749-752): 눌러서 지금 어플리뷰를 달라 그
# (750-752): 얘기고요
# (753-757): 자 보시면 저는 이미 이렇게
# (755-759): 잘렸는데요 아마 여러분들은 잘려있지
# (757-762): 않을 겁니다 지금 타입이죠 오토매틱
# (759-762): 돼 있죠 안 됩니다
# (763-766): 그리드 바이 셀 사이즈로 하겠습니다
# (765-768): 저는이
# (766-770): 캐릭터 하나의 크기를 어떻게
# (768-772): 잡았냐면요 18
# (770-773): y축은 2
# (772-775): 이렇게
# (773-779): 잡아 놓았던 사실 그리고 제가
# (775-781): 여러분들께 제공해 드릴 때는 꼭이
# (779-783): 칸칸마다 1픽셀씩
# (781-785): 여유 공간을 둡니다
# (783-787): 여유 공간 그거는 패딩이거든요
# (785-789): 패딩도
# (787-792): 이렇게 해서
# (789-794): 이 빨간색 네모칸이 잘 맞는지
# (792-797): 확인하시고 여기 맨 아래에다가
# (794-799): 슬라이스 하시면 되겠습니다
# (797-800): 됐나요
# (799-802): 근데 좀 더
# (800-804): 명확하게 이게 잘 될는지 안 짤렸는지
# (802-805): 구분을 하기 위해서는 여러분들이
# (804-807): 스프라이트 에디터에
# (805-809): 우측 위쪽 보시면 약간
# (807-812): RGB
# (809-813): 모양이 있습니다
# (812-817): 요거 눌러 보시면은 요렇게 나옵니다
# (813-820): 알파값만 보는 거거든요 자 지금
# (817-822): 발이 모두 지금 바닥에 잘 붙어 있는
# (820-825): 모습 확인되고 있습니까 좋습니다 저
# (822-826): 확인됐으면은 바로 옆에 있는 어플에
# (825-830): 붙은 눌러 주셔서 잘라 주시면
# (826-831): 되겠습니다 좋아요 아 여기에서 그
# (830-834): 각 이미지마다
# (831-837): 이름도 바꿀 수 있거든요 지금은 파머
# (834-838): 0 1 2 3 4 이렇게 나오죠
# (837-842): 근데 이걸 이렇게 하면은 나중에
# (838-844): 알아보기가 좀 어려우니까 보통 이런
# (842-846): 것들은 나중에 팀 작업을 위해서도
# (844-848): 이름을 바꿔주는게 좋습니다
# (846-850): 해서 요거는
# (848-850): 런에
# (857-861): 이런 식으로 이름 바꿔 주는게 훨씬
# (859-861): 더 좋아요
# (863-866): 그래서
# (867-868): 움직임
# (868-870): 애니메이션은 이렇게
# (870-875): 012345 이렇게 있고요 그리고
# (873-876): 가만히서 있을 때도 약간의 좀
# (875-878): 움직임이 있으면
# (876-881): 생동감 넘치겠죠
# (878-881): 그래서이 아래에 4개는 스탠드라고
# (881-883): 하겠습니다
# (881-885): 스탠드 0
# (883-888): 스탠드 1
# (885-888): 스탠드 2
# (888-891): 빠르지만
# (889-893): 천천히
# (891-895): 따라주시면 좋겠습니다 그 다음 묘비
# (893-897): 아 죽었을 때 자 죽었을 때는
# (895-898): 대드군요
# (897-899): 레드
# (898-902): 0
# (899-904): 이런
# (902-907): 식으로 이름을 바꿔 주시면 좋겠습니다
# (904-909): 되었으면 어플라이 꼭 눌러 주시고요
# (907-911): 자 다들께요 창
# (909-913): 닫겠습니다
# (911-918): 창을 닫으시고이 파머형에서 있잖아요
# (913-919): 보시면 여기 조그맣게 자 보이십니까
# (918-924): 화살표가 있습니다
# (919-925): 이 화살표 눌러 주셔야 우리가 자른
# (924-927): 스프라이트들을
# (925-931): 확인을 할 수가 있어요
# (927-931): 됐습니까 좋습니다 여기에서
# (932-934): 스탠드
# (933-935): 0을
# (934-936): 가지고 올게요
# (935-937): 쭉
# (936-941): 들어갑니다
# (937-941): 드래그 하셔서 여기에다가 딱 놔주세요
# (942-948): 지금 보시면은 스탠드 0 지금 하얗게
# (946-949): 창에 하나 추가되었습니다 그리고
# (948-951): 인스펙터 창에
# (949-953): 스탠드 0 있죠 자 이거는
# (951-955): 플레이니깐요 우리가 플레이어로 이름을
# (953-959): 바꿔줍시다 그 다음에 지금 포지션
# (955-959): 지금 0이었는데요
# (961-966): 트랜스폼은 게임 오브젝트의 기본적인
# (964-968): 속성들을 관리하는 그런 컴포넌트인데요
# (966-969): 자 위치와
# (968-971): 회전
# (969-973): 크기를 가지고 있습니다 이거는
# (971-976): 꼭 있고요
# (973-978): 이렇게 초기화 완료했나요 자 이렇게
# (976-980): 했는데 아이고 이게 세상에 이게 신청
# (978-983): 보시면은 자 이거 아이콘이 아이콘은
# (980-984): 지금 글로벌 라이트 2D 때문이에요
# (983-986): 끄면 사라지죠
# (984-988): 요거는 보통 우리가 신창에서
# (986-991): 어떤 컴포넌트들이 어느 위치에 위치해
# (988-993): 있는가라고 약간 좀 쉽게 표시를
# (991-996): 해주기 위해서 있는 3D 아이콘인데요
# (993-998): 너무 커요 그렇죠 너무 커 가지고
# (996-1000): 플레이어를 갈아버리네 자 이거는 게임
# (998-1001): 개발과 불편함을 줄 수 있기 때문에요
# (1000-1003): 요거
# (1001-1006): 크기 줄이기 하겠습니다 자 신창의
# (1003-1009): 위쪽 보시면은 우측 상단 자 이거
# (1006-1010): 화살표 아래 펼쳐 보시면은 요런
# (1009-1014): 수많은 옵션들이 있습니다
# (1010-1015): 그중에 맨 위에 3D 아이콘즈라는게
# (1014-1017): 있는데요 자 여기이 슬라이드 바
# (1015-1020): 보이시죠이 슬라이드바를 살짝
# (1017-1022): 줄여볼게요 오 좋아 좋아요
# (1020-1024): 어느 정도 줄이니까
# (1022-1027): 약간 좀 이제 개발할 때
# (1024-1027): 거치도 걸리지 않겠네요
# (1030-1035): 자 여기에서 끝입니다
# (1032-1037): 유니티는요 컴포넌트
# (1035-1040): 기반 게임 엔진입니다 그래서 우리가
# (1037-1042): 뭔가 하나의 개체를 만들 때는요
# (1040-1044): 역할에 맞는 컴포넌트를 우리가 계속
# (1042-1046): 레고를 붙이듯이 조립을 해 줘야 돼요
# (1044-1049): 그래서이
# (1046-1051): 플레이어도 그 우리가 물리로
# (1049-1053): 움직일 거거든요 그래서 여기에 좀 더
# (1051-1056): 몇 가지 컴포넌트를 추가를 해 주셔야
# (1053-1057): 되는데요 자 한번 가보도록 하죠 지금
# (1056-1059): 스프라이트 랜더러까지 있어요
# (1057-1061): 스프레이트 렌더런은 스프라이트를
# (1059-1066): 그리는 역할의 컴포트입니다
# (1061-1066): 애가 없으면은 안 그려져요 아래에도
# (1066-1070): 컴포넌트라고 있습니다 이거
# (1068-1073): 눌러주시고요 그럼 이렇게 컴포넌트의
# (1070-1075): 카테고리가 쭉 나오는데요 우리는 지금
# (1073-1077): 2D 공간이죠 그래서 피직스 2D
# (1075-1080): 선택을 해 주시고요
# (1077-1082): 그러면 여러가지 이제 물리 2d에
# (1080-1083): 대한 컴포넌트들이 이렇게 준비가 되어
# (1082-1085): 있습니다
# (1083-1088): 참 많이 듣네요 그쵸
# (1085-1089): 그중에 아래쪽에 리지드 바지
# (1088-1090): 특이했어요
# (1089-1092): 요거를 눌러줘서
# (1090-1093): 추가를 해주시면 되겠습니다 자
# (1092-1095): 리드보드 2d는
# (1093-1098): 뭔가 중력이라든가 아니면 충돌할 때
# (1095-1100): 속력이라든가 보통
# (1098-1103): 물리에 해당하는 모든 효과들을
# (1100-1105): 담당하는 그런 컴포넌트입니다 그리고
# (1103-1107): 무엇보다 지금 이대로 실행을 해버리면
# (1105-1110): 어떤 일이 발생하는가 자 중력을 받기
# (1107-1112): 때문에 떨어집니다
# (1110-1116): 자 우리는
# (1112-1116): 뱀사라이크입니다 상하좌우
# (1116-1120): 왔다 갔다 다 걸을 겁니다 그렇죠
# (1118-1121): 그렇기 때문에 중력을 받을 필요가
# (1120-1124): 전혀 없습니다
# (1121-1126): 해서 여기 보시면은 중간쯤에 자
# (1124-1128): 그래비티 스케일 자 중력 스케일 한게
# (1126-1131): 있어요 중력 중력이 지금 1로 돼
# (1128-1133): 있죠 이런 일인데 사실 중력은요 따로
# (1131-1135): 값이 있습니다 어딨냐고 하면은
# (1133-1138): 에디트에
# (1135-1140): 프로젝트 세팅을 한번 가보겠습니다
# (1138-1143): 그러면은 여기에
# (1140-1145): 피직스 2d가 있는데요 여기에
# (1143-1148): 그래비티 아 지금 중력이 어느
# (1145-1151): 방향으로 어느 크기만큼 줄 거냐라고
# (1148-1154): 지금 나와 있는데 지금 y축이
# (1151-1156): 마이너스 9.81 정확한 건 아니지만
# (1154-1157): 대략적으로
# (1156-1159): 원래
# (1157-1161): 지구 중력에 해당하는 그런 힘을
# (1159-1163): 이렇게
# (1161-1164): 표시를 해주고 있네요
# (1163-1167): 그렇죠
# (1164-1170): 그거를 그대로 1만큼 받겠다 곱하기
# (1167-1171): 1이죠 그만큼 받겠다는 얘기입니다
# (1170-1175): 근데 우리 주님 받기 싫잖아요 그래서
# (1171-1178): 그걸 영어로 줄게요
# (1175-1179): 이렇게 해주시면 되겠습니다
# (1178-1181): 자 그리고 아래 또
# (1179-1183): 애드 컴포넌트에서 더
# (1181-1185): 추가를 해보도록 하겠습니다 자
# (1183-1187): 컴포넌트는 여기
# (1185-1189): 좌측에 화살표 눌러주시면 이렇게 접을
# (1187-1191): 수 있어요
# (1189-1194): 접은 다음에 다시 한번 자 비즈 2D
# (1191-1196): 들어가시고네
# (1194-1198): 번째가 캡슐 콜라이드 2d입니다 자
# (1196-1199): 콜라이더가 뭐냐면은
# (1198-1200): 충돌
# (1199-1201): 면을 말하는 거예요
# (1200-1202): 충돌면
# (1202-1207): 리지드 바디는 이제 뭐 물리적인 속도
# (1204-1209): 하고 중력하고 이런 건 책임지는데
# (1207-1210): 충돌 면은 따로이 콜라이더가
# (1209-1212): 책임집니다 그래서
# (1210-1214): 요거 추가 주셔야 되고요
# (1212-1215): 그러면 이런 식으로
# (1214-1218): 연두색
# (1215-1219): 줄이 쭉 볼 거예요 그쵸 여기가 바로
# (1218-1221): 충돌 면입니다
# (1219-1223): 근데 보시면 알겠지만이 총들면이
# (1221-1227): 뭔가이 플레이어랑 안 맞는 것 같아요
# (1223-1228): 그쵸 그래서 사이즈 보시면은 일단 S
# (1227-1229): 축을 먼저
# (1228-1232): 0.7로 할게요
# (1229-1234): 0.6입니다네 이건 뭐 이런게 원하실
# (1232-1237): 때로 바꾸시면 되고요
# (1234-1237): y축도 한 0.9
# (1238-1242): 맞출 필요 없는데요 여러분께서 아이
# (1241-1245): 정도면 되겠네 10불 정도의 크기로
# (1242-1247): 맞춰주시면 될 것 같아요 자이 크기가
# (1245-1250): 크면 클수록
# (1247-1252): 플레이어가 적들한테 훨씬 더 많이
# (1250-1255): 맞겠죠 그건 피격 보며 크니까
# (1252-1257): 그렇죠 이게 작으면 작을수록
# (1255-1260): 피격 범위가 작아진다는 사실 그래서
# (1257-1261): 뭐 이건 여러분들 게임 스타일대로
# (1260-1264): 크기 설정해 주시면 되겠습니다
# (1261-1267): 되었나요 자 이렇게 하시고 한번
# (1264-1269): 실행을 해보시면은
# (1267-1273): 대략 요런 모습이 됩니다 아 물론
# (1269-1274): 지금 여러분들은 키보드를 뭐 아무리
# (1273-1275): 눌러봐도
# (1274-1278): 움직이지 않습니다
# (1275-1280): 그렇죠 당연히 움직이는 로직
# (1278-1283): 스크립트가 없기 때문입니다 자 지금은
# (1280-1286): 우리는 위치 트랜스포머고 그리고 자
# (1283-1287): 이미지를 그려주는 스프레드 렌더러
# (1286-1289): 물리를 체인지는
# (1287-1291): 리드보드 2D 하고
# (1289-1293): 충돌 면을 책임지는 캡슐 콜라 2D
# (1291-1295): 4개만 넣었다는 점
# (1293-1297): 참고하시고요
# (1295-1299): 자 이렇게만 되면
# (1297-1301): 조금 그러니까 그림자
# (1299-1304): 약간 지도로 하겠습니다 사실 그림들도
# (1301-1305): 제가 미리 준비해 놨습니다 자
# (1304-1308): 프롭스라는
# (1305-1310): 프로젝트를 열어 보시면은 어 열리네요
# (1308-1312): 자 제가 플레이어
# (1310-1315): 0 빼고는 다 제가 미리 나눴습니다
# (1312-1317): 여러분들 귀찮지 않게 안 하고
# (1315-1319): 쭉 내려가시면 여기 쉐도우가 있어요
# (1317-1320): 이거 쉐도우도
# (1319-1323): 쭉 끌어다가 놓으면 되는데 자
# (1320-1324): 여기다가 아닙니다 어디에다가 여기
# (1323-1325): 하얗게 창에
# (1324-1328): 플레이어에다가 마우스 갖다 대보세요
# (1325-1332): 어 그러면
# (1328-1335): 이렇게 집어 넣을 수가 있어요 자
# (1332-1338): 이걸 우리는 부모와 자식 관계라고
# (1335-1339): 합니다 자 플레이어는 부모 오브젝트를
# (1338-1341): 뜻한 거고요
# (1339-1344): 요거 영역할게요
# (1341-1346): 자 아래 쉐도우 한 칸 약간 조금
# (1344-1348): 지금 들여쓰게 되었죠 이건 이제
# (1346-1350): 45m예요 그리고
# (1348-1351): 접을 수도 있죠
# (1350-1354): 섀도우는
# (1351-1356): 지금이 플레이어 자식으로 등용되어
# (1354-1358): 있다는 의미이구요
# (1356-1361): 포지션도 영령으로 아주 주고요 특히
# (1358-1363): 지금 y축 너무 위에 있죠 약간 발
# (1361-1365): 아래에 들어와 있습니다 마이너스
# (1363-1367): 0.45로 할게요네 제가 이것저것
# (1365-1369): 한번 테스트 해봤는데 마르스
# (1367-1370): 0.45가 제일 이쁘더라구요 하지만
# (1369-1373): 섀도우가 지금
# (1370-1375): 발 가리고 있죠 안 됩니다 지금
# (1373-1377): 보시면이 쉐도우의 스프라이트 렌더러
# (1375-1380): 열어 보시면은
# (1377-1381): 에디션을 세팅 오더인 레이어가
# (1380-1382): 0입니다
# (1381-1384): 애들 0
# (1382-1386): 플레이도 0입니다
# (1384-1389): 숫자가 같으면은 누가 먼저 그려질지
# (1386-1391): 그냥 랜덤하게 표시가 돼요
# (1389-1393): 그래서이 우선적으로 그리는 것을
# (1391-1395): 숫자에 높게 주시면 됩니다
# (1393-1399): 플레이어가 먼저 튀어나야겠죠 1
# (1395-1401): 누가이 스프레드를 내리고 올리느냐
# (1399-1403): 그렇게 맞춰주시면 되겠습니다 자
# (1401-1406): 쉐도우를 영어로 하고요 자 플레이어는
# (1403-1408): 나중에 또 그 다른 것도 하기 위해서
# (1406-1411): 이거를 제가
# (1408-1411): 5로 올리겠습니다 나중에 또 팔도
# (1411-1413): 붙이고
# (1411-1416): 그렇게 할 거니까요
# (1413-1417): 자 여기까지 확인되었습니까 그냥 게임
# (1416-1419): 창에는
# (1417-1421): 요렇게 보일 것이에요
# (1419-1424): 근데 보시면 여기 지금 파란색 배경
# (1421-1428): 화면이잖아요 이건 왜 그러죠 이거는
# (1424-1430): 카메라입니다 카메라에 보시면
# (1428-1431): mvirement 하면서 지금
# (1430-1432): 백그라운드가
# (1431-1434): 파란색 되어 있죠
# (1432-1436): 요거는 뭐 여러분대로
# (1434-1439): 색깔을 바꿔 주시면 되겠습니다 저는
# (1436-1442): 살짝 회색 뭐 한요 정도로 하겠습니다
# (1439-1442): 이렇게 하겠습니다
# (1443-1446): 해서 플레이 시키면은 뭐 그렇게 뭐
# (1445-1449): 그다지
# (1446-1451): 큰 채널이지만 이렇게 보일 거예요 자
# (1449-1453): 요렇게 해서 간단하게
# (1451-1454): 플레이어 오브젝트를 한번 만들어
# (1453-1457): 봤구요
# (1454-1461): 자 꽤나 괜찮은 모습이 나왔죠 그래서
# (1457-1464): 자이 다음 시간에는이 플레이어를 직접
# (1461-1465): 우리가 스크립트 로직을 작성을 해서
# (1464-1466): 움직여 보고
# (1465-1469): 애니메이션도
# (1466-1471): 넣어보는 시간 가져볼 겁니다 자
# (1469-1473): 그리고 첫 번째 시간 여기서
# (1471-1475): 마무리하도록 하지요
# (1473-1475): 감사합니다
#     - Whisper 자막: (0-11):  자 여러분들 반갑습니다 골드메탈입니다
# (11-15):  이번엔 뱀스라이크 언더티 서바이버 개발의 첫 번째 시간으로서
# (15-24):  유니티를 한번 설치해 보고 프리에이트 시작과 그 다음에 플레이어를 간단하게 만들어 보는 방법에 대해서 같이 한번 진행 좀 해보도록 하겠습니다.
# (24-31):  그래서 여러분들 네이버나 아니면 구글에다가 유니티 검색하셔서 이렇게 공식 홈페이지에 들어오시면 되는데요.
# (31-34):  unity.com.kr 입니다.
# (34-37):  보시면 여기 유니티 다운로드 버튼 있어요
# (37-43):  자 들어가시구요 그러면 여기 또 윈도우 용 따온 되겠습니다
# (43-49):  아 물론 또 이제 ios 1 땀 로드 아래에서 할 수 있을까요 확인을 하시면 좋겠습니다
# (49-53):  그래서 버튼 눌러서 자다 5 다시구요
# (54-57):  그러면 유니티 에디터 설치파일이 나오는게 아니고
# (57-59):  유니티 허브 설치파일이 나옵니다
# (59-61):  자 요거 누르셔서
# (61-64):  유니티 허브부터 설치를 하시는게 좋겠습니다
# (64-67):  그래서 설치 동의함 눌러주시구요
# (67-69):  자 한가지 제가 추천드리는 사항은요
# (69-83):  유니티 허브나 아니면 다른거 설치하하실 때 보통은 주 드라이버 내에다가 바로 여러분들이 따로 유니티 허브 폴드를 만드시고 거기에 설치하시는 것을 추천드립니다.
# (83-86):  그래야 유니티 파일들을 관리하기가 상당히 쉽거든요.
# (87-93):  그래서 이런 식으로 깔끔하게 정리해서 설치를 하시는 것을 추천드립니다.
# (94-96):  그래서 설치를 완료했으면요.
# (96-98):  이렇게 유니티 허브가 나올 겁니다.
# (99-101):  지금 버전은 유니티 허브 3.3 버전이네요.
# (102-105):  가장 첫 번째 해야 할 것은 바로 로그인입니다. 여러분이 당연히 유니티 쓰시면 유니티 허브 3.3 버전이네요. 가장 첫번째 해야할 것은 바로 로그인 입니다.
# (105-114):  여러분이 유니티 쓰시면 유니티 개인계정 로그인 계정이 필요하구요. 그거를 여기에서 로그인 해주셔야 됩니다.
# (114-120):  그렇게 되면은 여러분들 라이센스를 다 가지게 되는데요. 개인 라이센스 있는거 확인하시고
# (120-122):  자 지금 여기가 유니티 허브잖아요.
# (122-124):  우리가 보통 말하고 있는 유니티는
# (124-125):  유니티 에디터입니다.
# (125-128):  그래서 에디터는 여기 설치 탭에 보시면
# (128-130):  이렇게 설치를 할 수 있어요.
# (130-132):  저는 이미 2022.2 버전
# (132-134):  그리고 2021 버전
# (134-136):  같이 설치가 되어 있습니다.
# (136-141):  그런데 이 에디터도 허브와 마찬가지로 여러분들 어 드라이버
# (141-145):  바로 다음에 설치하는 편이 정말 좋거든요
# (145-150):  그래서 자 여기 톱니바퀴 확률 설정 눌러 보시면 은 프로젝트가
# (150-158):  있습니다 그래서 프로젝트 위치를 미리 사전에 지정을 할 수 있는데요 저는 이렇게 c 드라이브 바로 아래에다가
# (158-167):  유니티 프로젝트 라는 폴더를 새로 만들어서 딱 지정을 해놨습니다 자 이렇게 해두면은 나중에 여러분께서 플랫폼 빌드할 때 이 한글 폴드에
# (167-170):  의해서 문제가 발생하지가 않아요.
# (171-171):  괜찮죠?
# (172-173):  그래서 미리 이렇게 하는 걸 추천드리고요.
# (174-177):  마찬가지로 설치 탭에 가시면 에디터, 그리고 컨텐츠
# (177-179):  이런 식으로도 깔끔하게 제가 정리했으니까요.
# (180-182):  이런 식으로 바로 드라이버 아래에
# (182-184):  두는 것을 적극 추천드립니다.
# (186-187):  이렇게 하면
# (187-188):  제 C드라이버 한번 보여드릴게요. 깔끔하죠? 유니드 컨텐츠 두는 것을 적극 추천 드립니다 자 이렇게 하면은
# (188-190):  자 제 CD Driver 한번 보여드릴게요
# (190-191):  와 깔끔하죠?
# (191-196):  유닛 콘텐츠, 에디터, 허브, 프레디트
# (196-200):  한꺼번에 다 볼 수 있다는 점 참고하시구요
# (200-201):  그럼 이제 에디터를 설치할 거 아닙니까?
# (201-203):  저는 이미 에디터 설치되어 있지만은
# (203-205):  여러분들은 아마 지금 없을 거예요 그래서 에디터를 설치할 거 아닙니까? 저는 이미 에디터 설치되어 있지만 여러분들은 아마 지금 없을 거예요
# (205-208):  그래서 에디터를 설치 버튼을 눌러주시고
# (208-209):  자, 이번 뱀스라이크
# (209-213):  언데드 서버 앨범은 2021.3 LTS 버전으로 진행합니다
# (213-218):  해서 이거 맨 위에 거 설치를 진행해 주시면 되고요
# (218-220):  아, 근데 설치하실 때 주의할 점
# (220-225):  자, 일단 저는 설치가 이미 되었기 때문에 아래꺼 눌러오면서 예시를 한번 들어보겠습니다
# (225-235):  아마 처음 설치 하실 분들은 그 코드 스크립트 코드를 이렇게 에디터 해주는 마이크로소프트 비주얼 스튜디오 같이 필요합니다 그래서 여기 아마
# (235-238):  체크 되어있을 거에요 네 저도 체크 되어있죠
# (238-245):  그리고 나중에 거의 마지막 부분에는 이 안드로이드 빌드와 같이 할 거기 때문에 꼭
# (245-250):  여러분들 플랫폼 안드로이드 빌드 서포트에 체크해 주시면 좋겠습니다
# (250-255):  오픈 JDK 안드로이드 SDK와 ND NDK까지 이 세 개 꼭 같이 체크하시고
# (255-258):  계속 눌러주셔서 설치를 해주시면 좋겠습니다
# (258-261):  이렇게 모듈 설치 완료됐고요
# (261-263):  만약에 이미 설치된 모듈이 있다
# (263-266):  근데 안드로이드만 설치가 안 되어 있어요
# (266-268):  라고 할 때는 어떻게 해야 되냐
# (268-270):  그럼 여기 토니마켓 모양 눌러주시고요
# (270-273):  모듈 추가 해주신 다음에
# (273-282):  플랫폼에서 여기 안드로이드 체크 하시고 계속하시면 모듈만 따로 설치가 된다는 점 확인해 주겠습니다
# (282-291):  되셨나요? 자 그러면 이제 프로젝트 만들어 볼게요 프로젝임트 택 가지고 새 프로젝트 가시면 되겠습니다
# (291-299):  맨 위에 2d 가 있긴 있어요 자 근데 요즘은 또 이제 유니티가 그 ui 피에 대해서 퍼포먼스 라든가 그래픽 이라든가
# (299-306):  이러한 많은 기능들을 계속 꾸준히 업데이트하기 때문에 요즘은 URP로 진행하는 것도 참 좋아요
# (306-308):  그래서 우리는요
# (308-311):  2D URP로 한번 진행을 해보도록 하겠습니다
# (311-314):  자, 에디터 버전 확인하시고요
# (314-316):  2021.3.13 LTS 맞네
# (316-317):  그래
# (317-320):  자, 그래서 제 플레이트 이름은
# (320-326):  Undead Survivor 좋군요 이렇게 이름을 짓도록 하겠습니다
# (326-335):  자 위치 꼭 확인해주시구요 자 한글 폴더가 없어야 됩니다 되었으면은 프로젝트 생성 자 누르면서
# (335-338):  이제 프레트를 만들어 보도록 하겠습니다
# (339-343):  2021 버전은 이렇게 그림이 뜨면서
# (343-346):  오픈 플레이트 생성을 하고 있을 텐데요
# (346-350):  이거는 여러분들 컴퓨터 환경에 따라서 속도가 다르다는 점
# (350-355):  참고하시면서 느긋하게 한번 기다려 보도록 하겠습니다
# (360-363):  그래서 이렇게 프로젝트 생성이 완료되었으면
# (363-365):  에디터 창이 나올 것인데요
# (365-369):  위쪽에 보시면 프로젝트 이름, 장면 이름, 플랫폼
# (369-372):  그리고 유니티즈 에디터 버전과
# (372-381):  그리고 라이센스 다이렉트 버전 몇인지 이렇게 쭉 나올 것입니다 그 아래쪽에는 이렇게 메뉴 있을 거에요 쭉 메뉴가 됐구요
# (381-389):  그리고 6가지의 주요 인터페이스 창이 있는데 지금 이러한 사항들은 따로 제가 설명드리지는 않을게요
# (389-393):  혹시나 지금 아예 유니티를 처음 키신 분은
# (393-398):  제 입문 강좌 영상을 한번 보시면 좀 더 이해하기 쉬울 거니까요
# (398-399):  그쪽을 참고하시면 좋을 것 같습니다
# (399-403):  이번에 뱀스라이크, 언데드 서바이버 강좌는요
# (403-406):  조금 빠르게 진행한다는 점 참고해주시고요
# (406-408):  자 그러면 보통 저런 강좌일 때는요
# (408-410):  요거 제가 숨겨두거든요?
# (410-412):  자 이렇게 한번 숨겨보겠습니다
# (412-413):  깔끔하죠?
# (413-415):  그렇다면 이제 본격적으로 한번
# (415-418):  언데드 서바이버 개발에 착수해보도록 하겠습니다
# (420-425):  자 그럼 이제 뱀파이어 서바이버를 개발하기 위해서�이 필요하죠 뭐 그래피라든가 사운드라든가 애니메이션이라던가
# (426-429):  그래서 제가 또 이번에 여러분들을 위해서 에셋을 준비했는데요
# (430-437):  자 여러분들 네이버나 구글에 골드메탈을 검색하시면은 제 골드메탈 스튜디오 브랜드 페이지가 이렇게 보일겁니다
# (438-442):  그래요 여기 들어가시면은 자 이런식으로 홈페이지가 나오게 되는데요
# (442-448):  쭉 내려가셔야 되고 아니면 여기 lecture 쭉 내려가시면은
# (448-452):  여러분들에게 제공해 드리고 있는 에셋이 이렇게 있습니다
# (452-457):  그중에 언데드 서바이버 에셋이 있어요. 여기 들어가시고
# (457-464):  언데드 서바이버 포일이 되어있네요. 다운로드 버튼 눌러주시고 받아보시면 되겠습니다.
# (464-471):  받았으면요. 이렇게 zip 파일이 나오는데 일단 요거 압축을 해제를 해주세요
# (474-476):  해제가 되었으면은 이런식으로
# (476-478):  언데드 서바이버
# (478-480):  유니티 패키지가 나올겁니다
# (480-482):  자 이거를 넣어주셔야 돼요
# (482-485):  어디에다가? 바로 이 유니티 에디터에다가
# (485-487):  넣어주셔야 됩니다
# (487-487):  넣는 방법은 이거를 그냥 더블클릭 하셔도 되구요 아니면은 이걸 드래그 하셔도 바로 이 유니티 에디터에다가 넣어 주셔야 됩니다
# (487-496):  넣는 방법은 이거를 그냥 더블클릭 하셔도 되구요 아니면은 이걸 드래그 하셔서 여기 프로젝트 창 아래에다가 드랍을 해 주시면 되겠습니다
# (496-500):  자 전 드래그 드랍 할게요
# (500-504):  드래그 드랍을 하시게 되면은 이렇게 임포트 유니티 패키지 넣으면서
# (504-510):  이렇게 여러가지 내용물들이 나오게 되는데 그냥 임포트 해주시면 되겠습니다
# (510-517):  보시면 이 asset 이라고 하는 폴더 아래에 보시면 언데드 서바이버 라고 있습니다
# (517-523):  그쵸 이렇게 압축이 풀리면서 여러가지 에셋들이 포함이 되어 있고요.
# (525-528):  그리고 라이센스에 대해서 궁금하신 분들이 계실 거예요.
# (528-536):  여기에 대해서는 제가 리드미, 코리아 열어보시게 되면 이렇게 제가 문서를 제공해 드리고 있습니다.
# (538-542):  그렇죠? 그래서 강좌 외에도 개인 학습용, 과제용,
# (542-548):  아니면 여러분께서 직접 만든 개인 상용 플랫까지 자유롭게 사용이 가능하니까
# (548-552):  이 점 참고하시면 좋겠습니다. 마음껏 사용해주세요
# (552-556):  여러분께서 개조하셔도 상관없습니다
# (556-558):  그러면
# (558-560):  여기에서 한번
# (560-562):  애셋을 사용해서 플레이어를 만들어 보겠죠?
# (564-566):  플레이어를 한번 만들어 볼건데요
# (566-568):  그 전에 지금 이 창을
# (568-570):  편리하게 쓰도록
# (570-571):  커스터마이질이즈 해볼건데요
# (571-573):  요 창에 이름 있죠?
# (573-578):  이름 탭을 꾹 누르시면은 이렇게 자유롭게 이동할 수 있는데요
# (578-581):  이번엔 이런식으로 한번
# (581-587):  자 제가 창을 한번 이렇게 변경을 해보도록 하겠습니다
# (590-592):  그래서 어쨌든 나중에 여러분 이제 모바일로 할거기 때문에요
# (592-594):  요런 느낌으로
# (594-596):  한번 세팅을 해보시면
# (596-597):  어떨까 합니다
# (597-599):  플레이를 놓으려면 이미지가 필요하죠
# (599-602):  게임 개발에서는 보통
# (602-609):  이미지를 스프라이트 살펴보렵니다 스프라이트 폴더 들어가시면 다양한 스프라이트들이 이렇게 쭉 있는데요.
# (609-613):  보통 이제 우리가 게임을 개발할 때 아트 직군이 따로 있다 하시면
# (613-620):  그 아트분들께서 도트나 아니면 2D 만드실 때는 보통 이런 식으로 묶어서 주는 경우가 있어요.
# (620-625):  이런 것들을 우리는 아틀라스 혹은 스프라이트 시트를 버립니다
# (625-628):  근데 이걸 잘라야 하잖아요
# (628-633):  이거를 그대로 통째로 갖다 쓰기에는 조금 무리가 있습니다
# (633-635):  아 좀 그래요 그렇죠
# (635-640):  그래서 이걸 잘라 써야 되는데 잘라을 방법에 대해서 먼저 설명 좀 해드리겠습니다
# (640-649):  자 파머 영이 이게 플레이어 첫번째 건데요 요거 선택하시고 여기 인스팩터 참 보시면은 여러가지 설정이 있습니다
# (649-656):  자 좀 많죠 우리는 3가지만 보시면 될 것 같습니다 일단 픽셀퍼 유닛 지금 100으로 됐죠
# (656-661):  이 100이라는 의미는 지금 보시면 이 씬에 한 칸 이렇게 보이잖아요 모눈중이 보이십니까
# (661-671):  이 한 칸에 픽셀 몇 개가 들어가느냐 그 얘기입니다 즉 100이면 이 한 칸에 무려 100개가 들어간다는 얘기죠
# (671-674):  근데 뭐 100x100이면 만개가 들어간다는 얘기고
# (674-679):  그래서요 저는요 지금 이 캐릭터 하나의 크기가 18이거든요
# (679-682):  그래서 이걸 18로 바꿔줍니다
# (682-684):  되었습니까?
# (685-689):  자 그 다음에 아래쪽에 보시면 필터 모드 있죠
# (689-696):  자 이거 지금 어 빌린으로 되어 있는데요 요거를 이제 포인트로 바꿔 주시구요 깔끔하게 필터를 쓰지 않겠다
# (696-704):  원래 모습으로 보지겠다 그 얘기고요 그리고 아래쪽 보시면 컴프레션 색상을 아까 앞축하는 방식이 있어요
# (704-706):  근데 지금 우리는 도트
# (706-707):  이미지죠
# (707-709):  색깔 자체가 별로 없기 때문에
# (709-710):  굳이 압축을 할 필요도 없습니다
# (710-713):  압축을 하면 오히려 색상이 깨지기 때문에
# (713-715):  우리가 원하는 색상이 안나와요
# (715-716):  그래서 요거를 논으로
# (716-718):  바꿔주시면 되겠습니다
# (718-719):  자 이렇게 3개 되었죠
# (719-722):  그런 다음에 apply를 눌러주시면 되겠습니다. 자 이렇게 3개 되었죠? 그런다음에 apply를 눌러주시면 되겠습니다.
# (722-724):  됐어요.
# (724-726):  그러면 끝이냐?
# (726-728):  일단은 훨씬 더 깔끔하게 나왔어요.
# (728-730):  오 좋아요.
# (730-732):  하지만 우리는 하나씩 잘랐을거기 때문에
# (734-736):  여기에서
# (736-739):  스프라이트 모드있죠? 이거 지금 싱글로 되어있는데
# (739-741):  이거를 멀티플로 바꿔주셔야
# (741-743):  자를 수가 있다는 점
# (743-745):  참고하시길 바랍니다
# (745-747):  자 스프라이트에 들어갈게요
# (747-749):  자 지금 어플라이 안 눌러서
# (749-751):  어플리 누르달라 그 얘기고요
# (751-753):  어플리 누르면 이렇게 나옵니다
# (753-755):  음흠 그렇구나 자 보시면 저는 이미 이렇게 짤렸는데요.
# (755-757):  아마 지금 여러분들은 짤려있지 않을 겁니다.
# (757-759):  어, 지금 타입이 오토배틱 돼있죠?
# (759-760):  안 됩니다.
# (760-762):  오토배틱 하시면 안 되고요.
# (763-765):  자, 그리드 바이 셀 사이즈로 하겠습니다.
# (765-768):  저는 이 캐릭터 하나의 크기를 어떻게 잡았냐면요.
# (768-771):  열, 여덟 18 Y축은 20
# (771-774):  이렇게 잡아놨던 사실
# (774-776):  그리고 제가 여러분들께
# (776-777):  제공해드릴 때는 꼭
# (777-779):  칸칸마다
# (779-782):  1픽셀씩 여유공간을 둡니다
# (782-784):  여유공간? 그거는 패딩이거든요
# (784-786):  패딩도 S축 1
# (786-787):  Y축 1
# (787-788):  이렇게 해서
# (788-792):  이 빨간색 네모칸이 잘 맞는지 확인하시고
# (792-796):  여기 맨 아래에다가 슬라이스 하시면 되겠습니다
# (796-797):  되었나요?
# (798-803):  좀 더 명확하게 이게 잘 잘렸는지 안 잘렸는지 구분을 하기 위해서는
# (803-805):  여러분들 이 스프라이트 에디터에
# (805-808):  우측 위쪽 보시면 약간 RGB
# (808-811):  빨간색, 녹색, 파란색 약간 TV 모양이 있습니다
# (811-813):  이거 눌러보시면 이렇게 나옵니다
# (813-815):  알파 값만 보는 거거든요
# (815-820):  자 지금 발이 모두 지금 바닥에 잘 붙어있는 모습
# (820-821):  확인되고 있습니까?
# (821-827):  좋습니다. 확인됐으면 발 옆에 있는 Apply 버튼 눌러주셔서 잘라 주시면 되겠습니다.
# (827-835):  좋아요. 여기에서 각 이미지마다 이름도 바꿀 수 있거든요. 지금은 Farmer 0, 1, 2, 3, 4
# (835-841):  이렇게 나오죠? 근데 이걸 이렇게 하면 나중에 알아보기 가 좀 어려우니까
# (841-846):  보통 이런 것들은 나중에 팀 작업을 위해서도 이름을 바꿔주는 게 좋습니다
# (846-854):  해서 요거는 뭐 이건 런의 0번째 요거는 런의 첫번째 요거는 런의 두번째 요거는 런의 세� 번째 이거는 런의
# (854-855):  두 번째
# (855-857):  이거는 런의
# (857-857):  세 번째
# (857-859):  이런 식으로 이름 바꿔주는 게
# (859-859):  훨씬 더 좋아요
# (859-864):  자 네 번째
# (864-865):  다섯 번째
# (865-867):  그래서 움직임
# (867-868):  자 애니메이션은
# (868-869):  이렇게 1
# (869-869):  아 0
# (869-870):  1 2
# (870-872):  3 4 5 이렇게 있구요
# (872-877):  그리고 가만히 서 있을 때도 약간의 움직임이 있으면 생동감 넘치겠죠
# (877-881):  그래서 이 아래 4개는 스탠드라고 하겠습니다
# (881-892):  스탠드 0, 스탠드 1, 스탠드 2, 스탠드 4 저는 지금 빠르지만 천천히 따라해주시면 좋겠습니다
# (892-896):  그 다음 묘비 죽었을 때 죽었을 때는 데드군요
# (896-904):  데드 0 데드 1 이런식으로 이름을 바꿔주시면 좋겠습니다
# (904-907):  되었으면은 어플라이 꼭 눌러주시구요
# (907-909):  자 이제 닫을게요 창
# (909-910):  닫겠습니다
# (910-912):  창을 닫으시고
# (912-914):  이 파머영에서 있잖아요
# (914-916):  보시면 여기 조그맣게
# (916-917):  자 보이십니까?
# (917-919):  화살표가 있습니다
# (919-922):  자 이 화살표 눌러주셔야 우리가 자른
# (922-924):  스프라이트들을
# (924-926):  확인할 수 있어요.
# (926-928):  되었습니까?
# (928-930):  좋습니다.
# (930-932):  자른거 확인되었으면
# (932-934):  스탠드 0을 가지고 올게요.
# (934-936):  쭉 드래그합니다.
# (936-941):  드래그 하셔서 여기에다가 딱 놔주세요. 드래그 하셔서 여기에다가 딱 놔주세요
# (942-951):  자 지금 보시면은 스탠드 0 지금 하이로켓 창에 하나 추가 되었습니다 그리고 인스팩터 창에 스탠드 0 있죠
# (951-954):  자 요거는 플레이어니깐요 우리가 플레이어로 이름을 바꿔줍시다
# (954-956):  그 다음에 지금 포지션
# (956-957):  지금 0이 아닌데요
# (957-961):  제가 정확히 00으로 맞춰주겠습니다
# (961-964):  트랜스폼은 게임 오브젝트의 기본적인 속성들을
# (964-966):  관리하는 그런 컴포넌트인데요
# (966-970):  위치와 회전, 크기를 가지고 있습니다
# (970-975):  이거는 꼭 있고요 이렇게 초기기화 원래 했나요
# (975-979):  자 이렇게 했는데 어이구 이게 세상에 이게 신창 보시면은
# (979-982):  자 이거 아이콘 이 아이콘은 지금 글로벌 라이트 2d 때문이에요
# (982-986):  자 끄면 사라지죠 요거는 보통 우리 신창에서 어떤
# (986-993):  컴포넌트들이 어느 위치에 위치했는가 라고 약간 좀 쉽게 표시를 해주기 위해서 있는 3D 아이콘인데요.
# (993-1000):  지금 너무 커요 그쵸? 너무 커가지고 플레이어를 가려버리네. 자 이건 게임 개발에 약간 불편함을 줄 수 있기 때문에요.
# (1000-1006):  요거 크기 줄이기 하겠습니다. 자 신창에 위쪽 보시면은 우측 상단
# (1006-1016):  자 이거 화살표 아래 펼쳐 보시면은 요런 수많은 옵션들이 있습니다 그중에 맨 위에 3d 아이콘즈 란 게 인데요 자 여기 슬라이드 바 보이시죠
# (1016-1026):  이 슬라이드 바를 살짝 줄여 볼게요 오 좋아 좋아요 어느 정도 줄이니까 뭐 약간 좀 이제 개발할 때 어 그 거치도 걸리지 않겠네요 그죠
# (1026-1030):  자 이 정도를 줄이시고 가주시면 되겠습니다
# (1030-1039):  자 여기에서 끝이 아닙니다 유니티는요 컴포넌트 기반 게임 엔진입니다 그래서 우리가 뭔가 하나의 개체를 만들 때는요 역할에 맞는 컴포넌트 기반 게임 엔진 입니다. 그래서 우리가 뭔가 하나의 개체를 만들 때는요
# (1039-1045):  역할에 맞는 컴포넌트를 우리가 계속 레고를 붙이듯이 조립을 해 줘야 돼요.
# (1045-1050):  그래서 플레이어도 우리가 물리로 움직일 거거든요.
# (1050-1054):  그래서 여기에 좀 더 몇 가지 컴포넌트를 추가를 해 주셔야 되는데요
# (1054-1056):  자 한번 가보도록 하죠
# (1056-1057):  지금 스프레이트 렌더러까지 있어요
# (1057-1061):  스프레이트 렌더러는 스프레이트를 그리는 역할의 컴포넌트입니다
# (1061-1063):  애가 없으면 안 그려져요
# (1063-1065):  얘는 꼭 있어야 되고요
# (1065-1067):  아래에 add component라고 있습니다
# (1067-1068):  이거 눌러 주시고요
# (1068-1073):  그럼 이렇게 컴포넌트의 카테고리가 쭉 나오는데요 우리는 지금
# (1073-1083):  2d 공간이 줘 그래서 피닉스 2d 선택을 해 주시구요 그러면 여러가지 저 물리 2d 에 대한 컴포넌트 리 이렇게 준비가 되었습니다
# (1083-1088):  참 많이 있네요 그쵸 4 자 그중에 아래쪽에 리지드 버지 2D가 있어요
# (1088-1091):  요거를 눌러주셔서 추가를 해주시면 되겠습니다
# (1091-1092):  자 리지드 버지 2D는
# (1092-1094):  뭔가 중력이라던가
# (1094-1096):  아니면 충돌할 때 속력이라던가
# (1096-1100):  보통 물리에 해당하는 모든 효과들을 담당하는
# (1101-1102):  그런 컴포넌트입니다
# (1102-1106):  그리고 무엇보다 지금 이대로 실행을 해버리면은 어떤 일이 발생하는가
# (1106-1117):  자 중력을 받기 때문에 떨어집니다 어이구 떨어졌죠 자 우리는 벤스라이크 입니다 상 하 좌 우 왔다가다 다
# (1117-1121):  그럴겁니다 그쵸 그렇기 때문에 중력을 받을 필요가 전혀 없습니다.
# (1123-1124):  해서 여기 보시면 중간쯤에 자, 그래비티 스케일
# (1124-1125):  자, 중력 스케일이라는 게 있어요.
# (1126-1126):  중력
# (1126-1128):  중력이 지금 1로 되어 있죠?
# (1128-1130):  1은 1인데 사실 중력은요.
# (1130-1131):  따로 값이 있습니다.
# (1132-1132):  어디 있냐고 하면
# (1132-1134):  자, 에디트에
# (1134-1136):  프로젝트 세팅을 한번 가보겠습니다.
# (1138-1140):  그러면은 여기에
# (1140-1142):  피직스 2D가 있는데요
# (1142-1143):  여기에
# (1143-1144):  그래비티
# (1144-1146):  아 지금 중력이 어느 방향으로
# (1146-1149):  어느 크기만큼 줄거냐 라고
# (1149-1150):  지금 나와있는데
# (1150-1151):  지금 Y축이
# (1151-1153):  마이너스 9.81
# (1153-1155):  정확한건 아니지만은 대략적으로
# (1155-1158):  원래 지구중력
# (1158-1159):  에 해당하는 그런 힘을
# (1159-1162):  이렇게 표시를 해주고 있네요
# (1162-1163):  그쵸?
# (1164-1166):  그거를 그대로
# (1166-1168):  1만큼 받겠다 곱하기 1이죠
# (1168-1169):  그만큼 받겠다는 얘기입니다
# (1169-1171):  근데 우리 중력받기 싫잖아요
# (1171-1173):  그래서 0으로 넣을게요
# (1173-1176):  이렇게 해주시면 되겠습니다
# (1176-1179):  자 그리고 아래 또
# (1179-1181):  add component 해서 더 추가를
# (1181-1182):  해보도록 하겠습니다
# (1182-1184):  자 component는 여기
# (1184-1193):  좌측에 화살표 누르시면 이렇게 접을 수 있어요 접은 다음에 다시 한번 자 비스 2d 들어가시고
# (1193-1201):  네번째가 캡슐 콜라이드 2d 입니다 자 콜라이더가 뭐냐면은 충돌 면을 말하는 거에요 충돌면
# (1201-1204):  리즈드 바디는 이제 뭐 물리적인 속도 하고 중력하고 이런건 책임지는데 충돌면 리즈드 바디는 물리적인 속도하고
# (1204-1205):  중력하고
# (1205-1206):  이런건 책임지는데
# (1206-1208):  충돌면은 따로
# (1208-1209):  콜라이더가 책임집니다
# (1209-1209):  그래서
# (1209-1211):  요거 추가해주셔야 되구요
# (1211-1213):  그러면 이런식으로
# (1213-1214):  연두색
# (1214-1215):  줄이 쭉
# (1215-1216):  보일거에요
# (1216-1217):  그쵸
# (1217-1218):  여기가 바로 충돌면입니다
# (1218-1220):  근데 보시면 알겠지만
# (1220-1223):  이 충돌면이 뭔가 이 플레이어랑 안 맞는 것 같아요
# (1223-1224):  그쵸?
# (1224-1226):  그래서 요 사이즈 보시면은
# (1226-1229):  일단 S축을 먼저 0.7로 할게요
# (1229-1230):  0.6으로 하시면 됩니다
# (1230-1233):  이건 뭐 여러분이 원하실대로 바꿔주시면 되구요
# (1233-1236):  Y축도 한 0.9 정도로 할게요
# (1236-1239):  뭐 꼭 맞출 필요 없는데요
# (1239-1244):  여러분께서 아 이 정도면 되겠네 싶을 정도의 크기로 맞춰 주시면 될 것 같아요
# (1244-1253):  자 이 크기가 크면 클수록 플레이어가 적대한테 훨씬 더 많이 맞겠죠 그럼 피격 범위가 크니까 그쵸
# (1253-1256):  이게 짜고만 짜고 일수록 피격 범위가 크니까 그쵸? 이게 작으면 작을수록 피격 범위가 작아진다는 사실
# (1256-1258):  그래서 뭐 이건 여러분들
# (1258-1260):  게임 스타일대로 크기
# (1260-1262):  설정해주시면 되겠습니다
# (1262-1264):  되었나요? 자 이렇게 하시고 한번
# (1264-1266):  실행을 해보시면은
# (1266-1268):  대략 요런
# (1268-1270):  모습이 됩니다 아 물론 지금 여러분들은
# (1270-1275):  키보드로 뭐 아무리 눌러봐도 움직이지 않습니다
# (1275-1279):  당연히 움직이는 로직 스크립트가 없기 때문입니다
# (1279-1282):  지금은 우리는 위치 트랜스폼하고
# (1282-1285):  이미지를 그려주는 스프레트 렌더러
# (1285-1288):  물리를 책임지는 리즈드버즈 2D하고
# (1288-1290):  충돌면을 책임지는 캡처 콜라 2D
# (1290-1293):  이 4개만 넣었다는 점 참고하시고요
# (1293-1297):  이렇게 만들면 조금 그러니까
# (1297-1300):  그림자 지도록 하겠습니다
# (1300-1303):  사실 그림자도 제가 미리 준비해놨습니다
# (1303-1306):  프로프스라는 스프레트를 열어보시면 열리네요 있습니다 사실 그림도 제가 미리 준비해 왔습니다 자 요 프롭스 라는 페이트를 자
# (1306-1312):  열어 보시면은 어 열리네요 자 제가 플레이어 0 빼고는 다 제가 미리
# (1312-1315):  나눠 왔습니다 여러분들 귀찮지 않게 안하고
# (1315-1319):  자 쭉 내려가시면 여기 쉐도우가 있어요 어 이거 쉐도우도 쭉 끌어다가
# (1319-1322):  놓으면 되는데 자 여기다가 아닙니다 어디에다가
# (1322-1328):  저기 하얗게 창에 플레이어 에다가 마우스 갖다 드리세요 어 그러면
# (1328-1335):  이렇게 집어 넣을 수가 있어요 자 이걸 우리는 부모와 자식 관계라고 합니다
# (1335-1339):  자 플레이어는 이제 부모 오브젝트를 뜻한 거고요.
# (1339-1345):  이거 0, 0 할게요. 아래 섀도우 한 칸 약간 조금 들여 쓰게 되었죠.
# (1345-1349):  이건 이제 자식 오브젝트에요. 그리고 접을 수도 있죠.
# (1349-1355):  섀도우는 지금 플레이어 자식으로 등록되어 있다라는 얘기고요
# (1355-1357):  자 이거 포지션도 0,0으로 해주시고요
# (1357-1360):  특히 지금 Y축 너무 위했죠?
# (1360-1362):  약간 발 아래에 들어가 있습니다
# (1362-1364):  마이너스 0.45로 할게요
# (1364-1366):  네 제가 이것저것 한번 테스트해 봤는데
# (1366-1368):  마이너스 0.45가 제일 이쁘더라고요
# (1368-1373):  하지만 섀도우가 지금 발 가리고 있죠 안됩니다
# (1373-1378):  지금 보시면 이 섀도우의 스프레이트 랜더러 열어보시면은 이 에디셔널 세팅
# (1378-1383):  오더 인 레이어가 0 입니다 에더 0 플레이어 0 입니다
# (1383-1388):  숫자가 같으면은 누가 먼저 그릴지 그냥 랜덤하게 표시가 되요 그래서 이 우선적으로 그리는 것을 숫자가 같으면은 누가 먼저 그려질지 그냥 랜덤하게 표시가 돼요
# (1388-1392):  그래서 우선적으로 그리는 것을 숫자를 높게 해주시면 됩니다
# (1392-1395):  플레이어가 먼저 튀어나와야겠죠
# (1395-1398):  1. 누가 이 스프레이트를 내리고 올리느냐
# (1399-1400):  그렇게 맞춰주시면 되겠습니다
# (1400-1402):  쉐도우를 0으로 하고요
# (1402-1406):  플레이어는 나중에 또 그 다른 것도 하기 위해서
# (1406-1413):  이거를 제가 5로 올리겠습니다 나중에 또 팔도 붙이고 그렇게 할거니깐요
# (1413-1422):  여기까지 확인되었습니까 게임상에는 요렇게 보일 것이에요 근데 보시면 파란색 화면이잖아요
# (1422-1424):  이건 왜그러죠?
# (1424-1426):  이거는 카메라에 따릅니다
# (1426-1428):  카메라에 보시면
# (1428-1430):  environment 하면서
# (1430-1432):  지금 백그라운드가 파란색 되어있죠
# (1432-1434):  이거는 뭐 여러분들이 원하시는대로
# (1434-1436):  색깔을 바꿔주시면 되겠습니다
# (1436-1439):  저는 살짝 회색 뭐 한 요정도로 하겠습니다
# (1439-1442):  이렇게 하겠습니다
# (1442-1444):  해서 플레이시키면은
# (1444-1447):  뭐 그렇게 뭐 그다지 큰 차이는 없지만
# (1447-1449):  이렇게 보일거에요
# (1449-1453):  자 요렇게 해서 간단하게 플레이어 오브젝트를 한번 만들어봤구요
# (1455-1457):  자 꽤나 괜찮은 모습이 나왔죠?
# (1457-1461):  그래서 이 다음 시간에는 이 플레이어를
# (1461-1464):  직접 우리가 스크립트 로직을 작성을 해서
# (1464-1469):  움직여 보고 애니메이션도 넣어 보는 시간 가져볼 겁니다
# (1469-1472):  자, 그럼 첫 번째 시간 여기서 마무리 하도록 하죠
# (1472-1473):  감사합니다
#
#     위 정보를 참고하여 더 정확하고 매끄러운 자막 청크를 생성해주세요.
#     각 청크는 타임스탬프와 텍스트로 구성되어야 합니다.
#
#     - 오타가 났거나 애매한 용어는 유튜브 영상 설명 내용을 참고해주세요.
#     - 타임스탬프를 엄격하게 지켜주세요.
#
#     아래 JSON 형식에 맞춰 결과를 반환하세요:
#     The output should be formatted as a JSON instance that conforms to the JSON schema below.
#
# As an example, for the schema {"properties": {"foo": {"title": "Foo", "description": "a list of strings", "type": "array", "items": {"type": "string"}}}, "required": ["foo"]}
# the object {"foo": ["bar", "baz"]} is a well-formatted instance of the schema. The object {"properties": {"foo": ["bar", "baz"]}} is not well-formatted.
#
# Here is the output schema:
# ```
# {"$defs": {"YouTubeScriptChunkModel": {"properties": {"timestamp": {"description": "Chunk의 시작 및 끝 타임스탬프", "maxItems": 2, "minItems": 2, "prefixItems": [{"type": "integer"}, {"type": "integer"}], "title": "Timestamp", "type": "array"}, "text": {"description": "해당 시간의 스크립트 텍스트", "title": "Text", "type": "string"}}, "required": ["timestamp", "text"], "title": "YouTubeScriptChunkModel", "type": "object"}}, "properties": {"chunks": {"description": "타임스탬프별 텍스트 조각 리스트", "items": {"$ref": "#/$defs/YouTubeScriptChunkModel"}, "title": "Chunks", "type": "array"}}, "required": ["chunks"]}
# ```
#
# 19604

# %%
response = script_refine_chain.invoke(input=input_data)

# %%
print(response)
# Out:
# chunks=[YouTubeScriptChunkModel(timestamp=(0, 11), text='자 여러분들 반갑습니다. 골드메탈입니다.'), YouTubeScriptChunkModel(timestamp=(11, 24), text='이번엔 뱀사라이크 언데드 서바이벌 개발의 첫 번째 시간으로서 유니티를 한번 설치해 보고 프로젝트 시작과 그 다음에 플레이어를 간단하게 만들어 보는 방법에 대해서 같이 진행해 보도록 하겠습니다.'), YouTubeScriptChunkModel(timestamp=(24, 43), text='그래서 여러분들 네이버나 아니면 구글에다가 유니티 검색하셔서 이렇게 공식 홈페이지에 들어오시면 되는데요. unity.com.kr 입니다.'), YouTubeScriptChunkModel(timestamp=(43, 49), text='보시면 여기 유니티 다운로드 버튼이 있습니다. 자 들어가시구요. 그러면 여기 또 윈도우용 다운로드가 나오겠습니다.'), YouTubeScriptChunkModel(timestamp=(49, 54), text='물론 또 이제 iOS는 다운로드도 아래에서 할 수 있으니깐요 확인하시면 좋겠습니다.'), YouTubeScriptChunkModel(timestamp=(54, 57), text='그래서 버튼 눌러서 다운로드 하시면 되구요.'), YouTubeScriptChunkModel(timestamp=(57, 62), text='그러면 유니티 에디터 설치 파일이 나오는 게 아니고 유니티 허브 설치 파일이 나옵니다.'), YouTubeScriptChunkModel(timestamp=(62, 67), text='자, 이거 누르셔서 유니티 허브부터 설치를 하시는 게 좋겠습니다.'), YouTubeScriptChunkModel(timestamp=(67, 73), text='그래서 설치 동의함 눌러주시구요.'), YouTubeScriptChunkModel(timestamp=(73, 86), text='자 한 가지 제가 추천드리는 사항은요 유니티 허브나 아니면 다른 거 설치하실 때 보통은 주 드라이브 내에다가 여러분들이 따로 유니티 허브 폴드를 만드시고 거기에 설치하시는 것을 추천드립니다.'), YouTubeScriptChunkModel(timestamp=(86, 94), text='그래야 유니티 파일들을 관리하기가 상당히 쉽거든요. 그래서 이런 식으로 깔끔하게 정리해서 설치하시는 것을 추천드립니다.'), YouTubeScriptChunkModel(timestamp=(94, 101), text='그래서 설치를 완료했으면요 이렇게 유니티 허브가 나올 겁니다.'), YouTubeScriptChunkModel(timestamp=(101, 105), text='지금 버전은 유니티 허브 3.3 버전이네요.'), YouTubeScriptChunkModel(timestamp=(105, 114), text='가장 첫 번째 해야 할 것은 바로 로그인입니다. 여러분이 유니티를 사용하시려면 유니티 개인 계정 로그인 계정이 필요하구요.'), YouTubeScriptChunkModel(timestamp=(114, 120), text='그거를 여기에서 로그인 해 주셔야 됩니다. 그렇게 되면은 여러분들 라이센스를 다 가지게 되는데요.'), YouTubeScriptChunkModel(timestamp=(120, 128), text='자, 지금 여기가 유니티 허브잖아요. 우리가 보통 말하고 있는 유니티는 유니티 에디터입니다.'), YouTubeScriptChunkModel(timestamp=(128, 132), text='그래서 에디터는 여기 설치 탭에 보시면 이렇게 설치를 할 수 있어요.'), YouTubeScriptChunkModel(timestamp=(132, 136), text='저는 이미 2022.2 버전 그리고 2021이란 버전이 같이 설치가 되어 있습니다.'), YouTubeScriptChunkModel(timestamp=(136, 141), text='그런데 이 에디터도 허브와 마찬가지로 여러분들 드라이브 바로 다음에 설치하는 편이 정말 좋거든요.'), YouTubeScriptChunkModel(timestamp=(141, 158), text='그래서 자 여기 톱니바퀴 환경 설정 눌러보시면 프로젝트 위치가 있습니다. 그래서 프로젝트 위치를 미리 지정할 수 있는데요.'), YouTubeScriptChunkModel(timestamp=(158, 167), text='저는 이렇게 c 드라이브 바로 아래에다가 유니티 프로젝트라는 폴더를 새로 만들어서 딱 지정을 해놓았습니다.'), YouTubeScriptChunkModel(timestamp=(167, 171), text='자 이렇게 해두면은 나중에 여러분께서 플랫폼 빌드할 때 이 한글 폴더에 의해서 문제가 발생하지가 않아요.'), YouTubeScriptChunkModel(timestamp=(171, 176), text='괜찮죠? 그래서 미리 이렇게 하는 걸 추천드리고요.'), YouTubeScriptChunkModel(timestamp=(176, 181), text='마찬가지로 설치 탭에 가시면 에디터와 컨텐츠 이런 식으로도 깔끔하게 정리해 두시는 것을 추천드립니다.'), YouTubeScriptChunkModel(timestamp=(181, 187), text='이렇게 하면 제 C 드라이브 한번 보여드릴게요. 깔끔하죠? 유니티 콘텐츠, 에디터, 허브 이렇게 한꺼번에 다 볼 수 있다는 점 참고하시구요.'), YouTubeScriptChunkModel(timestamp=(187, 193), text='그럼 이제 에디터를 설치할 거 아닙니까? 저는 이미 에디터가 설치되어 있지만 여러분들은 아마 지금 없을 겁니다.'), YouTubeScriptChunkModel(timestamp=(193, 203), text='그래서 에디터를 설치 버튼을 눌러주시고 이번 뱀사라이크 언데드 서바이버는 2021.3 LTS 버전으로 진행합니다.'), YouTubeScriptChunkModel(timestamp=(203, 209), text='해서 이 맨 위에 거 설치를 진행해 주시면 되구요. 아, 근데 설치하실 때 주의할 점.'), YouTubeScriptChunkModel(timestamp=(209, 219), text='자, 일단 저는 설치가 이미 되었기 때문에 아래 거 눌러오면서 예시를 한번 들어보겠습니다.'), YouTubeScriptChunkModel(timestamp=(219, 225), text='아마 처음 설치하실 분들은 그 코드 스크립트, 마이크로소프트 비주얼 스튜디오도 같이 필요합니다.'), YouTubeScriptChunkModel(timestamp=(225, 238), text='그래서 여기에 체크 되어 있을 거예요. 네, 저도 체크 되어 있죠.'), YouTubeScriptChunkModel(timestamp=(238, 245), text='그리고 나중에 거의 마지막 부분에는 이 안드로이드 빌드도 같이 할 거기 때문에 꼭 여러분들 플랫폼 안드로이드 빌드 서포트에 체크해 주시면 좋겠습니다.'), YouTubeScriptChunkModel(timestamp=(245, 258), text='오픈 JDK와 안드로이드 SDK, NDK까지 이 세 개 꼭 같이 체크하시고 계속 눌러주셔서 설치해 주시면 좋겠습니다.'), YouTubeScriptChunkModel(timestamp=(258, 261), text='이렇게 모듈 설치 완료됐고요.'), YouTubeScriptChunkModel(timestamp=(261, 266), text='만약에 이미 설치된 모듈이 있다. 근데 안드로이드만 설치가 안 되어 있어요.'), YouTubeScriptChunkModel(timestamp=(266, 270), text='그럼 여기에 톱니바퀴 눌러주시고요, 모듈 추가 해주신 다음에 플랫폼에서 여기 안드로이드 체크하시고 계속하시면 모듈만 따로 설치가 된다는 점 확인해 주시기 바랍니다.'), YouTubeScriptChunkModel(timestamp=(270, 275), text='되셨나요? 자 그러 ...

# %%
from domain import  YouTubeScript, YouTubeScriptChunk
chunks = [
        YouTubeScriptChunk(
            timestamp=chunk.timestamp,
            text=chunk.text,
        )
        for chunk in response.chunks
    ]
# 전체 스크립트를 청크 텍스트의 조합으로 생성
script = " ".join(chunk.text for chunk in chunks)

refine_script = YouTubeScript(script, chunks)
print(refine_script)
# Out:
# YouTubeScript(script='자 여러분들 반갑습니다. 골드메탈입니다. 이번엔 뱀사라이크 언데드 서바이벌 개발의 첫 번째...', chunks=[(0-11: 자 여러분들 반갑습니다. 골...), (11-24: 이번엔 뱀사라이크 언데드 서...), (24-43: 그래서 여러분들 네이버나 아...), ...] (213 chunks))

# %%
content.set_script(refine_script)
repository.save(content)
# Out:
# True
