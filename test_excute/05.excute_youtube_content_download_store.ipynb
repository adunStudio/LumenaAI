# %%
from infrastructure.database.mongo_client import MongoDBClient
from infrastructure.repository import YoutubeContentRepository
from application.use_case import YouTubeContentDownloadAndStore

import os
from dotenv import load_dotenv

load_dotenv()

# MongoDB 클라이언트 초기화
client = MongoDBClient(uri=os.environ['MONGO_CONNECTION_STRING'])
client.connect()

# 저장소 초기화
repository = YoutubeContentRepository(client)

# 유즈케이스 초기화
yds = YouTubeContentDownloadAndStore(repository)
# Out:
# INFO:speechbrain.utils.quirks:Applied quirks (see `speechbrain.utils.quirks`): [disable_jit_profiling, allow_tf32]
# INFO:speechbrain.utils.quirks:Excluded quirks specified by the `SB_DISABLE_QUIRKS` environment (comma-separated list): []
# Connected to MongoDB

# %%
import pandas as pd

youtube_parse_list = pd.read_csv('../data/youtube_parse_list.csv')
youtube_parse_list
# Out:
#       category                                                url  noplaylist
# 0        뱀서라이크  https://www.youtube.com/playlist?list=PLO-mt5I...       False
# 1        비행기슈팅  https://www.youtube.com/playlist?list=PLO-mt5I...       False
# 2       탑다운RPG  https://www.youtube.com/playlist?list=PLO-mt5I...       False
# 3         플랫포머  https://www.youtube.com/playlist?list=PLO-mt5I...       False
# 4         유니티6  https://www.youtube.com/watch?v=350EWYC_1ZA&li...        True
# 5         유니티6  https://www.youtube.com/watch?v=Q7mHfbEzaJM&li...        True
# 6         유니티6        https://www.youtube.com/watch?v=r4aZypBrFHE        True
# 7         유니티6        https://www.youtube.com/watch?v=3mSO1sMdGxM        True
# 8       고박사 C#  https://www.youtube.com/playlist?list=PLC2Tit6...       False
# 9   고박사 유니티 기술  https://www.youtube.com/playlist?list=PLC2Tit6...       False
# 10     유니티 코리아        https://www.youtube.com/watch?v=A0nsAjsJqHg        True
# 11        오늘코딩        https://www.youtube.com/watch?v=DXFrfh1oy3M        True
# 12        오늘코딩        https://www.youtube.com/watch?v=gj3gMhMZWoE        True
# 13        오늘코딩        https://www.youtube.com/watch?v=5WyebyiOayk        True
# 14        오늘코딩        https://www.youtube.com/watch?v=Cru7ZVVgy28        True
# 15        오늘코딩        https://www.youtube.com/watch?v=dLomdF5Z0DU        True
# 16        오늘코딩        https://www.youtube.com/watch?v=ILefNAZGVFY        True
# 17        오늘코딩        https://www.youtube.com/watch?v=cKBUcXDSqi4        True
# 18        오늘코딩        https://www.youtube.com/watch?v=OIcqe4ad5oA        True
# 19          베르  https://www.youtube.com/watch?v=2zU_FNym3ro&li...        True
# 20          배르  https://www.youtube.com/watch?v=aK1lfH8Q3SU&li...        True

# %%
import yt_dlp

def get_playlist_info(url):
    ydl_opts = {
        'quiet': True,
        'extract_flat': True,  # 재생목록일 경우 정보만 가져옴
        'noplaylist': False,  # 사용자의 선택에 따라 재생목록 전체 또는 단일 동영상 처리
    }
    with yt_dlp.YoutubeDL(ydl_opts) as ydl:
        info = ydl.extract_info(url, download=False)
        return info

# %%
custom_download_folder = '../downloads'

for row in youtube_parse_list.itertuples(index=False):
    category = row.category
    url = row.url
    is_playlist = not row.noplaylist

    if is_playlist:
        playlist_info = get_playlist_info(url)
        for entry in playlist_info['entries']:
            video_url = entry.get('url')
            print(video_url)
            yds.execute(video_url, category, custom_download_folder)
            print('----' * 7)

    else:
        yds.execute(url, category, custom_download_folder)
        print('----' * 7)
# Out:
# WARNING: [youtube:tab] Incomplete data received. Retrying (1/3)...
# WARNING: [youtube:tab] Incomplete data received. Retrying (2/3)...
# WARNING: [youtube:tab] Incomplete data received. Retrying (3/3)...
# WARNING: [youtube:tab] Incomplete data received. Giving up after 3 retries
# https://www.youtube.com/watch?v=MmW166cHj54
# 데이터가 이미 존재합니다.
# ../downloads/뱀서라이크
# 파일이 이미 존재합니다: ../downloads/뱀서라이크/유니티 뱀서라이크 개발강좌가 온다?! 언데드 서바이버.mp3
# ----------------------------
# https://www.youtube.com/watch?v=qOTbP9ciJ88
# 데이터가 이미 존재합니다.
# ../downloads/뱀서라이크
# 파일이 이미 존재합니다: ../downloads/뱀서라이크/2D 오브젝트🧍만들기 [유니티 뱀서라이크 01].mp3
# ----------------------------
# https://www.youtube.com/watch?v=YAu4yWU5D5U
# 데이터가 이미 존재합니다.
# ../downloads/뱀서라이크
# 파일이 이미 존재합니다: ../downloads/뱀서라이크/플레이어 이동🚶구현하기 [유니티 뱀서라이크 02].mp3
# ----------------------------
# https://www.youtube.com/watch?v=tKMnVBTes0M
# 데이터가 이미 존재합니다.
# ../downloads/뱀서라이크
# 파일이 이미 존재합니다: ../downloads/뱀서라이크/새로운 인풋시스템🎮적용하기 [유니티 뱀서라이크 02+].mp3
# ----------------------------
# https://www.youtube.com/watch?v=vizfd1TeRMI
# 데이터가 이미 존재합니다.
# ../downloads/뱀서라이크
# 파일이 이미 존재합니다: ../downloads/뱀서라이크/2D 셀 애니메이션🏃제작하기 [유니티 뱀서라이크 03].mp3
# ----------------------------
# https://www.youtube.com/watch?v=SNjgew0VhHY
# 데이터가 이미 존재합니다.
# ../downloads/뱀서라이크
# 파일이 이미 존재합니다: ../downloads/뱀서라이크/무한🌍맵 이동 [유니티 뱀서라이크 04].mp3
# ----------------------------
# https://www.youtube.com/watch?v=0aUCu1BcZxs
# 데이터가 이미 존재합니다.
# ../downloads/뱀서라이크
# 파일이 이미 존재합니다: ../downloads/뱀서라이크/몬스터🧟만들기 [유니티 뱀서라이크 05].mp3
# ----------------------------
# https://www.youtube.com/watch?v=A7mfPH8jyBE
# 데이터가 이미 존재합니다.
# ../downloads/뱀서라이크
# 파일이 이미 존재합니다: ../downloads/뱀서라이크/오브젝트 풀링🏊으로 소환하기 [유니티 뱀서라이크 06].mp3
# ----------------------------
# https://www.youtube.com/watch?v=SSg_9q-8h-A
# 데이터가 이미 존재합니다.
# ../downloads/뱀서라이크
# 파일이 이미 존재합니다: ../downloads/뱀서라이크/소환 레벨⏳적용하기 [유니티 뱀서라이크 06+].mp3
# ----------------------------
# https://www.youtube.com/watch?v=HPJVVcRKwn0
# 데이터가 이미 존재합니다.
# ../downloads/뱀서라이크
# 파일이 이미 존재합니다: ../downloads/뱀서라이크/회전하는🪓근접무기 구현 [유니티 뱀서라이크 07].mp3
# ----------------------------
# https://www.youtube.com/watch?v=dBQHtMI-Og4
# 데이터가 이미 존재합니다.
# ../downloads/뱀서라이크
# 파일이 이미 존재합니다: ../downloads/뱀서라이크/자동🎯원거리 공격 구현 [유니티 뱀서라이크 08].mp3
# ----------------------------
# https://www.youtube.com/watch?v=JRaIlTEmvHY
# 데이터가 이미 존재합니다.
# ../downloads/뱀서라이크
# 파일이 이미 존재합니다: ../downloads/뱀서라이크/타격감🌟있는 몬스터 처치 만들기 [유니티 뱀서라이크 09].mp3
# ----------------------------
# https://www.youtube.com/watch?v=ip0xffLSWlk
# 데이터가 이미 존재합니다.
# ../downloads/뱀서라이크
# 파일이 이미 존재합니다: ../downloads/뱀서라이크/HUD📐제작하기 [유니티 뱀서라이크 10].mp3
# ----------------------------
# https://www.youtube.com/watch?v=-47pjK-P888
# 데이터가 이미 존재합니다.
# ../downloads/뱀서라이크
# 파일이 이미 존재합니다: ../downloads/뱀서라이크/능력 업그레이드💪구현 [유니티 뱀서라이크 11].mp3
# ----------------------------
# https://www.youtube.com/watch?v=NE5j8YmJ5Ds
# 데이터가 이미 존재합니다.
# ../downloads/뱀서라이크
# 파일이 이미 존재합니다: ../downloads/뱀서라이크/플레이어 무기 장착 표현하기 [유니티 뱀서라이크 11+].mp3
# ----------------------------
# https://www.youtube.com/watch?v=eo8bLO7kHVo
# 데이터가 이미 존재합니다.
# ../downloads/뱀서라이크
# 파일이 이미 존재합니다: ../downloads/뱀서라이크/레벨업🥳시스템 [유니티 뱀서라이크 12].mp3
# ----------------------------
# https://www.youtube.com/watch?v=Lt2Q9glJlw0
# 데이터가 이미 존재합니다.
# ../downloads/뱀서라이크
# 파일이 이미 존재합니다: ../downloads/뱀서라이크/게임 시작과 종료 [유니티 뱀서라이크 13].mp3
# ----------------------------
# https://www.youtube.com/watch?v=vJACbWBDa90
# 데이터가 이미 존재합니다.
# ../downloads/뱀서라이크
# 파일이 이미 존재합니다: ../downloads/뱀서라이크/플레이 캐릭터🧑‍🤝‍🧑선택 [유니티 뱀서라이크 14].mp3
# ----------------------------
# https://www.youtube.com/watch?v=QxsH5fE0iAo
# 데이터가 이미 존재합니다.
# ../downloads/뱀서라이크
# 파일이 이미 존재합니다: ../downloads/뱀서라이크/캐릭터 해금🔓시스템 [유니티 뱀서라이크 14+].mp3
# ----------------------------
# https://www.youtube.com/watch?v=YPEkpwPrmPk
# 데이터가 이미 존재합니다.
# ../downloads/뱀서라이크
# 파일이 이미 존재합니다: ../downloads/뱀서라이크/편리한 오디오🔊시스템 구축 [유니티 뱀서라이크 15].mp3
# ----------------------------
# https://www.youtube.com/watch?v=XslHd_0oVXg
# 데이터가 이미 존재합니다.
# ../downloads/뱀서라이크
# 파일이 이미 존재합니다: ../downloads/뱀서라이크/로직🛠️보완하기 [유니티 뱀서라이크 16].mp3
# ----------------------------
# https://www.youtube.com/watch?v=O5Qvq4dypOg
# 데이터가 이미 존재합니다.
# ../downloads/뱀서라이크
# 파일이 이미 존재합니다: ../downloads/뱀서라이크/모바일📱빌드하기 [유니티 뱀서라이크 17].mp3
# ----------------------------
# WARNING: [youtube:tab] Incomplete data received. Retrying (1/3)...
# WARNING: [youtube:tab] Incomplete data received. Retrying (2/3)...
# WARNING: [youtube:tab] Incomplete data received. Retrying (3/3)...
# WARNING: [youtube:tab] Incomplete data received. Giving up after 3 retries
# https://www.youtube.com/watch?v=ETYzjbnLixY
# 데이터가 이미 존재합니다.
# ../downloads/비행기슈팅
# 파일이 이미 존재합니다: ../downloads/비행기슈팅/2D 종스크롤 슈팅 -  플레이어 이동 구현하기 [유니티 기초 강좌 B27 + 에셋 다운로드].mp3
# ----------------------------
# https://www.youtube.com/watch?v=JUG0GnsJHQw
# 데이터가 이미 존재합니다.
# ../downloads/비행기슈팅
# 파일이 이미 존재합니다: ../downloads/비행기슈팅/2D 종스크롤 슈팅 -  총알발사 구현하기 [유니티 기초 강좌 B28].mp3
# ----------------------------
# https://www.youtube.com/watch?v=lKFka1regy8
# 데이터가 이미 존재합니다.
# ../downloads/비행기슈팅
# 파일이 이미 존재합니다: ../downloads/비행기슈팅/2D 종스크롤 슈팅 -  적 비행기 만들기 [유니티 기초 강좌 B29].mp3
# ----------------------------
# https://www.youtube.com/watch?v=OI7BvnN4zLE
# 데이터가 이미 존재합니다.
# ../downloads/비행기슈팅
# 파일이 이미 존재합니다: ../downloads/비행기슈팅/2D 종스크롤 슈팅 -  적 전투와 피격 이벤트 만들기 [유니티 기초 강좌 B30].mp3
# ----------------------------
# https://www.youtube.com/watch?v=qXa7y1Que6s
# 데이터가 이미 존재합니다.
# ../downloads/비행기슈팅
# 파일이 이미 존재합니다: ../downloads/비행기슈팅/2D 종스크롤 슈팅 -  UI 간단하게 완성하기 [유니티 기초 강좌 B31].mp3
# ----------------------------
# https://www.youtube.com/watch?v=RLbcov_aGfo
# 데이터가 이미 존재합니다.
# ../downloads/비행기슈팅
# 파일이 이미 존재합니다: ../downloads/비행기슈팅/2D 종스크롤 슈팅 - 아이템과 필살기 구현하기 [유니티 기초 강좌 B32].mp3
# ----------------------------
# https://www.youtube.com/watch?v=KUQAULcpYZU
# 데이터가 이미 존재합니다.
# ../downloads/비행기슈팅
# 파일이 이미 존재합니다: ../downloads/비행기슈팅/2D 종스크롤 슈팅 - 원근감있는 무한 배경 만들기 [유니티 기초 강좌 B33].mp3
# ----------------------------
# https://www.youtube.com/watch?v=x-5eHMRSgeg
# 데이터가 이미 존재합니다.
# ../downloads/비행기슈팅
# 파일이 이미 존재합니다: ../downloads/비행기슈팅/2D 종스크롤 슈팅 - 최적화의 기본, 오브젝트 풀링 (어려움!) [유니티 기초 강좌 B34].mp3
# ----------------------------
# https://www.youtube.com/watch?v=yBjsGYUdyAA
# 데이터가 이미 존재합니다.
# ../downloads/비행기슈팅
# 파일이 이미 존재합니다: ../downloads/비행기슈팅/2D 종스크롤 슈팅 - 텍스트파일을 이용한 커스텀 배치 구현 [유니티 기초 강좌 B35].mp3
# ----------------------------
# https://www.youtube.com/watch?v=QPwF2Lsf7c8
# 데이터가 이미 존재합니다.
# ../downloads/비행기슈팅
# 파일이 이미 존재합니다: ../downloads/비행기슈팅/2D 종스크롤 슈팅 - 따라다니는 보조무기 만들기 [유니티 기초 강좌 B36].mp3
# ----------------------------
# https://www.youtube.com/watch?v=dnMVMBVpgYA
# 데이터가 이미 존재합니다.
# ../downloads/비행기슈팅
# 파일이 이미 존재합니다: ../downloads/비행기슈팅/2D 종스크롤 슈팅 - 탄막을 뿜어대는 보스 만들기 [유니티 기초 강좌 B37].mp3
# ----------------------------
# https://www.youtube.com/watch?v=wM2IfVuEYYE
# 데이터가 이미 존재합니다.
# ../downloads/비행기슈팅
# 파일이 이미 존재합니다: ../downloads/비행기슈팅/2D 종스크롤 슈팅 - 모바일 슈팅게임 만들기 [유니티 기초 강좌 BE4].mp3
# ----------------------------
# WARNING: [youtube:tab] Incomplete data received. Retrying (1/3)...
# WARNING: [youtube:tab] Incomplete data received. Retrying (2/3)...
# WARNING: [youtube:tab] Incomplete data received. Retrying (3/3)...
# WARNING: [youtube:tab] Incomplete data received. Giving up after 3 retries
# https://www.youtube.com/watch?v=JY-KFx3OsJo
# 데이터가 이미 존재합니다.
# ../downloads/탑다운RPG
# 파일이 이미 존재합니다: ../downloads/탑다운RPG/탑다운 2D RPG - 도트 타일맵으로 쉽게 준비하기 [유니티 기초 강좌 B20 + 에셋 다운로드].mp3
# ----------------------------
# https://www.youtube.com/watch?v=bZVa6C6vRBQ
# 데이터가 이미 존재합니다.
# ../downloads/탑다운RPG
# 파일이 이미 존재합니다: ../downloads/탑다운RPG/탑다운 2D RPG - 쯔꾸르식 액션 구현하기 [유니티 기초 강좌 B21].mp3
# ----------------------------
# https://www.youtube.com/watch?v=jVBiGhlwhZg
# 데이터가 이미 존재합니다.
# ../downloads/탑다운RPG
# 파일이 이미 존재합니다: ../downloads/탑다운RPG/탑다운 2D RPG - 대화창 UI 구축하기 [유니티 기초 강좌 B22].mp3
# ----------------------------
# https://www.youtube.com/watch?v=qJjfYvEYKiE
# 데이터가 이미 존재합니다.
# ../downloads/탑다운RPG
# 파일이 이미 존재합니다: ../downloads/탑다운RPG/탑다운 2D RPG - 대화 시스템 구현하기 [유니티 기초 강좌 B23].mp3
# ----------------------------
# https://www.youtube.com/watch?v=RwndWebxbmo
# 데이터가 이미 존재합니다.
# ../downloads/탑다운RPG
# 파일이 이미 존재합니다: ../downloads/탑다운RPG/탑다운 2D RPG - 퀘스트 시스템 구현하기 [유니티 기초 강좌 B24].mp3
# ----------------------------
# https://www.youtube.com/watch?v=emGwkkM6bnc
# 데이터가 이미 존재합니다.
# ../downloads/탑다운RPG
# 파일이 이미 존재합니다: ../downloads/탑다운RPG/탑다운 2D RPG - 대화 애니메이션 느낌있게 만들기 [유니티 기초 강좌 B25].mp3
# ----------------------------
# https://www.youtube.com/watch?v=mYjUVmws2F0
# 데이터가 이미 존재합니다.
# ../downloads/탑다운RPG
# 파일이 이미 존재합니다: ../downloads/탑다운RPG/탑다운 2D RPG - 서브메뉴와 저장기능 만들기 [유니티 기초 강좌 B26].mp3
# ----------------------------
# https://www.youtube.com/watch?v=IJxc-ANxO-w
# 데이터가 이미 존재합니다.
# ../downloads/탑다운RPG
# 파일이 이미 존재합니다: ../downloads/탑다운RPG/탑다운 2D RPG - 모바일 UI & 안드로이드 빌드 [유니티 기초 강좌 BE3].mp3
# ----------------------------
# WARNING: [youtube:tab] Incomplete data received. Retrying (1/3)...
# WARNING: [youtube:tab] Incomplete data received. Retrying (2/3)...
# WARNING: [youtube:tab] Incomplete data received. Retrying (3/3)...
# WARNING: [youtube:tab] Incomplete data received. Giving up after 3 retries
# https://www.youtube.com/watch?v=v_Y5FH_tCpc
# 데이터가 이미 존재합니다.
# ../downloads/플랫포머
# 파일이 이미 존재합니다: ../downloads/플랫포머/2D 플랫포머 - 프로젝트 준비하기 [유니티 기초 강좌 B13 + 에셋 다운로드].mp3
# ----------------------------
# https://www.youtube.com/watch?v=IkvYstCzcoc
# 데이터가 이미 존재합니다.
# ../downloads/플랫포머
# 파일이 이미 존재합니다: ../downloads/플랫포머/2D 플랫포머 - 아틀라스와 애니메이션 [유니티 기초 강좌 B14].mp3
# ----------------------------
# https://www.youtube.com/watch?v=Z4iULRbiSTg
# 데이터가 이미 존재합니다.
# ../downloads/플랫포머
# 파일이 이미 존재합니다: ../downloads/플랫포머/2D 플랫포머 - 플레이어 이동 구현하기 [유니티 기초 강좌 B15].mp3
# ----------------------------
# https://www.youtube.com/watch?v=2SikOdH7xvQ
# 데이터가 이미 존재합니다.
# ../downloads/플랫포머
# 파일이 이미 존재합니다: ../downloads/플랫포머/2D 플랫포머 - 플레이어 점프 구현하기 [유니티 기초 강좌 B16].mp3
# ----------------------------
# https://www.youtube.com/watch?v=f8ixw9IpnD8
# 데이터가 이미 존재합니다.
# ../downloads/플랫포머
# 파일이 이미 존재합니다: ../downloads/플랫포머/2D 플랫포머 - 타일맵으로 플랫폼 만들기 [유니티 기초 강좌 B17].mp3
# ----------------------------
# https://www.youtube.com/watch?v=7MYUOzgZTf8
# 데이터가 이미 존재합니다.
# ../downloads/플랫포머
# 파일이 이미 존재합니다: ../downloads/플랫포머/2D 플랫포머 - 몬스터 AI 구현하기 [유니티 기초 강좌 B18].mp3
# ----------------------------
# https://www.youtube.com/watch?v=epZFE5Hpbdc
# 데이터가 이미 존재합니다.
# ../downloads/플랫포머
# 파일이 이미 존재합니다: ../downloads/플랫포머/2D 플랫포머 - 플레이어 피격 이벤트 구현하기 [유니티 기초 강좌 B19].mp3
# ----------------------------
# https://www.youtube.com/watch?v=GHUJMXtHKL0
# 데이터가 이미 존재합니다.
# ../downloads/플랫포머
# 파일이 이미 존재합니다: ../downloads/플랫포머/2D 플랫포머 - 스테이지를 넘나드는 게임 완성하기 [유니티 기초 강좌 BE2].mp3
# ----------------------------
# 데이터가 이미 존재합니다.
# ../downloads/유니티6
# 파일이 이미 존재합니다: ../downloads/유니티6/더욱 편리한 카메라워킹 패키지 유니티6의 시네머신3 소개.mp3
# ----------------------------
# 데이터가 이미 존재합니다.
# ../downloads/유니티6
# 파일이 이미 존재합니다: ../downloads/유니티6/편리한 기능과 API가 추가된 Unity 6 Physics 2D.mp3
# ----------------------------
# 데이터가 이미 존재합니다.
# ../downloads/유니티6
# 파일이 이미 존재합니다: ../downloads/유니티6/[Unity 6] Unity 6를 소개합니다.mp3
# ----------------------------
# 데이터가 이미 존재합니다.
# ../downloads/유니티6
# 파일이 이미 존재합니다: ../downloads/유니티6/Unity 6 Fantasy Kingdom으로 알아보는 4가지 그래픽스 신기능.mp3
# ----------------------------
# WARNING: [youtube:tab] Incomplete data received. Retrying (1/3)...
# WARNING: [youtube:tab] Incomplete data received. Retrying (2/3)...
# WARNING: [youtube:tab] Incomplete data received. Retrying (3/3)...
# WARNING: [youtube:tab] Incomplete data received. Giving up after 3 retries
# https://www.youtube.com/watch?v=YKiTGbPIZKQ
# 데이터가 이미 존재합니다.
# ../downloads/고박사 C#
# 파일이 이미 존재합니다: ../downloads/고박사 C#/[Unity C#] #01 변수 : 변수와 데이터 (Variable and data).mp3
# ----------------------------
# https://www.youtube.com/watch?v=bA9AVLUSvIo
# 데이터가 이미 존재합니다.
# ../downloads/고박사 C#
# 파일이 이미 존재합니다: ../downloads/고박사 C#/[Unity C#] #02 변수 : 기본 데이터 형식 (Data type).mp3
# ----------------------------
# https://www.youtube.com/watch?v=3NuO7TaWl0s
# 데이터가 이미 존재합니다.
# ../downloads/고박사 C#
# 파일이 이미 존재합니다: ../downloads/고박사 C#/[Unity C#] #03 변수 : 데이터의 형 변환 (Type conversion).mp3
# ----------------------------
# https://www.youtube.com/watch?v=O3L2GMcQn1U
# 데이터가 이미 존재합니다.
# ../downloads/고박사 C#
# 파일이 이미 존재합니다: ../downloads/고박사 C#/[Unity C#] #04 변수 : 상수, 열거형, Nullable, var.mp3
# ----------------------------
# https://www.youtube.com/watch?v=8L_lWH9u2UU
# 데이터가 이미 존재합니다.
# ../downloads/고박사 C#
# 파일이 이미 존재합니다: ../downloads/고박사 C#/[Unity C#] #05 문자열 다루기.mp3
# ----------------------------
# https://www.youtube.com/watch?v=Ci9k6ECcRp0
# 데이터가 이미 존재합니다.
# ../downloads/고박사 C#
# 파일이 이미 존재합니다: ../downloads/고박사 C#/[Unity C#] #06 연산자.mp3
# ----------------------------
# https://www.youtube.com/watch?v=IvfJigYIrAU
# 데이터가 이미 존재합니다.
# ../downloads/고박사 C#
# 파일이 이미 존재합니다: ../downloads/고박사 C#/[Unity C#] #07 조건문.mp3
# ----------------------------
# https://www.youtube.com/watch?v=u8pxxQZFVH4
# 데이터가 이미 존재합니다.
# ../downloads/고박사 C#
# 파일이 이미 존재합니다: ../downloads/고박사 C#/[Unity C#] #08 반복문.mp3
# ----------------------------
# https://www.youtube.com/watch?v=iao7UL-OBIw
# 데이터가 이미 존재합니다.
# ../downloads/고박사 C#
# 파일이 이미 존재합니다: ../downloads/고박사 C#/[Unity C#] 반복문 문제.mp3
# ----------------------------
# https://www.youtube.com/watch?v=rtl5SoWaJvk
# 데이터가 이미 존재합니다.
# ../downloads/고박사 C#
# 파일이 이미 존재합니다: ../downloads/고박사 C#/[Unity C#] #09 배열.mp3
# ----------------------------
# https://www.youtube.com/watch?v=o0Pklkow-AA
# 데이터가 이미 존재합니다.
# ../downloads/고박사 C#
# 파일이 이미 존재합니다: ../downloads/고박사 C#/[Unity C#] #10 메소드 (Method).mp3
# ----------------------------
# https://www.youtube.com/watch?v=wbzF4BNw5Zs
# 데이터가 이미 존재합니다.
# ../downloads/고박사 C#
# 파일이 이미 존재합니다: ../downloads/고박사 C#/[Unity C#] #11 클래스 기초 (Class Basic).mp3
# ----------------------------
# https://www.youtube.com/watch?v=Y4mc6C7mYK0
# 데이터가 이미 존재합니다.
# ../downloads/고박사 C#
# 파일이 이미 존재합니다: ../downloads/고박사 C#/[Unity C#] #12 클래스 심화 (Class Advanced).mp3
# ----------------------------
# https://www.youtube.com/watch?v=2B16TSUyQPU
# 데이터가 이미 존재합니다.
# ../downloads/고박사 C#
# 파일이 이미 존재합니다: ../downloads/고박사 C#/[Unity C#] #13 클래스 추가 기능 (Class Additive Function).mp3
# ----------------------------
# https://www.youtube.com/watch?v=u0iXSe5IEV8
# 데이터가 이미 존재합니다.
# ../downloads/고박사 C#
# 파일이 이미 존재합니다: ../downloads/고박사 C#/[Unity C#] #14 프로퍼티 (Property).mp3
# ----------------------------
# https://www.youtube.com/watch?v=8WRh8TJkHBc
# 데이터가 이미 존재합니다.
# ../downloads/고박사 C#
# 파일이 이미 존재합니다: ../downloads/고박사 C#/[Unity C#] #15 컬렉션 (Collection).mp3
# ----------------------------
# https://www.youtube.com/watch?v=ab83gVHMZNg
# 데이터가 이미 존재합니다.
# ../downloads/고박사 C#
# 파일이 이미 존재합니다: ../downloads/고박사 C#/[Unity C#] #16 일반화 프로그래밍 (Generic Programming).mp3
# ----------------------------
# https://www.youtube.com/watch?v=argeDbqzUdE
# 데이터가 이미 존재합니다.
# ../downloads/고박사 C#
# 파일이 이미 존재합니다: ../downloads/고박사 C#/[Unity C#] #17 파일입출력(File IO) - Directory, File.mp3
# ----------------------------
# https://www.youtube.com/watch?v=SvUYPh6lnqo
# 데이터가 이미 존재합니다.
# ../downloads/고박사 C#
# 파일이 이미 존재합니다: ../downloads/고박사 C#/[Unity C#] #18 파일입출력(File IO) - 스트림과 객체 직렬화.mp3
# ----------------------------
# https://www.youtube.com/watch?v=Bwi7EXCqscc
# 데이터가 이미 존재합니다.
# ../downloads/고박사 C#
# 파일이 이미 존재합니다: ../downloads/고박사 C#/[유니티 C#] #19 파일 브라우저 - 현재 폴더의 파일 목록 출력.mp3
# ----------------------------
# https://www.youtube.com/watch?v=fsgEgPdHmFk
# 데이터가 이미 존재합니다.
# ../downloads/고박사 C#
# 파일이 이미 존재합니다: ../downloads/고박사 C#/[유니티 C#] #20 파일 브라우저 - 폴더(Directory) 이동.mp3
# ----------------------------
# https://www.youtube.com/watch?v=wBzAe9Ewsc4
# 데이터가 이미 존재합니다.
# ../downloads/고박사 C#
# 파일이 이미 존재합니다: ../downloads/고박사 C#/[유니티 C#] #21 파일 브라우저 - 문서, 일반 파일 선택 : 파일 정보 출력.mp3
# ----------------------------
# https://www.youtube.com/watch?v=ydS6u2bQI84
# 데이터가 이미 존재합니다.
# ../downloads/고박사 C#
# 파일이 이미 존재합니다: ../downloads/고박사 C#/[유니티 C#] #22 파일 브라우저 - PNG, JPG 파일 선택 : 이미지 출력.mp3
# ----------------------------
# https://www.youtube.com/watch?v=IvXg2PDb034
# 데이터가 이미 존재합니다.
# ../downloads/고박사 C#
# 파일이 이미 존재합니다: ../downloads/고박사 C#/[유니티 C#] #23 파일 브라우저 - MP3 파일 선택 : 사운드 재생.mp3
# ----------------------------
# https://www.youtube.com/watch?v=uqBQZqFMxkI
# 데이터가 이미 존재합니다.
# ../downloads/고박사 C#
# 파일이 이미 존재합니다: ../downloads/고박사 C#/[유니티 C#] #24 파일 브라우저 - MP4 파일 선택 : 동영상 재생.mp3
# ----------------------------
# WARNING: [youtube:tab] Incomplete data received. Retrying (1/3)...
# WARNING: [youtube:tab] Incomplete data received. Retrying (2/3)...
# WARNING: [youtube:tab] Incomplete data received. Retrying (3/3)...
# WARNING: [youtube:tab] Incomplete data received. Giving up after 3 retries
# https://www.youtube.com/watch?v=IA9UfytQ5R8
# 데이터가 이미 존재합니다.
# ../downloads/고박사 유니티 기술
# 파일이 이미 존재합니다: ../downloads/고박사 유니티 기술/How to make a Minimap UI in Unity!.mp3
# ----------------------------
# https://www.youtube.com/watch?v=C0y00zDBK3c
# 데이터가 이미 존재합니다.
# ../downloads/고박사 유니티 기술
# 파일이 이미 존재합니다: ../downloads/고박사 유니티 기술/How to make a HP/MP UI in Unity!.mp3
# ----------------------------
# https://www.youtube.com/watch?v=1fRbGvQlIEQ
# 데이터가 이미 존재합니다.
# ../downloads/고박사 유니티 기술
# 파일이 이미 존재합니다: ../downloads/고박사 유니티 기술/How to make a Dialog System in Unity!.mp3
# ----------------------------
# https://www.youtube.com/watch?v=2oip0H7VgPM
# 데이터가 이미 존재합니다.
# ../downloads/고박사 유니티 기술
# 파일이 이미 존재합니다: ../downloads/고박사 유니티 기술/How to make a Excel Importer in Unity!.mp3
# ----------------------------
# https://www.youtube.com/watch?v=emuT10nz5Ho
# 데이터가 이미 존재합니다.
# ../downloads/고박사 유니티 기술
# 파일이 이미 존재합니다: ../downloads/고박사 유니티 기술/How to make a Keep In Screen UI in Unity!.mp3
# ----------------------------
# https://www.youtube.com/watch?v=vxCMOPCYeM0
# 데이터가 이미 존재합니다.
# ../downloads/고박사 유니티 기술
# 파일이 이미 존재합니다: ../downloads/고박사 유니티 기술/How to make a RTS Unit Control in Unity!.mp3
# ----------------------------
# https://www.youtube.com/watch?v=O_NJaHpbjaI
# 데이터가 이미 존재합니다.
# ../downloads/고박사 유니티 기술
# 파일이 이미 존재합니다: ../downloads/고박사 유니티 기술/How to make a FSM in Unity! [01].mp3
# ----------------------------
# https://www.youtube.com/watch?v=4rmf0S885X4
# 데이터가 이미 존재합니다.
# ../downloads/고박사 유니티 기술
# 파일이 이미 존재합니다: ../downloads/고박사 유니티 기술/How to make a FSM in Unity! [02].mp3
# ----------------------------
# https://www.youtube.com/watch?v=DeJO4zOFG9E
# 데이터가 이미 존재합니다.
# ../downloads/고박사 유니티 기술
# 파일이 이미 존재합니다: ../downloads/고박사 유니티 기술/How to make a FSM in Unity! [03].mp3
# ----------------------------
# https://www.youtube.com/watch?v=xGu-sTL73iU
# 데이터가 이미 존재합니다.
# ../downloads/고박사 유니티 기술
# 파일이 이미 존재합니다: ../downloads/고박사 유니티 기술/How to make a FSM in Unity! [04].mp3
# ----------------------------
# https://www.youtube.com/watch?v=L4tVAWcWHbs
# 데이터가 이미 존재합니다.
# ../downloads/고박사 유니티 기술
# 파일이 이미 존재합니다: ../downloads/고박사 유니티 기술/유니티 룰렛 시스템 How to make a Roulette in Unity!.mp3
# ----------------------------
# https://www.youtube.com/watch?v=vfpnyz1a_no
# 데이터가 이미 존재합니다.
# ../downloads/고박사 유니티 기술
# 파일이 이미 존재합니다: ../downloads/고박사 유니티 기술/2D 플랫포머 캐릭터 이동 2D Platformer Movement with Raycast.mp3
# ----------------------------
# https://www.youtube.com/watch?v=JZYFhNpobQo
# 데이터가 이미 존재합니다.
# ../downloads/고박사 유니티 기술
# 파일이 이미 존재합니다: ../downloads/고박사 유니티 기술/격자맵에서 부드러운 이동 구현 How to make a Grid based Smooth Movement in Unity!.mp3
# ----------------------------
# https://www.youtube.com/watch?v=eh04LRnh2Tg
# 데이터가 이미 존재합니다.
# ../downloads/고박사 유니티 기술
# 파일이 이미 존재합니다: ../downloads/고박사 유니티 기술/겹치지 않는 난수 생성 How to make a Non-Overlapping Random Numbers in Unity!.mp3
# ----------------------------
# https://www.youtube.com/watch?v=unuZi0FEt8k
# 데이터가 이미 존재합니다.
# ../downloads/고박사 유니티 기술
# 파일이 이미 존재합니다: ../downloads/고박사 유니티 기술/How to make a Primitive Objects in Unity!.mp3
# ----------------------------
# https://www.youtube.com/watch?v=atVEkx4v5cM
# 데이터가 이미 존재합니다.
# ../downloads/고박사 유니티 기술
# 파일이 이미 존재합니다: ../downloads/고박사 유니티 기술/How to make a Primitive Objects II in Unity!.mp3
# ----------------------------
# https://www.youtube.com/watch?v=9lzASRQuWYM
# 데이터가 이미 존재합니다.
# ../downloads/고박사 유니티 기술
# 파일이 이미 존재합니다: ../downloads/고박사 유니티 기술/How to make a Polygon Generator in Unity!.mp3
# ----------------------------
# https://www.youtube.com/watch?v=biL29u6YFpk
# 데이터가 이미 존재합니다.
# ../downloads/고박사 유니티 기술
# 파일이 이미 존재합니다: ../downloads/고박사 유니티 기술/라인렌더러(LineRenderer) A to Z [Part 01][Basic].mp3
# ----------------------------
# https://www.youtube.com/watch?v=wAY9exBIw3A
# 데이터가 이미 존재합니다.
# ../downloads/고박사 유니티 기술
# 파일이 이미 존재합니다: ../downloads/고박사 유니티 기술/라인렌더러(LineRenderer) A to Z [Part 02][Shapes].mp3
# ----------------------------
# https://www.youtube.com/watch?v=fLdxtwm76Ok
# 데이터가 이미 존재합니다.
# ../downloads/고박사 유니티 기술
# 파일이 이미 존재합니다: ../downloads/고박사 유니티 기술/라인렌더러(LineRenderer) A to Z [Part 03][Morphology Conversion].mp3
# ----------------------------
# https://www.youtube.com/watch?v=GXaW4GiyCHU
# 데이터가 이미 존재합니다.
# ../downloads/고박사 유니티 기술
# 파일이 이미 존재합니다: ../downloads/고박사 유니티 기술/라인렌더러(LineRenderer) A to Z [Part 04][Collision].mp3
# ----------------------------
# https://www.youtube.com/watch?v=uyttyyB1HjI
# 데이터가 이미 존재합니다.
# ../downloads/고박사 유니티 기술
# 파일이 이미 존재합니다: ../downloads/고박사 유니티 기술/2D 배경 스크롤 2D Infinite Parallax Background.mp3
# ----------------------------
# https://www.youtube.com/watch?v=82l6GZz32E8
# 데이터가 이미 존재합니다.
# ../downloads/고박사 유니티 기술
# 파일이 이미 존재합니다: ../downloads/고박사 유니티 기술/튜토리얼 제작 How to create Tutorial in Unity!.mp3
# ----------------------------
# https://www.youtube.com/watch?v=FgnLBO4DPA8
# 데이터가 이미 존재합니다.
# ../downloads/고박사 유니티 기술
# 파일이 이미 존재합니다: ../downloads/고박사 유니티 기술/모바일 재화 축약 표현 (K, M, G, T, P, E, Z).mp3
# ----------------------------
# https://www.youtube.com/watch?v=zRfq2rZa9Ho
# 데이터가 이미 존재합니다.
# ../downloads/고박사 유니티 기술
# 파일이 이미 존재합니다: ../downloads/고박사 유니티 기술/선형 보간 (linear interpolate) - Lerp() 메소드.mp3
# ----------------------------
# https://www.youtube.com/watch?v=plrsQbdimpI
# 데이터가 이미 존재합니다.
# ../downloads/고박사 유니티 기술
# 파일이 이미 존재합니다: ../downloads/고박사 유니티 기술/확률을 이용한 오브젝트 생성 비율 조절 how to create Random Spawner with Probability in Unity!.mp3
# ----------------------------
# https://www.youtube.com/watch?v=VJwLcSyY_uE
# 데이터가 이미 존재합니다.
# ../downloads/고박사 유니티 기술
# 파일이 이미 존재합니다: ../downloads/고박사 유니티 기술/씬을 실행할 때 현재 씬 자동 저장 how to create Save On Playmode in Unity!.mp3
# ----------------------------
# https://www.youtube.com/watch?v=8QBeWNb2yaw
# 데이터가 이미 존재합니다.
# ../downloads/고박사 유니티 기술
# 파일이 이미 존재합니다: ../downloads/고박사 유니티 기술/0번 씬 또는 현재 씬 재생 how to create Edit Start Scene in Unity!.mp3
# ----------------------------
# https://www.youtube.com/watch?v=_7EOwJEEVPs
# 데이터가 이미 존재합니다.
# ../downloads/고박사 유니티 기술
# 파일이 이미 존재합니다: ../downloads/고박사 유니티 기술/[Custom Editor] Editor 폴더, Editor Window 제작.mp3
# ----------------------------
# https://www.youtube.com/watch?v=5BOMX5FHbD0
# 데이터가 이미 존재합니다.
# ../downloads/고박사 유니티 기술
# 파일이 이미 존재합니다: ../downloads/고박사 유니티 기술/[Custom Editor] GUI, GUILayout, EditorGUI, EditorGUILayout.mp3
# ----------------------------
# https://www.youtube.com/watch?v=cImwp_-8hZY
# 데이터가 이미 존재합니다.
# ../downloads/고박사 유니티 기술
# 파일이 이미 존재합니다: ../downloads/고박사 유니티 기술/[Custom Editor] Field Methods - Input, Color, Object, Dropdown.mp3
# ----------------------------
# https://www.youtube.com/watch?v=9LtIS4laeWw
# 데이터가 이미 존재합니다.
# ../downloads/고박사 유니티 기술
# 파일이 이미 존재합니다: ../downloads/고박사 유니티 기술/[Custom Editor] Toggle - Toggle, Button Style Toggle, Toggle Group.mp3
# ----------------------------
# https://www.youtube.com/watch?v=uOj9FiIKw_0
# 데이터가 이미 존재합니다.
# ../downloads/고박사 유니티 기술
# 파일이 이미 존재합니다: ../downloads/고박사 유니티 기술/[Custom Editor] Slider, HelpBox, Knob, IndentLevel, ProgressBar.mp3
# ----------------------------
# https://www.youtube.com/watch?v=FFuD4pRJaUg
# 데이터가 이미 존재합니다.
# ../downloads/고박사 유니티 기술
# 파일이 이미 존재합니다: ../downloads/고박사 유니티 기술/[Custom Editor] Begin/End Group.mp3
# ----------------------------
# https://www.youtube.com/watch?v=2GtpnMbRRn0
# 데이터가 이미 존재합니다.
# ../downloads/고박사 유니티 기술
# 파일이 이미 존재합니다: ../downloads/고박사 유니티 기술/씬 자동 저장 how to create Scene Auto Save in Unity!.mp3
# ----------------------------
# https://www.youtube.com/watch?v=yO0UxTo5Elk
# 데이터가 이미 존재합니다.
# ../downloads/고박사 유니티 기술
# 파일이 이미 존재합니다: ../downloads/고박사 유니티 기술/유니티 어트리뷰트 how to use attributes in Unity!.mp3
# ----------------------------
# https://www.youtube.com/watch?v=dkbf75dt0AY
# 데이터가 이미 존재합니다.
# ../downloads/고박사 유니티 기술
# 파일이 이미 존재합니다: ../downloads/고박사 유니티 기술/유니티 어트리뷰트 2   how to use attributes in Unity!.mp3
# ----------------------------
# https://www.youtube.com/watch?v=snh2HrpV4No
# 데이터가 이미 존재합니다.
# ../downloads/고박사 유니티 기술
# 파일이 이미 존재합니다: ../downloads/고박사 유니티 기술/폭발 오브젝트  how to create Explosive Object in Unity!.mp3
# ----------------------------
# https://www.youtube.com/watch?v=ZVpdSmN_Sis
# 데이터가 이미 존재합니다.
# ../downloads/고박사 유니티 기술
# 파일이 이미 존재합니다: ../downloads/고박사 유니티 기술/경로 따라가기  how to create Follow Path in Unity!.mp3
# ----------------------------
# https://www.youtube.com/watch?v=lMPymM0Q6Rs
# 데이터가 이미 존재합니다.
# ../downloads/고박사 유니티 기술
# 파일이 이미 존재합니다: ../downloads/고박사 유니티 기술/목표 에워싸기  how to create Surround Target in Unity!.mp3
# ----------------------------
# https://www.youtube.com/watch?v=XI56ogm7eFI
# 데이터가 이미 존재합니다.
# ../downloads/고박사 유니티 기술
# 파일이 이미 존재합니다: ../downloads/고박사 유니티 기술/마우스 커서 방향으로 회전  Look At Me!!.mp3
# ----------------------------
# https://www.youtube.com/watch?v=uJ9teYEqJ48
# 데이터가 이미 존재합니다.
# ../downloads/고박사 유니티 기술
# 파일이 이미 존재합니다: ../downloads/고박사 유니티 기술/반사  how to use Vector3.Reflect in Unity!.mp3
# ----------------------------
# https://www.youtube.com/watch?v=kDIKrar2maE
# 데이터가 이미 존재합니다.
# ../downloads/고박사 유니티 기술
# 파일이 이미 존재합니다: ../downloads/고박사 유니티 기술/완전한 어둠 how to create real dark world in Unity!.mp3
# ----------------------------
# https://www.youtube.com/watch?v=-dBSfaC4Qss
# 데이터가 이미 존재합니다.
# ../downloads/고박사 유니티 기술
# 파일이 이미 존재합니다: ../downloads/고박사 유니티 기술/가장 근접한 목표 탐색 how to find closest target in Unity!.mp3
# ----------------------------
# https://www.youtube.com/watch?v=hZKk5iXmGG0
# 데이터가 이미 존재합니다.
# ../downloads/고박사 유니티 기술
# 파일이 이미 존재합니다: ../downloads/고박사 유니티 기술/직선, 유도, 곡선 발사체 (1) how to create straight, homing, bezier curve projectile in Unity!.mp3
# ----------------------------
# https://www.youtube.com/watch?v=9X13qf62UQA
# 데이터가 이미 존재합니다.
# ../downloads/고박사 유니티 기술
# 파일이 이미 존재합니다: ../downloads/고박사 유니티 기술/직선, 유도, 곡선 발사체 (2) how to create straight, homing, bezier curve projectile in Unity!.mp3
# ----------------------------
# https://www.youtube.com/watch?v=BVqMfq_ilbA
# 데이터가 이미 존재합니다.
# ../downloads/고박사 유니티 기술
# 파일이 이미 존재합니다: ../downloads/고박사 유니티 기술/[유니티6] 다중 언어 지원 how to use Localization in Unity!.mp3
# ----------------------------
# https://www.youtube.com/watch?v=6bg1ltzFor0
# 데이터가 이미 존재합니다.
# ../downloads/고박사 유니티 기술
# 파일이 이미 존재합니다: ../downloads/고박사 유니티 기술/[유니티6] 아이템 수집 효과 how to create Item Collect Effect in Unity!.mp3
# ----------------------------
# https://www.youtube.com/watch?v=y6omNlRAN3Q
# 데이터가 이미 존재합니다.
# ../downloads/고박사 유니티 기술
# 파일이 이미 존재합니다: ../downloads/고박사 유니티 기술/[유니티6] 2D 길 찾기 인공지능 how to use Navmesh 2D in Unity!.mp3
# ----------------------------
# https://www.youtube.com/watch?v=ZbWbxlCQ6cA
# 데이터가 이미 존재합니다.
# ../downloads/고박사 유니티 기술
# 파일이 이미 존재합니다: ../downloads/고박사 유니티 기술/[유니티6] Behavior Tree를 이용한 AI 구현 (순찰) [1/3]   how to use Behavior Tree in Unity!.mp3
# ----------------------------
# https://www.youtube.com/watch?v=Oa2LW2rxb48
# 데이터가 이미 존재합니다.
# ../downloads/고박사 유니티 기술
# 파일이 이미 존재합니다: ../downloads/고박사 유니티 기술/[유니티6] Behavior Tree를 이용한 AI 구현 (대기, 순찰, 배회) [2/3].mp3
# ----------------------------
# https://www.youtube.com/watch?v=mRH0i0iqQAM
# 데이터가 이미 존재합니다.
# ../downloads/고박사 유니티 기술
# 파일이 이미 존재합니다: ../downloads/고박사 유니티 기술/[유니티6] Behavior Tree를 이용한 AI 구현 (추적, 공격) [3/3].mp3
# ----------------------------
# 데이터가 이미 존재합니다.
# ../downloads/유니티 코리아
# 파일이 이미 존재합니다: ../downloads/유니티 코리아/[유니티 TIPS] 새로워진 길찾기 AI Navigation 2.0 공략.mp3
# ----------------------------
# 데이터가 이미 존재합니다.
# ../downloads/오늘코딩
# 파일이 이미 존재합니다: ../downloads/오늘코딩/유니티 시네머신 1 - 기본 컴포넌트 알아보기.mp3
# ----------------------------
# 데이터가 이미 존재합니다.
# ../downloads/오늘코딩
# 파일이 이미 존재합니다: ../downloads/오늘코딩/2개 이상의 애니메이션을 하나로 합쳐서 표현하는 방법.mp3
# ----------------------------
# 데이터가 이미 존재합니다.
# ../downloads/오늘코딩
# 파일이 이미 존재합니다: ../downloads/오늘코딩/체력에 따라 애니메이션이 달라지는 방법.mp3
# ----------------------------
# 데이터가 이미 존재합니다.
# ../downloads/오늘코딩
# 파일이 이미 존재합니다: ../downloads/오늘코딩/유니티 애니메이션 총정리 1편 - 기초 설명 및 구현.mp3
# ----------------------------
# 데이터가 이미 존재합니다.
# ../downloads/오늘코딩
# 파일이 이미 존재합니다: ../downloads/오늘코딩/유니티 애니메이션 총정리 2편 -  트랜지션과 파라미터 설명.mp3
# ----------------------------
# 데이터가 이미 존재합니다.
# ../downloads/오늘코딩
# 파일이 이미 존재합니다: ../downloads/오늘코딩/[유니티] 클릭 이동 구현하기 | Navigation(NavMesh).mp3
# ----------------------------
# 데이터가 이미 존재합니다.
# ../downloads/오늘코딩
# 파일이 이미 존재합니다: ../downloads/오늘코딩/[유니티] 클릭 이동 구현하기 2 | Navigation(NavMesh).mp3
# ----------------------------
# 데이터가 이미 존재합니다.
# ../downloads/오늘코딩
# 파일이 이미 존재합니다: ../downloads/오늘코딩/이제는 필수가 되어버린 고급네비메쉬.mp3
# ----------------------------
# 데이터가 이미 존재합니다.
# ../downloads/베르
# 파일이 이미 존재합니다: ../downloads/베르/애니메이션 리타게팅 | 유니티.mp3
# ----------------------------
# 데이터가 이미 존재합니다.
# ../downloads/배르
# 파일이 이미 존재합니다: ../downloads/배르/애니메이션 샘플 레이트 | 유니티.mp3
# ----------------------------
