# %%
# !pip install dependency-injector

# %%
from app.app_container import AppContainer

container = AppContainer()
service = container.youtube_content_service()

contents = service.list_all_content()
for content in contents:
    print(content.title)
# Out:
# Connected to MongoDB
# 2D 오브젝트🧍만들기 [유니티 뱀서라이크 01]
# 플레이어 이동🚶구현하기 [유니티 뱀서라이크 02]
# 새로운 인풋시스템🎮적용하기 [유니티 뱀서라이크 02+]
# 2D 셀 애니메이션🏃제작하기 [유니티 뱀서라이크 03]
# 무한🌍맵 이동 [유니티 뱀서라이크 04]
# 몬스터🧟만들기 [유니티 뱀서라이크 05]
# 오브젝트 풀링🏊으로 소환하기 [유니티 뱀서라이크 06]
# 소환 레벨⏳적용하기 [유니티 뱀서라이크 06+]
# 회전하는🪓근접무기 구현 [유니티 뱀서라이크 07]
# 자동🎯원거리 공격 구현 [유니티 뱀서라이크 08]
# 타격감🌟있는 몬스터 처치 만들기 [유니티 뱀서라이크 09]
# HUD📐제작하기 [유니티 뱀서라이크 10]
# 능력 업그레이드💪구현 [유니티 뱀서라이크 11]
# 플레이어 무기 장착 표현하기 [유니티 뱀서라이크 11+]
# 레벨업🥳시스템 [유니티 뱀서라이크 12]
# 게임 시작과 종료 [유니티 뱀서라이크 13]
# 플레이 캐릭터🧑‍🤝‍🧑선택 [유니티 뱀서라이크 14]
# 캐릭터 해금🔓시스템 [유니티 뱀서라이크 14+]
# 편리한 오디오🔊시스템 구축 [유니티 뱀서라이크 15]
# 로직🛠️보완하기 [유니티 뱀서라이크 16]
# 모바일📱빌드하기 [유니티 뱀서라이크 17]
# 2D 종스크롤 슈팅 -  플레이어 이동 구현하기 [유니티 기초 강좌 B27 + 에셋 다운로드]
# 2D 종스크롤 슈팅 -  총알발사 구현하기 [유니티 기초 강좌 B28]
# 2D 종스크롤 슈팅 -  적 비행기 만들기 [유니티 기초 강좌 B29]
# 2D 종스크롤 슈팅 -  적 전투와 피격 이벤트 만들기 [유니티 기초 강좌 B30]
# 2D 종스크롤 슈팅 -  UI 간단하게 완성하기 [유니티 기초 강좌 B31]
# 2D 종스크롤 슈팅 - 아이템과 필살기 구현하기 [유니티 기초 강좌 B32]
# 2D 종스크롤 슈팅 - 원근감있는 무한 배경 만들기 [유니티 기초 강좌 B33]
# ...
