# %%
from infrastructure.database.mongo_client import MongoDBClient
from infrastructure.repository import YouTubeContentRepository

import os
from dotenv import load_dotenv

load_dotenv()

# MongoDB 클라이언트 초기화
client = MongoDBClient(uri=os.environ['MONGO_CONNECTION_STRING'])
client.connect()

# 저장소 초기화
repository = YouTubeContentRepository(client)
# Out:
# Connected to MongoDB

# %%
contents = repository.find_all()

content = contents[0]

video_link = content.url

import yt_dlp
import requests

def get_meta(video_link):
    ydl_opts = {
        'quiet': True,
        'skip_download': True,  # 영상 다운로드 생략
        'writeautomaticsub': True,  # 자동 생성된 자막 활성화
        'http_headers': {
            'Accept-Language': 'ko',  # HTTP 요청에 한국어 언어 설정
        },
    }
    video_url = video_link.url
    with yt_dlp.YoutubeDL(ydl_opts) as ydl:
        info = ydl.extract_info(video_url, download=False)
        # 자동 생성된 자막 확인
        captions = info.get('automatic_captions', {}).get('ko')

        if captions:
            json_url = captions[0]['url']  # 첫 번째 JSON 링크 가져오기
            print(f"Subtitles JSON URL: {json_url}")

            # JSON 데이터 요청
            response = requests.get(json_url)
            if response.status_code == 200:
                return response.json()  # JSON 데이터 반환
            else:
                print("Failed to fetch subtitle JSON.")
                return None
        else:
            raise Exception("자막이 없습니다.")

print(content.url)
def parse_subtitles(json_data):
    """JSON 데이터에서 자막 텍스트를 추출합니다."""
    events = json_data.get('events', [])
    subtitles = []

    for event in events:
        segments = event.get('segs', [])
        for seg in segments:
            text = seg.get('utf8', '') # 자막 텍스트를 가져옴
            if text:  # 빈 문자열이 아닌 경우에만 추가
                # 이전 텍스트와 이어붙이는 방식으로 처리
                text = text.replace('\n', ' ')
                subtitles.append(text)  # 새로운 문장 시작

    return ''.join(subtitles)  # 전체 텍스트 반환
a = get_meta(video_link)
print(a)
print(parse_subtitles(a))
# Out:
# https://www.youtube.com/watch?v=qOTbP9ciJ88
# Subtitles JSON URL: https://www.youtube.com/api/timedtext?v=qOTbP9ciJ88&ei=wkKXZ6joNuSW1d8Ph6Tv4A8&caps=asr&opi=112496729&xoaf=5&hl=en&ip=0.0.0.0&ipbits=0&expire=1737991474&sparams=ip%2Cipbits%2Cexpire%2Cv%2Cei%2Ccaps%2Copi%2Cxoaf&signature=301E795F47F26030DA79937EB85765A00720D08C.7CFD26591EF55C9C8930CC379E1047B956622ACF&key=yt8&kind=asr&lang=ko&fmt=json3
# {'wireMagic': 'pb3', 'pens': [{}], 'wsWinStyles': [{}, {'mhModeHint': 2, 'juJustifCode': 0, 'sdScrollDir': 3}], 'wpWinPositions': [{}, {'apPoint': 6, 'ahHorPos': 20, 'avVerPos': 100, 'rcRows': 2, 'ccCols': 40}], 'events': [{'tStartMs': 0, 'dDurationMs': 1481499, 'id': 1, 'wpWinPosId': 1, 'wsWinStyleId': 1}, {'tStartMs': 0, 'dDurationMs': 11880, 'wWinId': 1, 'segs': [{'utf8': '[음악]'}]}, {'tStartMs': 7789, 'dDurationMs': 4091, 'wWinId': 1, 'aAppend': 1, 'segs': [{'utf8': '\n'}]}, {'tStartMs': 7799, 'dDurationMs': 4081, 'wWinId': 1, 'segs': [{'utf8': '자', 'acAsrConf': 222}, {'utf8': ' 여러분들', 'tOffsetMs': 481, 'acAsrConf': 222}, {'utf8': ' 반갑습니다', 'tOffsetMs': 840, 'acAsrConf': 222}, {'utf8': ' 이번에는', 'tOffsetMs': 1081, 'acAsrConf': 222}]}, {'tStartMs': 12049, 'wWinId': 1, 'aAppend': 1, 'segs': [{'utf8': '\n'}]}, {'tStartMs': 12059, 'dDurationMs': 2281, 'wWinId': 1, 'segs': [{'utf8': '뱀사이크', 'acAsrConf': 222}]}, {'tStartMs': 13009, 'dDurationMs': 1331, 'wWinId': 1, 'aAppend': 1, 'segs': [{'utf8': '\n'}]}, {'tStartMs': 13019, 'dDurationMs': 3360, 'wWinId': 1, 'segs': [{'utf8': '언제든', 'acAsrConf': 222}, {'utf8': ' 서바이버', 'tOffsetMs': 301, 'acAsrConf': 222}, {'utf8': ' 개발에', 'tOffsetMs': 660, 'acAsrConf': 222}, {'utf8': ' 첫', 'tOffsetMs': 1261, 'acAsrConf': 222}, {'utf8': ' 번째', 'tOffsetMs': 1321, 'acAsrConf': 222}]}, {'tStartMs': 14330, 'dDurationMs': 2049, 'wWinId': 1, 'aAppend': 1, 'segs': [{'utf8': '\n'}]}, {'tStartMs': 14340, 'dDurationMs': 4920, 'wWinId': 1, 'segs': [{'utf8': '시간으로서', 'acAsrConf': 222}, {'utf8': ' 일단', 'tOffsetMs': 540, 'acAsrConf': 222}, {'utf8': ' 유니티를', 'tOffsetMs': 1020, 'acAsrConf': 222}, {'utf8': ' 한번', 'tOffsetMs': 1859, 'acAsrConf': 222}]}, {'tStartMs': 16369, 'dDurationMs': 2891, 'wWinId': 1, 'aAppend': 1, 'segs': [{'utf8': '\n'}]}, {'tStartMs': 16379, 'dDurationMs': 4021, 'wWinId': 1, 'segs': [{'utf8': '설치해보고', 'acAsrConf': 222}, {'utf8': ' 자', 'tOffsetMs': 541, 'acAsrConf': 222}, {'utf8': ' 브레이트', 'tOffsetMs': 1381, 'acAsrConf': 222}, {'utf8': ' 시합과', 'tOffsetMs': 1681, 'acAsrConf': 222}, {'utf8': ' 그', 'tOffsetMs': 1921, 'acAsrConf': 222}]}, {'tStartMs': 19250, 'dDurationMs': 1150, 'wWinId': 1, 'aAppend': 1, 'segs': [{'utf8': '\n'}]}, {'tStartMs': 19260, 'dDurationMs': 3000, 'wWinId': 1, 'segs': [{'utf8': '다음에', 'acAsrConf': 222}, {'utf8': ' 플레이어를', 'tOffsetMs': 300, 'acAsrConf': 222}]}, {'tStartMs': 20390, 'dDurationMs': 1870, 'wWinId': 1, 'aAppend': 1, 'segs': [{'utf8': '\n'}]}, {'tStartMs': 20400, 'dDurationMs': 3420, 'wWinId': 1, 'segs': [{'utf8': '간단하게', 'acAsrConf': 222}, {'utf8': ' 만들어', 'tOffsetMs': 180, 'acAsrConf': 222}, {'utf8': ' 보는', 'tOffsetMs': 959, 'acAsrConf': 222}]}, {'tStartMs': 22250, 'dDurationMs': 1570, 'wWinId': 1, 'aAppend': 1, 'segs': [{'utf8': '\n'}]}, {'tStartMs': 22260, 'dDurationMs': 3179, 'wWinId': 1, 'segs': [{'utf8': '방법에', 'acAsrConf': 222}, {'utf8': ' 대해서', 'tOffsetMs': 240, 'acAsrConf': 222}, {'utf8': ' 같이', 'tOffsetMs': 359, 'acAsrConf': 222}, {'utf8': ' 한번', 'tOffsetMs': 779, 'acAsrConf': 222}]}, {'tStartMs': 23810, 'dDurationMs': 1629, 'wWinId': 1, 'aAppend': 1, 'segs': [{'utf8': '\n'}]}, {'tStartMs': 23820, 'dDurationMs': 3600, 'wWinId': 1, 'segs': [{'utf8': '진행', 'acAsrConf': 222}, {'utf8': ' 좀', 'tOffsetMs': 119, 'acAsrConf': 222}, {'utf8': ' 해보도록', 'tOffsetMs': 180, 'acAsrConf': 222}, {'utf8': ' 하겠습니다', 'tOffsetMs': 539, 'acAsrConf': 222}, {'utf8': ' 그래서', 'tOffsetMs': 719, 'acAsrConf': 222}]}, {'tStartMs': 25429, 'dDurationMs': 1991, 'wWinId': 1, 'aAppend': 1, 'segs': [{'utf8': '\n'}]}, {'tStartMs': 25439, 'dDurationMs': 4561, 'wWinId': 1, 'segs': [{'utf8': '여러분들', 'acAsrConf': 222}, {'utf8': ' 뭐', 'tOffsetMs': 721, 'acAsrConf': 222}, {'utf8': ' 네이버나', 'tOffsetMs': 961, 'acAsrConf': 222}, {'utf8': ' 아니면', 'tOffsetMs': 1441, 'acAsrConf': 222}]}, {'tStartMs': 27410, 'dDurationMs': 2590, 'wWinId': 1, 'aAppend': 1, 'segs': [{'utf8': '\n'}]}, {'tStartMs': 27420, 'dDurationMs': 4140, 'wWinId': 1, 'segs': [{'utf8': '구글에다가', 'acAsrConf': 222}, {'utf8': ' 유니티', 'tOf ...
# [음악] 자 여러분들 반갑습니다 이번에는 뱀사이크 언제든 서바이버 개발에 첫 번째 시간으로서 일단 유니티를 한번 설치해보고 자 브레이트 시합과 그 다음에 플레이어를 간단하게 만들어 보는 방법에 대해서 같이 한번 진행 좀 해보도록 하겠습니다 그래서 여러분들 뭐 네이버나 아니면 구글에다가 유니티 검색하셔서 이렇게 공식 홈페이지 들어오시면 되는데요 유니티.com/h 다운로드 버튼이 있어요 자 들어가시고요 [음악] 그러면 여기 또 윈도우용 다운로드 했습니다 물론 또 이제 ius는 다운로드도 아래에서 할 수 있으니깐요 확인을 하시면 좋겠습니다 그래서 버튼 눌러서 자 다운로드 하시고요 그러면 유니티 에디터 설치 파일이 나오는게 아니고 허브 설치 파일이 나옵니다 자 이거 누르셔서 밑에 허브부터 설치를 하시는게 좋겠습니다 그래서 설치 동의함 눌러주고요 자 한 가지 제가 추천드리는 사항은요이 유니티 허브나 아니면 다른 거 설치하실 때 보통은 주드라이버 내에다가 바로 여러분들이 따로 이제 뭐 유니티 허브 프린트 폴드를 만드시고 거기에 설치하시는 것을 추천드립니다 그래야 유니티 파일들을 관리하기가 상당히 쉽거든요 그래서 이런 식으로 깔끔하게 정리해서 설치를 하시는 것을 추천드립니다 그래서 설치를 완료했으면요 이렇게 유니티 허브가 나올 겁니다 자 지금 보시는 리치허브 3.3 버전이네요 가장 첫 번째 해야한 것은 바로 로그인입니다 여러분들 당연히 유니티 개인 계정 로그인 계정이 필요하구요 그거를 여기에서 로그인 해 주셔야 됩니다 그렇게 되면은 여러분들 라이센스를 다 가지게 되는데요 우리가 보통 말하고 있는 유니티는 유니티 에디터입니다 그래서 에디터는 여기 설치 태백 보시면은 이렇게 설치를 할 수 있어요 저는 이미 2021.2 버전 그리고 2021 버전 같이 설치가 되어 있습니다 자 그런데이 에디터도 허브와 마찬가지로 여러분들 드라이버 바로 다음에 설치하는 편이 정말 좋거든요 그래서 자 여기 톱니바퀴 환경 설정 눌러 보시면은 프로젝트가 있습니다 그래서 프로젝트 위치를 미리 사전 때문에 지정을 할 수 있는데요 저는 이렇게 c 드라이브 바로 아래에다가 유니티 플레이트라는 폴더를 새로 만들어서 딱 지점을 해냈습니다 자 이렇게 해두면은 나중에 여러분께서 플랫폼 빌드 할 때이 한글 폴더에 의해서 문제가 발생하지가 않아요 괜찮죠 그래서 미리 이렇게 하는 걸 추천드리고요 마찬가지로 설치 탭에 가시면은 에디터 그리고 컨텐츠 이런 식으로도 깔끔하게 제가 정리했으니까요 아 이런 식으로 바로 드라이버 아래에 두른거를 적극 추천드립니다 자 이렇게 하면은 자 제 c드라이브 한번 보여 드릴게요 와 깔끔하죠 유니드 컨텐츠 에디터 허브 브레이트 한꺼번에 다 볼 수 있다는 점 참고하시고요 그럼 이제 에디터를 설치할 거 아닙니까 저는 이미 에디터 설치되어 있지만 여러분들 아마 없을 거예요 그래서 에디터를 설치 버튼을 눌러 주시고 이번 뱀사라이크 서바이버는 2021.3 lts 버전으로 진행합니다 해서 요거 맨 위에 거 설치를 진행해 주시면 되겠구요 아 근데 설치하실 때 주의할 점 자 일단 저는 설치가 이미 됐기 때문에 아래 거 누르면서 예시를 한번 들어보겠습니다 아마 처음 설치하실 분들은 그 코드 스크립트 코드를 이렇게 에디터 해주는 마이크로소프트 비주얼 스튜디오도 같이 필요합니다 그래서 여기 아마 체크 되어 있을 거예요네 저도 체크 되어 있죠 그리고 나중에 자 거의 마지막 부분에는이 안드로이드 빌드도 같이 할 거기 때문에 꼭 여러분들 플랫폼 안드로이드 필드 서포트에 체크해 주시면 좋겠습니다 그럼 오픈 jdk 안드로이드 k와 ndk까지요 3개 꼭 같이 체크하시고 계속을 눌러주셔서 설치를 해주시면 좋겠습니다 자 이렇게 모든 설치 완료됐고요 만약에 이미 설치된 무도 있다 근데 안드로이드만 설치가 안 돼 있어요라고 할 때는 어떻게 됐냐 여기 톱니바퀴 뭐야 눌러주시고요 모듈 추가 해주신 다음에 플랫폼에서 여기 안드로이드 체크하시고 계속하시면 모듈만 따로 설치가 된다는 점 자이 점 확인했으면 좋겠습니다 되셨나요 자 그러면 이제 플레이트 한번 만들어 볼게요 플레이트 탭 가지고 새플렉트 가시면 되겠습니다 맨 위에 2d가 있긴 있어요 자 근데 요즘은 또 이제 유니티가 그 urp에 대해서 퍼포먼스라든가 그래픽이라든가 이러한 많은 기능들을 계속 꾸준히 업데이트 하기 때문에 요즘은 urp를 드러나는 것도 참 좋아요 그래서 우리는요 2D urp를 한번 진행을 해보도록 하겠습니다 자 에디터 버전 확인하시고요 22003.13 lts 맞네 그래 자 그래서 제 프로젝트 이름은 언데드 좋군요 이렇게 이름을 짓도록 하겠습니다 자 위치 꼭 확인해 주시고요 자 한글 폴더가 없어야 됩니다 되었으면 프로젝트 생성 자 누르면서 페이트를 만들어 보도록 하겠습니다 자 2021 버전은 이렇게 그림이 뛰면서 자 오픈 플레이트 생성하고 있을 텐데요 요거는 여러분들 컴퓨터 환경에 따라서 속도가 다르다는 점 참고하시면서 느긋하게 한번 기다려 보도록 하겠습니다 [음악] 자 그래서 이렇게 프로젝트 생성이 완료되었으면 에디터 창이 나올 것인데요 플랫폼 그리고 유니티치 에디터 버전과 그리고 라이센스 다이렉트 버전 몇인지 이렇게 쭉 나올 것입니다 그 아래쪽에는 이렇게 메뉴 있을 거예요 쭉 메뉴가 됐구요 그리고 자 6가지의 주요 인터페이스 창이 있는데 자 지금 이러한 사항들은 따로 제가 설명드리지 않을게요 혹시나 지금 아예 유니티를 처음 키신 분은 제 그러니까 입문 강좌 영상을 한번 보시면은 좀 더 이해하기 쉬울 거니깐요 그쪽을 참고하시면 좋을 것 같습니다 이번에 뱀프라이크 언데드 서바이벌 강좌는요 조금 빠르게 진행한다는 점 참고해 주시고요 자 그러면 보통 저는 강조할 때는요 깔끔하죠 그렇다면 이제 본격적으로 한번 언제든 서버에 착수해 보도록 하겠습니다 [음악] 다운로드 버튼 눌러주시고 받아보시면 되겠습니다 자 받았으면요 이렇게 자 g8이 나오는데 일단 요거 압축을 해제를 해주세요 해제가 되었으면 이런 식으로 서바이버 유니티 패키지가 나올 겁니다 자 이거를 넣어 주셔야 돼요 어디에다가 바로이 유니티 에디터에다가 넣어 주셔야 됩니다 넣는 방법은 이거를 그냥 더블 클릭하셔도 되고요 아니면은 이걸 드래그 하셔서 여기 프랜차 아래다가 드랍을 해주시면 되겠습니다 자 전 드래그 드랍 할게요 드래그 드랍을 하시게 되면은 이렇게 임포트 일렉트 패키지 넣으면서 이렇게 여러가지 내용물들이 나오게 되는데 그냥 임포트 해주시면 되겠습니다 보시면이 에셋이라고 하는 폴더 아래에 보시면 언제든 서바이버라고 있습니다 그렇죠 자 이렇게 압축이 풀리면서 여러가지 에셋들이 포함이 되어 있고요 그리고 뭐 라이센스에 대해서 궁금하신 분들 계실 거예요 자 여기에 대해서는 제가 리듬이 코리아 열어 보시게 되면 이렇게 제가 문서를 제공을 해 드리고 있습니다 그렇죠 그래서 강좌 외에도 뭐 개인 학습용 뭐 과제용 아니면 여러분께서 직접 만든 개인 상용 프랜드까지 자유롭게 사용이 가능하니까 이점 참고하시면 좋겠습니다 내 마음껏 해주세요네 여러분께서 개조하셔도 상관없습니다 그러면 여기에서 이제 한번 이틀들을 사용을 해서 이제 플레이어를 만들어야겠죠 자 그럼 플레이를 한번 만들어 볼 건데요 그 전에 자 지금이 창을 편리하게 쓰도록 요걸 살짝 커스텀을 재볼 건데요요 창에 이름 있죠 이름 탭을 꾹 누르시면은 이렇게 자유롭게 이동할 수 있는데요 이번에는 이런 식으로 한번 창을 한번 이렇게 변경을 해 보도록 하겠습니다 그래서 어쨌든 나중에 여러분 이제 모바일로 할 거기 때문에요 이런 느낌으로 한번 세팅을 해보시면 어떨까 합니다 자 그럼 여기서 이제 플레이어를 놓으려면 이미지가 필요하죠 자 게임 개발에서는 보통 이미지를 스프라이트라고 부릅니다 스프레이트 폴더 들어가시면은 다양한 스프라이트들이 이렇게 쭉 있는데요 보통 이제 우리가 게임을 개발할 때 뭐 아트 직군이 따로 있다 하시면 그 아트 분들께서 도트나 아니면 2D 만드실 때는 보통 이런 식으로 묶어서 주는 경우가 있어요 자 요런 것들을 우리는 아틀라스 혹은 리스프라이트 시트라고 부릅니다 근데 요거 이제 잘라야 하잖아요 그쵸 이거를 그대로 통째로 갖다 쓰기에는 조금 무리가 있습니다 이런 식으로요 아 좀 그래요 그쵸 그래서 잘랐어야 되는데 그 짤라 쓰는  ...

# %%
contents = repository.find_all()

content = contents[0]
video_link = content.url

from application.strategy import AutoYoutubeStrategy

stt_strategy = AutoYoutubeStrategy()

result = stt_strategy.transcribe(video_link.url)

# %%
print(result)
# Out:
# {'wireMagic': 'pb3', 'pens': [{}], 'wsWinStyles': [{}, {'mhModeHint': 2, 'juJustifCode': 0, 'sdScrollDir': 3}], 'wpWinPositions': [{}, {'apPoint': 6, 'ahHorPos': 20, 'avVerPos': 100, 'rcRows': 2, 'ccCols': 40}], 'events': [{'tStartMs': 0, 'dDurationMs': 1481499, 'id': 1, 'wpWinPosId': 1, 'wsWinStyleId': 1}, {'tStartMs': 0, 'dDurationMs': 11880, 'wWinId': 1, 'segs': [{'utf8': '[음악]'}]}, {'tStartMs': 7789, 'dDurationMs': 4091, 'wWinId': 1, 'aAppend': 1, 'segs': [{'utf8': '\n'}]}, {'tStartMs': 7799, 'dDurationMs': 4081, 'wWinId': 1, 'segs': [{'utf8': '자', 'acAsrConf': 222}, {'utf8': ' 여러분들', 'tOffsetMs': 481, 'acAsrConf': 222}, {'utf8': ' 반갑습니다', 'tOffsetMs': 840, 'acAsrConf': 222}, {'utf8': ' 이번에는', 'tOffsetMs': 1081, 'acAsrConf': 222}]}, {'tStartMs': 12049, 'wWinId': 1, 'aAppend': 1, 'segs': [{'utf8': '\n'}]}, {'tStartMs': 12059, 'dDurationMs': 2281, 'wWinId': 1, 'segs': [{'utf8': '뱀사이크', 'acAsrConf': 222}]}, {'tStartMs': 13009, 'dDurationMs': 1331, 'wWinId': 1, 'aAppend': 1, 'segs': [{'utf8': '\n'}]}, {'tStartMs': 13019, 'dDurationMs': 3360, 'wWinId': 1, 'segs': [{'utf8': '언제든', 'acAsrConf': 222}, {'utf8': ' 서바이버', 'tOffsetMs': 301, 'acAsrConf': 222}, {'utf8': ' 개발에', 'tOffsetMs': 660, 'acAsrConf': 222}, {'utf8': ' 첫', 'tOffsetMs': 1261, 'acAsrConf': 222}, {'utf8': ' 번째', 'tOffsetMs': 1321, 'acAsrConf': 222}]}, {'tStartMs': 14330, 'dDurationMs': 2049, 'wWinId': 1, 'aAppend': 1, 'segs': [{'utf8': '\n'}]}, {'tStartMs': 14340, 'dDurationMs': 4920, 'wWinId': 1, 'segs': [{'utf8': '시간으로서', 'acAsrConf': 222}, {'utf8': ' 일단', 'tOffsetMs': 540, 'acAsrConf': 222}, {'utf8': ' 유니티를', 'tOffsetMs': 1020, 'acAsrConf': 222}, {'utf8': ' 한번', 'tOffsetMs': 1859, 'acAsrConf': 222}]}, {'tStartMs': 16369, 'dDurationMs': 2891, 'wWinId': 1, 'aAppend': 1, 'segs': [{'utf8': '\n'}]}, {'tStartMs': 16379, 'dDurationMs': 4021, 'wWinId': 1, 'segs': [{'utf8': '설치해보고', 'acAsrConf': 222}, {'utf8': ' 자', 'tOffsetMs': 541, 'acAsrConf': 222}, {'utf8': ' 브레이트', 'tOffsetMs': 1381, 'acAsrConf': 222}, {'utf8': ' 시합과', 'tOffsetMs': 1681, 'acAsrConf': 222}, {'utf8': ' 그', 'tOffsetMs': 1921, 'acAsrConf': 222}]}, {'tStartMs': 19250, 'dDurationMs': 1150, 'wWinId': 1, 'aAppend': 1, 'segs': [{'utf8': '\n'}]}, {'tStartMs': 19260, 'dDurationMs': 3000, 'wWinId': 1, 'segs': [{'utf8': '다음에', 'acAsrConf': 222}, {'utf8': ' 플레이어를', 'tOffsetMs': 300, 'acAsrConf': 222}]}, {'tStartMs': 20390, 'dDurationMs': 1870, 'wWinId': 1, 'aAppend': 1, 'segs': [{'utf8': '\n'}]}, {'tStartMs': 20400, 'dDurationMs': 3420, 'wWinId': 1, 'segs': [{'utf8': '간단하게', 'acAsrConf': 222}, {'utf8': ' 만들어', 'tOffsetMs': 180, 'acAsrConf': 222}, {'utf8': ' 보는', 'tOffsetMs': 959, 'acAsrConf': 222}]}, {'tStartMs': 22250, 'dDurationMs': 1570, 'wWinId': 1, 'aAppend': 1, 'segs': [{'utf8': '\n'}]}, {'tStartMs': 22260, 'dDurationMs': 3179, 'wWinId': 1, 'segs': [{'utf8': '방법에', 'acAsrConf': 222}, {'utf8': ' 대해서', 'tOffsetMs': 240, 'acAsrConf': 222}, {'utf8': ' 같이', 'tOffsetMs': 359, 'acAsrConf': 222}, {'utf8': ' 한번', 'tOffsetMs': 779, 'acAsrConf': 222}]}, {'tStartMs': 23810, 'dDurationMs': 1629, 'wWinId': 1, 'aAppend': 1, 'segs': [{'utf8': '\n'}]}, {'tStartMs': 23820, 'dDurationMs': 3600, 'wWinId': 1, 'segs': [{'utf8': '진행', 'acAsrConf': 222}, {'utf8': ' 좀', 'tOffsetMs': 119, 'acAsrConf': 222}, {'utf8': ' 해보도록', 'tOffsetMs': 180, 'acAsrConf': 222}, {'utf8': ' 하겠습니다', 'tOffsetMs': 539, 'acAsrConf': 222}, {'utf8': ' 그래서', 'tOffsetMs': 719, 'acAsrConf': 222}]}, {'tStartMs': 25429, 'dDurationMs': 1991, 'wWinId': 1, 'aAppend': 1, 'segs': [{'utf8': '\n'}]}, {'tStartMs': 25439, 'dDurationMs': 4561, 'wWinId': 1, 'segs': [{'utf8': '여러분들', 'acAsrConf': 222}, {'utf8': ' 뭐', 'tOffsetMs': 721, 'acAsrConf': 222}, {'utf8': ' 네이버나', 'tOffsetMs': 961, 'acAsrConf': 222}, {'utf8': ' 아니면', 'tOffsetMs': 1441, 'acAsrConf': 222}]}, {'tStartMs': 27410, 'dDurationMs': 2590, 'wWinId': 1, 'aAppend': 1, 'segs': [{'utf8': '\n'}]}, {'tStartMs': 27420, 'dDurationMs': 4140, 'wWinId': 1, 'segs': [{'utf8': '구글에다가', 'acAsrConf': 222}, {'utf8': ' 유니티', 'tOf ...

# %%
contents = repository.find_all()

content = contents[0]
video_link = content.url

from application.strategy import STTStrategyFactory, STTStrategyType

stt_strategy = STTStrategyFactory.create(STTStrategyType.AUTO_YOUTUBE)

result = stt_strategy.transcribe_to_script(video_link.url)
print(result)
# Out:
# YouTubeScript(script='[음악] 자 여러분들 반갑습니다 이번에는 뱀사이크 언제든 서바이버 개발에 첫 번째 시간으로...', chunks=[(0.0-11.88: [음악]...), (7.799-11.88: 자 여러분들 반갑습니다 이번...), (12.059-14.34: 뱀사이크...), ...] (641 chunks))

# %%
from infrastructure.database.mongo_client import MongoDBClient
from infrastructure.repository import YouTubeContentRepository

import os
from dotenv import load_dotenv

load_dotenv()

# MongoDB 클라이언트 초기화
client = MongoDBClient(uri=os.environ['MONGO_CONNECTION_STRING'])
client.connect()

# 저장소 초기화
repository = YouTubeContentRepository(client)

from application.strategy import STTStrategyFactory, STTStrategyType

stt_strategy = STTStrategyFactory.create(STTStrategyType.AUTO_YOUTUBE)

contents = repository.find_all()

count = len(contents)
for i, content in enumerate(contents):
    print(f'{i + 1}/{count}: {content.title}')
    script_auto = stt_strategy.transcribe(content.url.url)
    print(script_auto)

    if script_auto is not None:
        print(script_auto)
        pass
        #content.set_script_auto(script_auto)
        #repository.save(content)
    #script_auto = stt_strategy.transcribe(content.url.url)
    #print(script_auto)
    #content.set_script_auto(script_auto)
    #repository.save(content)
# Out:
# Connected to MongoDB
# 1/142: 2D 오브젝트🧍만들기 [유니티 뱀서라이크 01]
# https://www.youtube.com/api/timedtext?v=qOTbP9ciJ88&ei=pE6XZ8aBJtmrvcAPkv2HqA4&caps=asr&opi=112496729&xoaf=5&hl=en&ip=0.0.0.0&ipbits=0&expire=1737994516&sparams=ip%2Cipbits%2Cexpire%2Cv%2Cei%2Ccaps%2Copi%2Cxoaf&signature=BDBE13293A6302A3E027C56FBA0F98ABE699388B.BF8441C7A14CD5DE22F1424F115AAD6EB5BBF775&key=yt8&kind=asr&lang=ko&fmt=json3
# json
# {'wireMagic': 'pb3', 'pens': [{}], 'wsWinStyles': [{}, {'mhModeHint': 2, 'juJustifCode': 0, 'sdScrollDir': 3}], 'wpWinPositions': [{}, {'apPoint': 6, 'ahHorPos': 20, 'avVerPos': 100, 'rcRows': 2, 'ccCols': 40}], 'events': [{'tStartMs': 0, 'dDurationMs': 1481499, 'id': 1, 'wpWinPosId': 1, 'wsWinStyleId': 1}, {'tStartMs': 0, 'dDurationMs': 11880, 'wWinId': 1, 'segs': [{'utf8': '[음악]'}]}, {'tStartMs': 7789, 'dDurationMs': 4091, 'wWinId': 1, 'aAppend': 1, 'segs': [{'utf8': '\n'}]}, {'tStartMs': 7799, 'dDurationMs': 4081, 'wWinId': 1, 'segs': [{'utf8': '자', 'acAsrConf': 222}, {'utf8': ' 여러분들', 'tOffsetMs': 481, 'acAsrConf': 222}, {'utf8': ' 반갑습니다', 'tOffsetMs': 840, 'acAsrConf': 222}, {'utf8': ' 이번에는', 'tOffsetMs': 1081, 'acAsrConf': 222}]}, {'tStartMs': 12049, 'wWinId': 1, 'aAppend': 1, 'segs': [{'utf8': '\n'}]}, {'tStartMs': 12059, 'dDurationMs': 2281, 'wWinId': 1, 'segs': [{'utf8': '뱀사이크', 'acAsrConf': 222}]}, {'tStartMs': 13009, 'dDurationMs': 1331, 'wWinId': 1, 'aAppend': 1, 'segs': [{'utf8': '\n'}]}, {'tStartMs': 13019, 'dDurationMs': 3360, 'wWinId': 1, 'segs': [{'utf8': '언제든', 'acAsrConf': 222}, {'utf8': ' 서바이버', 'tOffsetMs': 301, 'acAsrConf': 222}, {'utf8': ' 개발에', 'tOffsetMs': 660, 'acAsrConf': 222}, {'utf8': ' 첫', 'tOffsetMs': 1261, 'acAsrConf': 222}, {'utf8': ' 번째', 'tOffsetMs': 1321, 'acAsrConf': 222}]}, {'tStartMs': 14330, 'dDurationMs': 2049, 'wWinId': 1, 'aAppend': 1, 'segs': [{'utf8': '\n'}]}, {'tStartMs': 14340, 'dDurationMs': 4920, 'wWinId': 1, 'segs': [{'utf8': '시간으로서', 'acAsrConf': 222}, {'utf8': ' 일단', 'tOffsetMs': 540, 'acAsrConf': 222}, {'utf8': ' 유니티를', 'tOffsetMs': 1020, 'acAsrConf': 222}, {'utf8': ' 한번', 'tOffsetMs': 1859, 'acAsrConf': 222}]}, {'tStartMs': 16369, 'dDurationMs': 2891, 'wWinId': 1, 'aAppend': 1, 'segs': [{'utf8': '\n'}]}, {'tStartMs': 16379, 'dDurationMs': 4021, 'wWinId': 1, 'segs': [{'utf8': '설치해보고', 'acAsrConf': 222}, {'utf8': ' 자', 'tOffsetMs': 541, 'acAsrConf': 222}, {'utf8': ' 브레이트', 'tOffsetMs': 1381, 'acAsrConf': 222}, {'utf8': ' 시합과', 'tOffsetMs': 1681, 'acAsrConf': 222}, {'utf8': ' 그', 'tOffsetMs': 1921, 'acAsrConf': 222}]}, {'tStartMs': 19250, 'dDurationMs': 1150, 'wWinId': 1, 'aAppend': 1, 'segs': [{'utf8': '\n'}]}, {'tStartMs': 19260, 'dDurationMs': 3000, 'wWinId': 1, 'segs': [{'utf8': '다음에', 'acAsrConf': 222}, {'utf8': ' 플레이어를', 'tOffsetMs': 300, 'acAsrConf': 222}]}, {'tStartMs': 20390, 'dDurationMs': 1870, 'wWinId': 1, 'aAppend': 1, 'segs': [{'utf8': '\n'}]}, {'tStartMs': 20400, 'dDurationMs': 3420, 'wWinId': 1, 'segs': [{'utf8': '간단하게', 'acAsrConf': 222}, {'utf8': ' 만들어', 'tOffsetMs': 180, 'acAsrConf': 222}, {'utf8': ' 보는', 'tOffsetMs': 959, 'acAsrConf': 222}]}, {'tStartMs': 22250, 'dDurationMs': 1570, 'wWinId': 1, 'aAppend': 1, 'segs': [{'utf8': '\n'}]}, {'tStartMs': 22260, 'dDurationMs': 3179, 'wWinId': 1, 'segs': [{'utf8': '방법에', 'acAsrConf': 222}, {'utf8': ' 대해서', 'tOffsetMs': 240, 'acAsrConf': 222}, {'utf8': ' 같이', 'tOffsetMs': 359, 'acAsrConf': 222}, {'utf8': ' 한번', 'tOffsetMs': 779, 'acAsrConf': 222}]}, {'tStartMs': 23810, 'dDurationMs': 1629, 'wWinId': 1, 'aAppend': 1, 'segs': [{'utf8': '\n'}]}, {'tStartMs': 23820, 'dDurationMs': 3600, 'wWinId': 1, 'segs': [{'utf8': '진행', 'acAsrConf': 222}, {'utf8': ' 좀', 'tOffsetMs': 119, 'acAsrConf': 222}, {'utf8': ' 해보도록', 'tOffsetMs': 180, 'acAsrConf': 222}, {'utf8': ' 하겠습니다', 'tOffsetMs': 539, 'acAsrConf': 222}, {'utf8': ' 그래서', 'tOffsetMs': 719, 'acAsrConf': 222}]}, {'tStartMs': 25429, 'dDurationMs': 1991, 'wWinId': 1, 'aAppend': 1, 'segs': [{'utf8': '\n'}]}, {'tStartMs': 25439, 'dDurationMs': 4561, 'wWinId': 1, 'segs': [{'utf8': '여러분들', 'acAsrConf': 222}, {'utf8': ' 뭐', 'tOffsetMs': 721, 'acAsrConf': 222}, {'utf8': ' 네이버나', 'tOffsetMs': 961, 'acAsrConf': 222}, {'utf8': ' 아니면', 'tOffsetMs': 1441, 'acAsrConf': 222}]}, {'tStartMs': 27410, 'dDurationMs': 2590, 'wWinId': 1, 'aAppend': 1, 'segs': [{'utf8': '\n'}]}, {'tStartMs': 27420, 'dDurationMs': 4140, 'wWinId': 1, 'segs': [{'utf8': '구글에다가', 'acAsrConf': 222}, {'utf8': ' 유니티', 'tOf ...
# {'wireMagic': 'pb3', 'pens': [{}], 'wsWinStyles': [{}, {'mhModeHint': 2, 'juJustifCode': 0, 'sdScrollDir': 3}], 'wpWinPositions': [{}, {'apPoint': 6, 'ahHorPos': 20, 'avVerPos': 100, 'rcRows': 2, 'ccCols': 40}], 'events': [{'tStartMs': 0, 'dDurationMs': 1481499, 'id': 1, 'wpWinPosId': 1, 'wsWinStyleId': 1}, {'tStartMs': 0, 'dDurationMs': 11880, 'wWinId': 1, 'segs': [{'utf8': '[음악]'}]}, {'tStartMs': 7789, 'dDurationMs': 4091, 'wWinId': 1, 'aAppend': 1, 'segs': [{'utf8': '\n'}]}, {'tStartMs': 7799, 'dDurationMs': 4081, 'wWinId': 1, 'segs': [{'utf8': '자', 'acAsrConf': 222}, {'utf8': ' 여러분들', 'tOffsetMs': 481, 'acAsrConf': 222}, {'utf8': ' 반갑습니다', 'tOffsetMs': 840, 'acAsrConf': 222}, {'utf8': ' 이번에는', 'tOffsetMs': 1081, 'acAsrConf': 222}]}, {'tStartMs': 12049, 'wWinId': 1, 'aAppend': 1, 'segs': [{'utf8': '\n'}]}, {'tStartMs': 12059, 'dDurationMs': 2281, 'wWinId': 1, 'segs': [{'utf8': '뱀사이크', 'acAsrConf': 222}]}, {'tStartMs': 13009, 'dDurationMs': 1331, 'wWinId': 1, 'aAppend': 1, 'segs': [{'utf8': '\n'}]}, {'tStartMs': 13019, 'dDurationMs': 3360, 'wWinId': 1, 'segs': [{'utf8': '언제든', 'acAsrConf': 222}, {'utf8': ' 서바이버', 'tOffsetMs': 301, 'acAsrConf': 222}, {'utf8': ' 개발에', 'tOffsetMs': 660, 'acAsrConf': 222}, {'utf8': ' 첫', 'tOffsetMs': 1261, 'acAsrConf': 222}, {'utf8': ' 번째', 'tOffsetMs': 1321, 'acAsrConf': 222}]}, {'tStartMs': 14330, 'dDurationMs': 2049, 'wWinId': 1, 'aAppend': 1, 'segs': [{'utf8': '\n'}]}, {'tStartMs': 14340, 'dDurationMs': 4920, 'wWinId': 1, 'segs': [{'utf8': '시간으로서', 'acAsrConf': 222}, {'utf8': ' 일단', 'tOffsetMs': 540, 'acAsrConf': 222}, {'utf8': ' 유니티를', 'tOffsetMs': 1020, 'acAsrConf': 222}, {'utf8': ' 한번', 'tOffsetMs': 1859, 'acAsrConf': 222}]}, {'tStartMs': 16369, 'dDurationMs': 2891, 'wWinId': 1, 'aAppend': 1, 'segs': [{'utf8': '\n'}]}, {'tStartMs': 16379, 'dDurationMs': 4021, 'wWinId': 1, 'segs': [{'utf8': '설치해보고', 'acAsrConf': 222}, {'utf8': ' 자', 'tOffsetMs': 541, 'acAsrConf': 222}, {'utf8': ' 브레이트', 'tOffsetMs': 1381, 'acAsrConf': 222}, {'utf8': ' 시합과', 'tOffsetMs': 1681, 'acAsrConf': 222}, {'utf8': ' 그', 'tOffsetMs': 1921, 'acAsrConf': 222}]}, {'tStartMs': 19250, 'dDurationMs': 1150, 'wWinId': 1, 'aAppend': 1, 'segs': [{'utf8': '\n'}]}, {'tStartMs': 19260, 'dDurationMs': 3000, 'wWinId': 1, 'segs': [{'utf8': '다음에', 'acAsrConf': 222}, {'utf8': ' 플레이어를', 'tOffsetMs': 300, 'acAsrConf': 222}]}, {'tStartMs': 20390, 'dDurationMs': 1870, 'wWinId': 1, 'aAppend': 1, 'segs': [{'utf8': '\n'}]}, {'tStartMs': 20400, 'dDurationMs': 3420, 'wWinId': 1, 'segs': [{'utf8': '간단하게', 'acAsrConf': 222}, {'utf8': ' 만들어', 'tOffsetMs': 180, 'acAsrConf': 222}, {'utf8': ' 보는', 'tOffsetMs': 959, 'acAsrConf': 222}]}, {'tStartMs': 22250, 'dDurationMs': 1570, 'wWinId': 1, 'aAppend': 1, 'segs': [{'utf8': '\n'}]}, {'tStartMs': 22260, 'dDurationMs': 3179, 'wWinId': 1, 'segs': [{'utf8': '방법에', 'acAsrConf': 222}, {'utf8': ' 대해서', 'tOffsetMs': 240, 'acAsrConf': 222}, {'utf8': ' 같이', 'tOffsetMs': 359, 'acAsrConf': 222}, {'utf8': ' 한번', 'tOffsetMs': 779, 'acAsrConf': 222}]}, {'tStartMs': 23810, 'dDurationMs': 1629, 'wWinId': 1, 'aAppend': 1, 'segs': [{'utf8': '\n'}]}, {'tStartMs': 23820, 'dDurationMs': 3600, 'wWinId': 1, 'segs': [{'utf8': '진행', 'acAsrConf': 222}, {'utf8': ' 좀', 'tOffsetMs': 119, 'acAsrConf': 222}, {'utf8': ' 해보도록', 'tOffsetMs': 180, 'acAsrConf': 222}, {'utf8': ' 하겠습니다', 'tOffsetMs': 539, 'acAsrConf': 222}, {'utf8': ' 그래서', 'tOffsetMs': 719, 'acAsrConf': 222}]}, {'tStartMs': 25429, 'dDurationMs': 1991, 'wWinId': 1, 'aAppend': 1, 'segs': [{'utf8': '\n'}]}, {'tStartMs': 25439, 'dDurationMs': 4561, 'wWinId': 1, 'segs': [{'utf8': '여러분들', 'acAsrConf': 222}, {'utf8': ' 뭐', 'tOffsetMs': 721, 'acAsrConf': 222}, {'utf8': ' 네이버나', 'tOffsetMs': 961, 'acAsrConf': 222}, {'utf8': ' 아니면', 'tOffsetMs': 1441, 'acAsrConf': 222}]}, {'tStartMs': 27410, 'dDurationMs': 2590, 'wWinId': 1, 'aAppend': 1, 'segs': [{'utf8': '\n'}]}, {'tStartMs': 27420, 'dDurationMs': 4140, 'wWinId': 1, 'segs': [{'utf8': '구글에다가', 'acAsrConf': 222}, {'utf8': ' 유니티', 'tOf ...
# 2/142: 플레이어 이동🚶구현하기 [유니티 뱀서라이크 02]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 25
#      23 for i, content in enumerate(contents):
#      24     print(f'{i + 1}/{count}: {content.title}')
# ---> 25     script_auto = stt_strategy.transcribe(content.url.url)
#      26     print(script_auto)
#      28     if script_auto is not None:
#
# File ~/Documents/GitHub/LumenaAI/application/strategy/stt/auto_youtube_strategy.py:22, in AutoYoutubeStrategy.transcribe(self, audio_link)
#      12 ydl_opts = {
#      13     'quiet': True,
#      14     'skip_download': True,  # 영상 다운로드 생략
#    (...)
#      18     },
#      19 }
#      21 with yt_dlp.YoutubeDL(ydl_opts) as ydl:
# ---> 22     info = ydl.extract_info(audio_link, download=False)
#      24     captions = info.get('automatic_captions', {}).get('ko')
#      26     if not captions:
#
# File ~/.conda/envs/LumenaAI/lib/python3.10/site-packages/yt_dlp/YoutubeDL.py:1626, in YoutubeDL.extract_info(self, url, download, ie_key, extra_info, process, force_generic_extractor)
#    1624             raise ExistingVideoReached
#    1625         break
# -> 1626     return self.__extract_info(url, self.get_info_extractor(key), download, extra_info, process)
#    1627 else:
#    1628     extractors_restricted = self.params.get('allowed_extractors') not in (None, ['default'])
#
# File ~/.conda/envs/LumenaAI/lib/python3.10/site-packages/yt_dlp/YoutubeDL.py:1637, in YoutubeDL._handle_extraction_exceptions.<locals>.wrapper(self, *args, **kwargs)
#    1635 while True:
#    1636     try:
# -> 1637         return func(self, *args, **kwargs)
#    1638     except (CookieLoadError, DownloadCancelled, LazyList.IndexError, PagedList.IndexError):
#    1639         raise
#
# File ~/.conda/envs/LumenaAI/lib/python3.10/site-packages/yt_dlp/YoutubeDL.py:1772, in YoutubeDL.__extract_info(self, url, ie, download, extra_info, process)
#    1769 self._apply_header_cookies(url)
#    1771 try:
# -> 1772     ie_result = ie.extract(url)
#    1773 except UserNotLive as e:
#    1774     if process:
#
# File ~/.conda/envs/LumenaAI/lib/python3.10/site-packages/yt_dlp/extractor/common.py:742, in InfoExtractor.extract(self, url)
#     739 self.initialize()
#     740 self.to_screen('Extracting URL: %s' % (
#     741     url if self.get_param('verbose') else truncate_string(url, 100, 20)))
# --> 742 ie_result = self._real_extract(url)
#     743 if ie_result is None:
#     744     return None
#
# File ~/.conda/envs/LumenaAI/lib/python3.10/site-packages/yt_dlp/extractor/youtube.py:4481, in YoutubeIE._real_extract(self, url)
#    4478 base_url = self.http_scheme() + '//www.youtube.com/'
#    4479 webpage_url = base_url + 'watch?v=' + video_id
# -> 4481 webpage, master_ytcfg, player_responses, player_url = self._download_player_responses(url, smuggled_data, video_id, webpage_url)
#    4483 playability_statuses = traverse_obj(
#    4484     player_responses, (..., 'playabilityStatus'), expected_type=dict)
#    4486 trailer_video_id = get_first(
#    4487     playability_statuses,
#    4488     ('errorScreen', 'playerLegacyDesktopYpcTrailerRenderer', 'trailerVideoId'),
#    4489     expected_type=str)
#
# File ~/.conda/envs/LumenaAI/lib/python3.10/site-packages/yt_dlp/extractor/youtube.py:4445, in YoutubeIE._download_player_responses(self, url, smuggled_data, video_id, webpage_url)
#    4440     webpage = self._download_webpage(
#    4441         webpage_url, video_id, fatal=False, query=query)
#    4443 master_ytcfg = self.extract_ytcfg(video_id, webpage) or self._get_default_ytcfg()
# -> 4445 player_responses, player_url = self._extract_player_responses(
#    4446     self._get_requested_clients(url, smuggled_data),
#    4447     video_id, webpage, master_ytcfg, smuggled_data)
#    4449 return webpage, master_ytcfg, player_responses, player_url
#
# File ~/.conda/envs/LumenaAI/lib/python3.10/site-packages/yt_dlp/extractor/youtube.py:4049, in YoutubeIE._extract_player_responses(self, clients, video_id, webpage, master_ytcfg, smuggled_data)
#    4047 pr = initial_pr if client == 'web' else None
#    4048 try:
# -> 4049     pr = pr or self._extract_player_response(
#    4050         client, video_id,
#    4051         master_ytcfg=player_ytcfg or master_ytcfg,
#    4052         player_ytcfg=player_ytcfg,
#    4053         player_url=player_url,
#    4054         initial_pr=initial_pr,
#    4055         visitor_data=visitor_data,
#    4056         data_sync_id=data_sync_id,
#    4057         po_token=po_token)
#    4058 except ExtractorError as e:
#    4059     self.report_warning(e)
#
# File ~/.conda/envs/LumenaAI/lib/python3.10/site-packages/yt_dlp/extractor/youtube.py:3934, in YoutubeIE._extract_player_response(self, client, video_id, master_ytcfg, player_ytcfg, player_url, initial_pr, visitor_data, data_sync_id, po_token)
#    3932 sts = self._extract_signature_timestamp(video_id, player_url, master_ytcfg, fatal=False) if player_url else None
#    3933 yt_query.update(self._generate_player_context(sts))
# -> 3934 return self._extract_response(
#    3935     item_id=video_id, ep='player', query=yt_query,
#    3936     ytcfg=player_ytcfg, headers=headers, fatal=True,
#    3937     default_client=client,
#    3938     note='Downloading {} player API JSON'.format(client.replace('_', ' ').strip()),
#    3939 ) or None
#
# File ~/.conda/envs/LumenaAI/lib/python3.10/site-packages/yt_dlp/extractor/youtube.py:1105, in YoutubeBaseInfoExtractor._extract_response(self, item_id, query, note, headers, ytcfg, check_get_keys, ep, fatal, api_hostname, default_client)
#    1103 while True:
#    1104     try:
# -> 1105         response = self._call_api(
#    1106             ep=ep, fatal=True, headers=headers,
#    1107             video_id=item_id, query=query, note=note,
#    1108             context=self._extract_context(ytcfg, default_client),
#    1109             api_hostname=api_hostname, default_client=default_client)
#    1110     except ExtractorError as e:
#    1111         if not isinstance(e.cause, network_exceptions):
#
# File ~/.conda/envs/LumenaAI/lib/python3.10/site-packages/yt_dlp/extractor/youtube.py:708, in YoutubeBaseInfoExtractor._call_api(self, ep, query, video_id, fatal, headers, note, errnote, context, api_key, api_hostname, default_client)
#     706 if headers:
#     707     real_headers.update(headers)
# --> 708 return self._download_json(
#     709     f'https://{self._select_api_hostname(api_hostname, default_client)}/youtubei/v1/{ep}',
#     710     video_id=video_id, fatal=fatal, note=note, errnote=errnote,
#     711     data=json.dumps(data).encode('utf8'), headers=real_headers,
#     712     query=filter_dict({
#     713         'key': self._configuration_arg(
#     714             'innertube_key', [api_key], ie_key=YoutubeIE.ie_key(), casesense=True)[0],
#     715         'prettyPrint': 'false',
#     716     }, cndn=lambda _, v: v))
#
# File ~/.conda/envs/LumenaAI/lib/python3.10/site-packages/yt_dlp/extractor/common.py:1152, in InfoExtractor.__create_download_methods.<locals>.download_content(self, url_or_request, video_id, note, errnote, transform_source, fatal, encoding, data, headers, query, expected_status, impersonate, require_impersonation)
#    1150     kwargs.pop('transform_source')
#    1151 # The method is fetched by name so subclasses can override _download_..._handle
# -> 1152 res = getattr(self, download_handle.__name__)(url_or_request, video_id, **kwargs)
#    1153 return res if res is False else res[0]
#
# File ~/.conda/envs/LumenaAI/lib/python3.10/site-packages/yt_dlp/extractor/common.py:1112, in InfoExtractor.__create_download_methods.<locals>.download_handle(self, url_or_request, video_id, note, errnote, transform_source, fatal, encoding, data, headers, query, expected_status, impersonate, require_impersonation)
#    1109 def download_handle(self, url_or_request, video_id, note=note, errnote=errnote, transform_source=None,
#    1110                     fatal=True, encoding=None, data=None, headers={}, query={}, expected_status=None,
#    1111                     impersonate=None, require_impersonation=False):
# -> 1112     res = self._download_webpage_handle(
#    1113         url_or_request, video_id, note=note, errnote=errnote, fatal=fatal, encoding=encoding,
#    1114         data=data, headers=headers, query=query, expected_status=expected_status,
#    1115         impersonate=impersonate, require_impersonation=require_impersonation)
#    1116     if res is False:
#    1117         return res
#
# File ~/.conda/envs/LumenaAI/lib/python3.10/site-packages/yt_dlp/extractor/common.py:962, in InfoExtractor._download_webpage_handle(self, url_or_request, video_id, note, errnote, fatal, encoding, data, headers, query, expected_status, impersonate, require_impersonation)
#     959 if isinstance(url_or_request, str):
#     960     url_or_request = url_or_request.partition('#')[0]
# --> 962 urlh = self._request_webpage(url_or_request, video_id, note, errnote, fatal, data=data,
#     963                              headers=headers, query=query, expected_status=expected_status,
#     964                              impersonate=impersonate, require_impersonation=require_impersonation)
#     965 if urlh is False:
#     966     assert not fatal
#
# File ~/.conda/envs/LumenaAI/lib/python3.10/site-packages/yt_dlp/extractor/common.py:898, in InfoExtractor._request_webpage(self, url_or_request, video_id, note, errnote, fatal, data, headers, query, expected_status, impersonate, require_impersonation)
#     895     self.report_warning(f'{message}; if you encounter errors, then {info_msg}', only_once=True)
#     897 try:
# --> 898     return self._downloader.urlopen(self._create_request(url_or_request, data, headers, query, extensions))
#     899 except network_exceptions as err:
#     900     if isinstance(err, HTTPError):
#
# File ~/.conda/envs/LumenaAI/lib/python3.10/site-packages/yt_dlp/YoutubeDL.py:4175, in YoutubeDL.urlopen(self, req)
#    4172 clean_headers(req.headers)
#    4174 try:
# -> 4175     return self._request_director.send(req)
#    4176 except NoSupportingHandlers as e:
#    4177     for ue in e.unsupported_errors:
#    4178         # FIXME: This depends on the order of errors.
#
# File ~/.conda/envs/LumenaAI/lib/python3.10/site-packages/yt_dlp/networking/common.py:117, in RequestDirector.send(self, request)
#     115 self._print_verbose(f'Sending request via "{handler.RH_NAME}"')
#     116 try:
# --> 117     response = handler.send(request)
#     118 except RequestError:
#     119     raise
#
# File ~/.conda/envs/LumenaAI/lib/python3.10/site-packages/yt_dlp/networking/_helper.py:208, in wrap_request_errors.<locals>.wrapper(self, *args, **kwargs)
#     205 @functools.wraps(func)
#     206 def wrapper(self, *args, **kwargs):
#     207     try:
# --> 208         return func(self, *args, **kwargs)
#     209     except RequestError as e:
#     210         if e.handler is None:
#
# File ~/.conda/envs/LumenaAI/lib/python3.10/site-packages/yt_dlp/networking/common.py:340, in RequestHandler.send(self, request)
#     338 if not isinstance(request, Request):
#     339     raise TypeError('Expected an instance of Request')
# --> 340 return self._send(request)
#
# File ~/.conda/envs/LumenaAI/lib/python3.10/site-packages/yt_dlp/networking/_requests.py:328, in RequestsRH._send(self, request)
#     322 session = self._get_instance(
#     323     cookiejar=self._get_cookiejar(request),
#     324     legacy_ssl_support=request.extensions.get('legacy_ssl'),
#     325 )
#     327 try:
# --> 328     requests_res = session.request(
#     329         method=request.method,
#     330         url=request.url,
#     331         data=request.data,
#     332         headers=headers,
#     333         timeout=self._calculate_timeout(request),
#     334         proxies=self._get_proxies(request),
#     335         allow_redirects=True,
#     336         stream=True,
#     337     )
#     339 except requests.exceptions.TooManyRedirects as e:
#     340     max_redirects_exceeded = True
#
# File ~/.conda/envs/LumenaAI/lib/python3.10/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/.conda/envs/LumenaAI/lib/python3.10/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/.conda/envs/LumenaAI/lib/python3.10/site-packages/requests/adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File ~/.conda/envs/LumenaAI/lib/python3.10/site-packages/urllib3/connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     784 response_conn = conn if not release_conn else None
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#     803 clean_exit = True
#
# File ~/.conda/envs/LumenaAI/lib/python3.10/site-packages/urllib3/connectionpool.py:534, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     532 # Receive the response from the server
#     533 try:
# --> 534     response = conn.getresponse()
#     535 except (BaseSSLError, OSError) as e:
#     536     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File ~/.conda/envs/LumenaAI/lib/python3.10/site-packages/urllib3/connection.py:516, in HTTPConnection.getresponse(self)
#     513 _shutdown = getattr(self.sock, "shutdown", None)
#     515 # Get the response from http.client.HTTPConnection
# --> 516 httplib_response = super().getresponse()
#     518 try:
#     519     assert_header_parsing(httplib_response.msg)
#
# File ~/.conda/envs/LumenaAI/lib/python3.10/http/client.py:1375, in HTTPConnection.getresponse(self)
#    1373 try:
#    1374     try:
# -> 1375         response.begin()
#    1376     except ConnectionError:
#    1377         self.close()
#
# File ~/.conda/envs/LumenaAI/lib/python3.10/http/client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File ~/.conda/envs/LumenaAI/lib/python3.10/http/client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File ~/.conda/envs/LumenaAI/lib/python3.10/socket.py:717, in SocketIO.readinto(self, b)
#     715 while True:
#     716     try:
# --> 717         return self._sock.recv_into(b)
#     718     except timeout:
#     719         self._timeout_occurred = True
#
# File ~/.conda/envs/LumenaAI/lib/python3.10/ssl.py:1307, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1303     if flags != 0:
#    1304         raise ValueError(
#    1305           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1306           self.__class__)
# -> 1307     return self.read(nbytes, buffer)
#    1308 else:
#    1309     return super().recv_into(buffer, nbytes, flags)
#
# File ~/.conda/envs/LumenaAI/lib/python3.10/ssl.py:1163, in SSLSocket.read(self, len, buffer)
#    1161 try:
#    1162     if buffer is not None:
# -> 1163         return self._sslobj.read(len, buffer)
#    1164     else:
#    1165         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
#print('complete')

# %%
# !pip install youtube-transcript-api
# Out:
# Collecting youtube-transcript-api
#   Downloading youtube_transcript_api-0.6.3-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: defusedxml<0.8.0,>=0.7.1 in /Users/kimhongil/.conda/envs/LumenaAI/lib/python3.10/site-packages (from youtube-transcript-api) (0.7.1)
# Requirement already satisfied: requests in /Users/kimhongil/.conda/envs/LumenaAI/lib/python3.10/site-packages (from youtube-transcript-api) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/kimhongil/.conda/envs/LumenaAI/lib/python3.10/site-packages (from requests->youtube-transcript-api) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/kimhongil/.conda/envs/LumenaAI/lib/python3.10/site-packages (from requests->youtube-transcript-api) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/kimhongil/.conda/envs/LumenaAI/lib/python3.10/site-packages (from requests->youtube-transcript-api) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/kimhongil/.conda/envs/LumenaAI/lib/python3.10/site-packages (from requests->youtube-transcript-api) (2024.12.14)
# Downloading youtube_transcript_api-0.6.3-py3-none-any.whl (622 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 622.3/622.3 kB 15.8 MB/s eta 0:00:00
# Installing collected packages: youtube-transcript-api
# Successfully installed youtube-transcript-api-0.6.3

# %%
from infrastructure.database.mongo_client import MongoDBClient
from infrastructure.repository import YouTubeContentRepository

from youtube_transcript_api import YouTubeTranscriptApi

import os
from dotenv import load_dotenv

load_dotenv()

# MongoDB 클라이언트 초기화
client = MongoDBClient(uri=os.environ['MONGO_CONNECTION_STRING'])
client.connect()

# 저장소 초기화
repository = YouTubeContentRepository(client)

from strategy import STTStrategyFactory, STTStrategyType

stt_strategy = STTStrategyFactory.create(STTStrategyType.AUTO_YOUTUBE)

contents = repository.find_all()

count = len(contents)
for i, content in enumerate(contents):
    print(f'{i + 1}/{count}: {content.title}: {content.url.url}')
    result = stt_strategy.transcribe_to_script(content.video_id)
    content.set_script_auto(result)

    if result is None:
        print("없어용")

    repository.save(content)
# Out:
# Connected to MongoDB
# 1/142: 2D 오브젝트🧍만들기 [유니티 뱀서라이크 01]: https://www.youtube.com/watch?v=qOTbP9ciJ88
# 2/142: 플레이어 이동🚶구현하기 [유니티 뱀서라이크 02]: https://www.youtube.com/watch?v=YAu4yWU5D5U
# 3/142: 새로운 인풋시스템🎮적용하기 [유니티 뱀서라이크 02+]: https://www.youtube.com/watch?v=tKMnVBTes0M
# 4/142: 2D 셀 애니메이션🏃제작하기 [유니티 뱀서라이크 03]: https://www.youtube.com/watch?v=vizfd1TeRMI
# 5/142: 무한🌍맵 이동 [유니티 뱀서라이크 04]: https://www.youtube.com/watch?v=SNjgew0VhHY
# 6/142: 몬스터🧟만들기 [유니티 뱀서라이크 05]: https://www.youtube.com/watch?v=0aUCu1BcZxs
# 7/142: 오브젝트 풀링🏊으로 소환하기 [유니티 뱀서라이크 06]: https://www.youtube.com/watch?v=A7mfPH8jyBE
# 8/142: 소환 레벨⏳적용하기 [유니티 뱀서라이크 06+]: https://www.youtube.com/watch?v=SSg_9q-8h-A
# 9/142: 회전하는🪓근접무기 구현 [유니티 뱀서라이크 07]: https://www.youtube.com/watch?v=HPJVVcRKwn0
# 10/142: 자동🎯원거리 공격 구현 [유니티 뱀서라이크 08]: https://www.youtube.com/watch?v=dBQHtMI-Og4
# 11/142: 타격감🌟있는 몬스터 처치 만들기 [유니티 뱀서라이크 09]: https://www.youtube.com/watch?v=JRaIlTEmvHY
# 12/142: HUD📐제작하기 [유니티 뱀서라이크 10]: https://www.youtube.com/watch?v=ip0xffLSWlk
# 13/142: 능력 업그레이드💪구현 [유니티 뱀서라이크 11]: https://www.youtube.com/watch?v=-47pjK-P888
# 14/142: 플레이어 무기 장착 표현하기 [유니티 뱀서라이크 11+]: https://www.youtube.com/watch?v=NE5j8YmJ5Ds
# 15/142: 레벨업🥳시스템 [유니티 뱀서라이크 12]: https://www.youtube.com/watch?v=eo8bLO7kHVo
# 16/142: 게임 시작과 종료 [유니티 뱀서라이크 13]: https://www.youtube.com/watch?v=Lt2Q9glJlw0
# 17/142: 플레이 캐릭터🧑‍🤝‍🧑선택 [유니티 뱀서라이크 14]: https://www.youtube.com/watch?v=vJACbWBDa90
# 18/142: 캐릭터 해금🔓시스템 [유니티 뱀서라이크 14+]: https://www.youtube.com/watch?v=QxsH5fE0iAo
# 19/142: 편리한 오디오🔊시스템 구축 [유니티 뱀서라이크 15]: https://www.youtube.com/watch?v=YPEkpwPrmPk
# 20/142: 로직🛠️보완하기 [유니티 뱀서라이크 16]: https://www.youtube.com/watch?v=XslHd_0oVXg
# 21/142: 모바일📱빌드하기 [유니티 뱀서라이크 17]: https://www.youtube.com/watch?v=O5Qvq4dypOg
# 22/142: 2D 종스크롤 슈팅 -  플레이어 이동 구현하기 [유니티 기초 강좌 B27 + 에셋 다운로드]: https://www.youtube.com/watch?v=ETYzjbnLixY
# 23/142: 2D 종스크롤 슈팅 -  총알발사 구현하기 [유니티 기초 강좌 B28]: https://www.youtube.com/watch?v=JUG0GnsJHQw
# 24/142: 2D 종스크롤 슈팅 -  적 비행기 만들기 [유니티 기초 강좌 B29]: https://www.youtube.com/watch?v=lKFka1regy8
# 25/142: 2D 종스크롤 슈팅 -  적 전투와 피격 이벤트 만들기 [유니티 기초 강좌 B30]: https://www.youtube.com/watch?v=OI7BvnN4zLE
# 26/142: 2D 종스크롤 슈팅 -  UI 간단하게 완성하기 [유니티 기초 강좌 B31]: https://www.youtube.com/watch?v=qXa7y1Que6s
# 27/142: 2D 종스크롤 슈팅 - 아이템과 필살기 구현하기 [유니티 기초 강좌 B32]: https://www.youtube.com/watch?v=RLbcov_aGfo
# 28/142: 2D 종스크롤 슈팅 - 원근감있는 무한 배경 만들기 [유니티 기초 강좌 B33]: https://www.youtube.com/watch?v=KUQAULcpYZU
# 29/142: 2D 종스크롤 슈팅 - 최적화의 기본, 오브젝트 풀링 (어려움!) [유니티 기초 강좌 B34]: https://www.youtube.com/watch?v=x-5eHMRSgeg
# 30/142: 2D 종스크롤 슈팅 - 텍스트파일을 이용한 커스텀 배치 구현 [유니티 기초 강좌 B35]: https://www.youtube.com/watch?v=yBjsGYUdyAA
# 31/142: 2D 종스크롤 슈팅 - 따라다니는 보조무기 만들기 [유니티 기초 강좌 B36]: https://www.youtube.com/watch?v=QPwF2Lsf7c8
# 32/142: 2D 종스크롤 슈팅 - 탄막을 뿜어대는 보스 만들기 [유니티 기초 강좌 B37]: https://www.youtube.com/watch?v=dnMVMBVpgYA
# 33/142: 2D 종스크롤 슈팅 - 모바일 슈팅게임 만들기 [유니티 기초 강좌 BE4]: https://www.youtube.com/watch?v=wM2IfVuEYYE
# 34/142: 탑다운 2D RPG - 도트 타일맵으로 쉽게 준비하기 [유니티 기초 강좌 B20 + 에셋 다운로드]: https://www.youtube.com/watch?v=JY-KFx3OsJo
# 35/142: 탑다운 2D RPG - 쯔꾸르식 액션 구현하기 [유니티 기초 강좌 B21]: https://www.youtube.com/watch?v=bZVa6C6vRBQ
# 36/142: 탑다운 2D RPG - 대화창 UI 구축하기 [유니티 기초 강좌 B22]: https://www.youtube.com/watch?v=jVBiGhlwhZg
# 37/142: 탑다운 2D RPG - 대화 시스템 구현하기 [유니티 기초 강좌 B23]: https://www.youtube.com/watch?v=qJjfYvEYKiE
# 38/142: 탑다운 2D RPG - 퀘스트 시스템 구현하기 [유니티 기초 강좌 B24]: https://www.youtube.com/watch?v=RwndWebxbmo
# 39/142: 탑다운 2D RPG - 대화 애니메이션 느낌있게 만들기 [유니티 기초 강좌 B25]: https://www.youtube.com/watch?v=emGwkkM6bnc
# 40/142: 탑다운 2D RPG - 서브메뉴와 저장기능 만들기 [유니티 기초 강좌 B26]: https://www.youtube.com/watch?v=mYjUVmws2F0
# 41/142: 탑다운 2D RPG - 모바일 UI & 안드로이드 빌드 [유니티 기초 강좌 BE3]: https://www.youtube.com/watch?v=IJxc-ANxO-w
# 42/142: 2D 플랫포머 - 프로젝트 준비하기 [유니티 기초 강좌 B13 + 에셋 다운로드]: https://www.youtube.com/watch?v=v_Y5FH_tCpc
# 43/142: 2D 플랫포머 - 아틀라스와 애니메이션 [유니티 기초 강좌 B14]: https://www.youtube.com/watch?v=IkvYstCzcoc
# 44/142: 2D 플랫포머 - 플레이어 이동 구현하기 [유니티 기초 강좌 B15]: https://www.youtube.com/watch?v=Z4iULRbiSTg
# 45/142: 2D 플랫포머 - 플레이어 점프 구현하기 [유니티 기초 강좌 B16]: https://www.youtube.com/watch?v=2SikOdH7xvQ
# 46/142: 2D 플랫포머 - 타일맵으로 플랫폼 만들기 [유니티 기초 강좌 B17]: https://www.youtube.com/watch?v=f8ixw9IpnD8
# 47/142: 2D 플랫포머 - 몬스터 AI 구현하기 [유니티 기초 강좌 B18]: https://www.youtube.com/watch?v=7MYUOzgZTf8
# 48/142: 2D 플랫포머 - 플레이어 피격 이벤트 구현하기 [유니티 기초 강좌 B19]: https://www.youtube.com/watch?v=epZFE5Hpbdc
# 49/142: 2D 플랫포머 - 스테이지를 넘나드는 게임 완성하기 [유니티 기초 강좌 BE2]: https://www.youtube.com/watch?v=GHUJMXtHKL0
# 50/142: 더욱 편리한 카메라워킹 패키지 유니티6의 시네머신3 소개: https://www.youtube.com/watch?v=350EWYC_1ZA
# 51/142: 편리한 기능과 API가 추가된 Unity 6 Physics 2D: https://www.youtube.com/watch?v=Q7mHfbEzaJM
# 52/142: [Unity 6] Unity 6를 소개합니다: https://www.youtube.com/watch?v=r4aZypBrFHE
# 없어용
# 53/142: Unity 6 Fantasy Kingdom으로 알아보는 4가지 그래픽스 신기능: https://www.youtube.com/watch?v=3mSO1sMdGxM
# 54/142: 유니티 뱀서라이크 개발강좌가 온다?! 언데드 서바이버: https://www.youtube.com/watch?v=MmW166cHj54
# 55/142: [Unity C#] #01 변수 : 변수와 데이터 (Variable and data): https://www.youtube.com/watch?v=YKiTGbPIZKQ
# 56/142: [Unity C#] #02 변수 : 기본 데이터 형식 (Data type): https://www.youtube.com/watch?v=bA9AVLUSvIo
# 57/142: [Unity C#] #03 변수 : 데이터의 형 변환 (Type conversion): https://www.youtube.com/watch?v=3NuO7TaWl0s
# 58/142: [Unity C#] #04 변수 : 상수, 열거형, Nullable, var: https://www.youtube.com/watch?v=O3L2GMcQn1U
# 59/142: [Unity C#] #05 문자열 다루기: https://www.youtube.com/watch?v=8L_lWH9u2UU
# 60/142: [Unity C#] #06 연산자: https://www.youtube.com/watch?v=Ci9k6ECcRp0
# 61/142: [Unity C#] #07 조건문: https://www.youtube.com/watch?v=IvfJigYIrAU
# 62/142: [Unity C#] #08 반복문: https://www.youtube.com/watch?v=u8pxxQZFVH4
# 63/142: [Unity C#] 반복문 문제: https://www.youtube.com/watch?v=iao7UL-OBIw
# 없어용
# 64/142: [Unity C#] #09 배열: https://www.youtube.com/watch?v=rtl5SoWaJvk
# 65/142: [Unity C#] #10 메소드 (Method): https://www.youtube.com/watch?v=o0Pklkow-AA
# 66/142: [Unity C#] #11 클래스 기초 (Class Basic): https://www.youtube.com/watch?v=wbzF4BNw5Zs
# 67/142: [Unity C#] #12 클래스 심화 (Class Advanced): https://www.youtube.com/watch?v=Y4mc6C7mYK0
# 68/142: [Unity C#] #13 클래스 추가 기능 (Class Additive Function): https://www.youtube.com/watch?v=2B16TSUyQPU
# 69/142: [Unity C#] #14 프로퍼티 (Property): https://www.youtube.com/watch?v=u0iXSe5IEV8
# 70/142: [Unity C#] #15 컬렉션 (Collection): https://www.youtube.com/watch?v=8WRh8TJkHBc
# 71/142: [Unity C#] #16 일반화 프로그래밍 (Generic Programming): https://www.youtube.com/watch?v=ab83gVHMZNg
# 72/142: [Unity C#] #17 파일입출력(File IO) - Directory, File: https://www.youtube.com/watch?v=argeDbqzUdE
# 73/142: [Unity C#] #18 파일입출력(File IO) - 스트림과 객체 직렬화: https://www.youtube.com/watch?v=SvUYPh6lnqo
# 74/142: [유니티 C#] #19 파일 브라우저 - 현재 폴더의 파일 목록 출력: https://www.youtube.com/watch?v=Bwi7EXCqscc
# 75/142: [유니티 C#] #20 파일 브라우저 - 폴더(Directory) 이동: https://www.youtube.com/watch?v=fsgEgPdHmFk
# 76/142: [유니티 C#] #21 파일 브라우저 - 문서, 일반 파일 선택 : 파일 정보 출력: https://www.youtube.com/watch?v=wBzAe9Ewsc4
# 77/142: [유니티 C#] #22 파일 브라우저 - PNG, JPG 파일 선택 : 이미지 출력: https://www.youtube.com/watch?v=ydS6u2bQI84
# 78/142: [유니티 C#] #23 파일 브라우저 - MP3 파일 선택 : 사운드 재생: https://www.youtube.com/watch?v=IvXg2PDb034
# 79/142: [유니티 C#] #24 파일 브라우저 - MP4 파일 선택 : 동영상 재생: https://www.youtube.com/watch?v=uqBQZqFMxkI
# 80/142: How to make a Minimap UI in Unity!: https://www.youtube.com/watch?v=IA9UfytQ5R8
# 81/142: How to make a HP/MP UI in Unity!: https://www.youtube.com/watch?v=C0y00zDBK3c
# 82/142: How to make a Dialog System in Unity!: https://www.youtube.com/watch?v=1fRbGvQlIEQ
# 83/142: How to make a Excel Importer in Unity!: https://www.youtube.com/watch?v=2oip0H7VgPM
# 84/142: How to make a Keep In Screen UI in Unity!: https://www.youtube.com/watch?v=emuT10nz5Ho
# 85/142: How to make a RTS Unit Control in Unity!: https://www.youtube.com/watch?v=vxCMOPCYeM0
# 86/142: How to make a FSM in Unity! [01]: https://www.youtube.com/watch?v=O_NJaHpbjaI
# 87/142: How to make a FSM in Unity! [02]: https://www.youtube.com/watch?v=4rmf0S885X4
# 88/142: How to make a FSM in Unity! [03]: https://www.youtube.com/watch?v=DeJO4zOFG9E
# 89/142: How to make a FSM in Unity! [04]: https://www.youtube.com/watch?v=xGu-sTL73iU
# 90/142: 유니티 룰렛 시스템 How to make a Roulette in Unity!: https://www.youtube.com/watch?v=L4tVAWcWHbs
# 91/142: 2D 플랫포머 캐릭터 이동 2D Platformer Movement with Raycast: https://www.youtube.com/watch?v=vfpnyz1a_no
# 92/142: 격자맵에서 부드러운 이동 구현 How to make a Grid based Smooth Movement in Unity!: https://www.youtube.com/watch?v=JZYFhNpobQo
# 93/142: 겹치지 않는 난수 생성 How to make a Non-Overlapping Random Numbers in Unity!: https://www.youtube.com/watch?v=eh04LRnh2Tg
# 94/142: How to make a Primitive Objects in Unity!: https://www.youtube.com/watch?v=unuZi0FEt8k
# 95/142: How to make a Primitive Objects II in Unity!: https://www.youtube.com/watch?v=atVEkx4v5cM
# 96/142: How to make a Polygon Generator in Unity!: https://www.youtube.com/watch?v=9lzASRQuWYM
# 97/142: 라인렌더러(LineRenderer) A to Z [Part 01][Basic]: https://www.youtube.com/watch?v=biL29u6YFpk
# 98/142: 라인렌더러(LineRenderer) A to Z [Part 02][Shapes]: https://www.youtube.com/watch?v=wAY9exBIw3A
# 99/142: 라인렌더러(LineRenderer) A to Z [Part 03][Morphology Conversion]: https://www.youtube.com/watch?v=fLdxtwm76Ok
# 100/142: 라인렌더러(LineRenderer) A to Z [Part 04][Collision]: https://www.youtube.com/watch?v=GXaW4GiyCHU
# 101/142: 2D 배경 스크롤 2D Infinite Parallax Background: https://www.youtube.com/watch?v=uyttyyB1HjI
# 102/142: 튜토리얼 제작 How to create Tutorial in Unity!: https://www.youtube.com/watch?v=82l6GZz32E8
# 103/142: 모바일 재화 축약 표현 (K, M, G, T, P, E, Z): https://www.youtube.com/watch?v=FgnLBO4DPA8
# 104/142: 선형 보간 (linear interpolate) - Lerp() 메소드: https://www.youtube.com/watch?v=zRfq2rZa9Ho
# 105/142: 확률을 이용한 오브젝트 생성 비율 조절 how to create Random Spawner with Probability in Unity!: https://www.youtube.com/watch?v=plrsQbdimpI
# 106/142: 씬을 실행할 때 현재 씬 자동 저장 how to create Save On Playmode in Unity!: https://www.youtube.com/watch?v=VJwLcSyY_uE
# 107/142: 0번 씬 또는 현재 씬 재생 how to create Edit Start Scene in Unity!: https://www.youtube.com/watch?v=8QBeWNb2yaw
# 108/142: [Custom Editor] Editor 폴더, Editor Window 제작: https://www.youtube.com/watch?v=_7EOwJEEVPs
# 109/142: [Custom Editor] GUI, GUILayout, EditorGUI, EditorGUILayout: https://www.youtube.com/watch?v=5BOMX5FHbD0
# 110/142: [Custom Editor] Field Methods - Input, Color, Object, Dropdown: https://www.youtube.com/watch?v=cImwp_-8hZY
# 111/142: [Custom Editor] Toggle - Toggle, Button Style Toggle, Toggle Group: https://www.youtube.com/watch?v=9LtIS4laeWw
# 112/142: [Custom Editor] Slider, HelpBox, Knob, IndentLevel, ProgressBar: https://www.youtube.com/watch?v=uOj9FiIKw_0
# 113/142: [Custom Editor] Begin/End Group: https://www.youtube.com/watch?v=FFuD4pRJaUg
# 114/142: 씬 자동 저장 how to create Scene Auto Save in Unity!: https://www.youtube.com/watch?v=2GtpnMbRRn0
# 115/142: 유니티 어트리뷰트 how to use attributes in Unity!: https://www.youtube.com/watch?v=yO0UxTo5Elk
# 116/142: 유니티 어트리뷰트 2   how to use attributes in Unity!: https://www.youtube.com/watch?v=dkbf75dt0AY
# 117/142: 폭발 오브젝트  how to create Explosive Object in Unity!: https://www.youtube.com/watch?v=snh2HrpV4No
# 118/142: 경로 따라가기  how to create Follow Path in Unity!: https://www.youtube.com/watch?v=ZVpdSmN_Sis
# 없어용
# 119/142: 목표 에워싸기  how to create Surround Target in Unity!: https://www.youtube.com/watch?v=lMPymM0Q6Rs
# 120/142: 마우스 커서 방향으로 회전  Look At Me!!: https://www.youtube.com/watch?v=XI56ogm7eFI
# 121/142: 반사  how to use Vector3.Reflect in Unity!: https://www.youtube.com/watch?v=uJ9teYEqJ48
# 122/142: 완전한 어둠 how to create real dark world in Unity!: https://www.youtube.com/watch?v=kDIKrar2maE
# 123/142: 가장 근접한 목표 탐색 how to find closest target in Unity!: https://www.youtube.com/watch?v=-dBSfaC4Qss
# 124/142: 직선, 유도, 곡선 발사체 (1) how to create straight, homing, bezier curve projectile in Unity!: https://www.youtube.com/watch?v=hZKk5iXmGG0
# 125/142: 직선, 유도, 곡선 발사체 (2) how to create straight, homing, bezier curve projectile in Unity!: https://www.youtube.com/watch?v=9X13qf62UQA
# 126/142: [유니티6] 다중 언어 지원 how to use Localization in Unity!: https://www.youtube.com/watch?v=BVqMfq_ilbA
# 127/142: [유니티6] 아이템 수집 효과 how to create Item Collect Effect in Unity!: https://www.youtube.com/watch?v=6bg1ltzFor0
# 128/142: [유니티6] 2D 길 찾기 인공지능 how to use Navmesh 2D in Unity!: https://www.youtube.com/watch?v=y6omNlRAN3Q
# 129/142: [유니티6] Behavior Tree를 이용한 AI 구현 (순찰) [1/3]   how to use Behavior Tree in Unity!: https://www.youtube.com/watch?v=ZbWbxlCQ6cA
# 130/142: [유니티6] Behavior Tree를 이용한 AI 구현 (대기, 순찰, 배회) [2/3]: https://www.youtube.com/watch?v=Oa2LW2rxb48
# 131/142: [유니티6] Behavior Tree를 이용한 AI 구현 (추적, 공격) [3/3]: https://www.youtube.com/watch?v=mRH0i0iqQAM
# 132/142: [유니티 TIPS] 새로워진 길찾기 AI Navigation 2.0 공략: https://www.youtube.com/watch?v=A0nsAjsJqHg
# 133/142: 유니티 시네머신 1 - 기본 컴포넌트 알아보기: https://www.youtube.com/watch?v=DXFrfh1oy3M
# 134/142: 2개 이상의 애니메이션을 하나로 합쳐서 표현하는 방법: https://www.youtube.com/watch?v=gj3gMhMZWoE
# 135/142: 체력에 따라 애니메이션이 달라지는 방법: https://www.youtube.com/watch?v=5WyebyiOayk
# 136/142: 유니티 애니메이션 총정리 1편 - 기초 설명 및 구현: https://www.youtube.com/watch?v=Cru7ZVVgy28
# 137/142: 유니티 애니메이션 총정리 2편 -  트랜지션과 파라미터 설명: https://www.youtube.com/watch?v=dLomdF5Z0DU
# 138/142: [유니티] 클릭 이동 구현하기 | Navigation(NavMesh): https://www.youtube.com/watch?v=ILefNAZGVFY
# 139/142: [유니티] 클릭 이동 구현하기 2 | Navigation(NavMesh): https://www.youtube.com/watch?v=cKBUcXDSqi4
# 140/142: 이제는 필수가 되어버린 고급네비메쉬: https://www.youtube.com/watch?v=OIcqe4ad5oA
# 141/142: 애니메이션 리타게팅 | 유니티: https://www.youtube.com/watch?v=2zU_FNym3ro
# 142/142: 애니메이션 샘플 레이트 | 유니티: https://www.youtube.com/watch?v=aK1lfH8Q3SU
